# %% [markdown]
# # Introduction
#
# Neural networks are vulnerable to adversarial examples. Adversarial examples alter input data that cause mistakes in models. These alternations must be imperceivable to humans. In the area of Natural Language Processing(NLP),  there exist only a few adversarial attacks. This might be due to the difficulty that words in sentences are discrete tokens, while images are continuous. It is much easier for a human to determine a perturbed sentence while minor changes to image pixels still yield a meaningful image for human eyes.
#
# In this project we will focus on a single adversarial attack, as well as two potential defense methods.

# %% [markdown]
# # Motivation
#
# The existence of adversarial examples for any task raises concerns about the safe use of neural networks. In NLP tasks such as document classification, named entity recognition, spam filtering, fake news detection, sentiment analysis, etc... adversarial examples that cause incorrect predictions could result in a variety of issues. For example in a form of governmental document classification if a form is misclassified and filed it could have potential security issues.

# %% [markdown]
# # Approach
#
# In this project we focus on Generating Natural Language Adversarial Examples through Probability Weighted Word Saliency. Their work provides an adversarial attack that insures lexical correctness with few grammatical errors and little semantic shifting.
#
# The work introduces a new synonym replacement method: Probability Weighted Word Saliency (PWWS). PWWS considers the word saliency as well as the classification probability. The change value of the classification probability is used to measure the attack effect of the proposed substitute word, while word saliency shows how well the original word affects the classification.  The change value of the classification probability weighted by word saliency determines the final substitute word and replacement order.
#
# In order to defend against this attack we will explore two methods: applying spectral normalization, and directly increase the inter-class variance for synonym word vectors as we want to study the link between cosine similarity and adversarial robustness.
#
# ## Attack
#
# ### Probability Weighted Word Saliency (PWWS)
#
# A high quality perturbation that is imperceptible to humans needs to satisfy lexical, grammatical, and semantic constraints. Lexical constraints prevent common misspellings while the semantic constraint insures the message of the text remains the same [4].
#
# Given a sentence which is represented as sequence of words:
#
# $x = w_1 w_2 ... w_i ... w_n$
#
# PWWS attempts to replace each $w_i$ with $w_{i}^{'}$
#
# $x^{'} = w_1 w_2 ... w_{i}^{'} ... w_n$
#
# Given the true label: $y_{true}$ PWWS evaluates each replacement via:
#
# $P(y_{true}|x) − P(y_{true}|x^{'})$
#
# Whichever $w_{i}^{'}$ maximizes this difference, is picked to replacemen that word. PWWS evaluates for ALL words in a sentence, and picks the largest $w_{i}^{'}$ for EACH word.  The words are replaced until PWWS either finds an adversarial example, or all words have been replaced and no adversary has been found [4]. More details on this are discussed below.
#
# #### Synonym Classification Probability
#
# To meet the above constraints, words are replaced with  synonyms  and  named entities (NEs) with similar NEs. Synonyms for each word are found in WordNet. NE's are entities that have a specific meaning in the sample text, such as a person’s name, a location, an organization, or a proper noun. To replace an NE, a subset of NE's based on their occurance within classes are created (i.e Christopher Nolan is a person related to a "Good" sentiment). Only related NE's within the same class of NE, as well as from the same label for the input are acceptable synonym replacements. With the synonym subsets created, each word is replaced with it synonym, the input is run through the model, and the substitute word that causes the most significant change in the classification probability after replacement is choosen [4].
#
# #### Word Saliency
#
# Word saliency refers to the degree of change in the output probability of the classifier if a word is set to unknown (out of vocabulary). Similar to synonym classification probability, a word is replaced with the unknown token, and the difference in classification probability is recorded. I.e in this case we still evaluate $P(y_{true}|x) − P(y_{true}|x^{'})$ BUT $w_{i}^{'} = \text{<UNK>}$ for all substitutions [4].
#
# #### PWWS
#
# The two scores (difference in classification) for each word, synonym pair are multiplied, and sorted. The best candidate for each word is choosen and the replacement order is determined via the highest scores [4].
#
# ## Defense
#
# ### Spectral Norm
#
# For adversarial defense, we want to first examine the use of spectral normalization for word-embedding model. Spectral normalization is a method that ensures the largest singular value for SVD of each network weight layer is 1 [3]. In this way, the model is very smooth (satisfies the l1-lipschitz constraint) and making small changes to the input will not result in large changes in the final output. As the PWWS attack attempts to make small changes that retain the semantic content of the text, sastify lexical properties, and do not introduce grammatical errors, we belive this method may be an effective defense.
#
# ### Maximizing Word Embedding Dissimilarity
#
# Our hypothesis is that during an attack, synonyms close to semantically different words are found using PWWS i.e the synonym the furthest away from the candidate word is chosen. Considering synonyms are likely with a degree range of cosine similarity, if we were to maximize the word embedding dissimilarity, we could "push" these synonyms out of this range and make them unviable candidates. By doing this we hope that PWWS will only select extremely similar words, and thus fail to fool the model, or ridiculous words in which a human reader could tell the input has been tampered with.
#
# We explicitly formulate the metric using Hamming distance. It can be shown that the Hamming distance between embeddings hash codes and their inner product is [5]:
#
# $dist_H(w_i, w_j) = \frac{1}{2}(L - \frac{|sign(w_i) (sign(w_j))^T|}{||sign(w_i) (sign(w_j))^T||^2_2})$
#
# Where the minimum hamming distance is thus:
#
# $d_{min}(Doc) = min(dist_H(x,y): x, y \in Doc, x \ne y)$
#
# Why the sign? Hamming distance is reservered for embeddings with a DISCRETE amount of states per dimension. In this work we explore using 2 states, i.e binary states, +1 and -1. This way we allow our embeddings to be continuous, while still partly constrainting the embeddings to be in the hamming space.
#
# Why the hamming distance? Simply, it provides a nice theoretical guarantee on correctness give a certain amount of error. Since we are corrupting word embeddings, this will help us retain as much "clean" classification accuracy as possible. Formally, if there are $V$ bits of errors in an erroneous document embedding from class $C$. Then as long as $V \le \lfloor \frac{d_{min}(Doc) - 1}{2} \rfloor$, then model can classy the document correctly. Note that in the numerator we see the minimum hamming distance. Therefore by maximizing the minimum hamming distance, simultaneously maximizing dissimilarity, the more corruptions the model can have while still being classified correctly [5].
#
# To formalize our loss: as the values are binary (due to the sign, in our case either -1 or +1) the inner product between the embeddings of two similar words should equal the length of the embedding. To represent this we can use a hinge loss:
#
# $max(dist_H - L, 0.0)$
#
# Where L is the embedding dimension of the model.
#
# We combine this loss with a cross entropy classification loss, as well as a L2 regularization term using the binary values:
#
# $||sign(w) - w ||_{2}^{2}$
#
# Our final loss is thus the regular cross entropy classification loss, plus the hinge loss based on the hamming distance above, and the binary regularization term weighted by a value. $\lambda = 0.1$ was used for all experiments seen.
#
# $CE(x,y_{true}) + max(dist_H - L, 0.0) + \lambda ||sign(w) - w ||_{2}^{2}$
#
# The differences between this work and the cited work [5] are that we apply this in an NLP task instead of a computer vision task on a document level, across individual word embeddings to defend against an adversarial attack, as well as combine the hamming distance optimization with a cross entropy loss. In [5] this method is strictly used for image retrieval. We implement the code from scratch in tensorflow, as well as provide additional experiments using spectral normalization and cosine similarity instead of a binary coding of the embeddings for the hamming disance. In addition to this, we provide plots related strictly to our work such as word clouds, and example generated advesarial examples.
#
# ## Model
#
# We follow a word level CNN model [1] defined in Generating Natural Language Adversarial Examples through Probability Weighted Word Saliency [4]. It is a very small model with an embedding layer, some convolutional layers, then a few fully connected layers into a softmax then cross entropy loss function.

# %% [markdown]
# ## Data
#
# Following the paper we will train and test on an NLP dataset. Due to time constraints we will only focus on the **IMDB sentiment classification** [2] dataset as it is the smallest at 25000 training samples. For time purposes only 200 examples will be used for validation due to extreme processing time to generate adversarial examples via PWWS (around 4 hours for just 200 examples for the baseline, longer for more robust defense methods).

# %% [markdown]
# ## Experimental Setup
#
# We will evaluate 5 different model structures:
#
# 1. Baseline
# 2. Baseline + Spectral Norm (SN)
# 3. Baseline + Spectral Norm (SN) + Binary Regularization Term
# 4. Baseline + Spectral Norm (SN) + Binary Regularization Term + Cosine Similarity Loss
# 5. Baseline + Spectral Norm (SN) + Binary Regularization Term + Min Hamming Distance Maximization
#
# Why these models? We need a baseline to compare to. We also iteratively add more losses to our model, effectively doing an abalation study to determine what loss term contributes to the performance. We test a model with a direct cosine similarity loss (instead of using the signed values), to show that a discrete hamming distance maximization is superior.
#
# Our measure of successes are:
#
# * Clean Accuracy: percentage of correctly classified clean inputs, Higher is better. Ideally we want our model to be as close to the baseline as possible [4].
# * Substitution rates: percentage of words or named entities substituted. Higher is better, the more words and named entities substitued, the harder the attacker is working and the more likely a human will be able to detect an attack has occured [4].
# * Attack Success Rate: percentage of successful adversarial inputs. Lower is better, it represents 1 - defense rate [4].
# * Avg Replacement Similarity: cosine similarity of replaced word with original word. We want to see that our model has a lower replacement cosine similarity value.

# %% [markdown]
# ## Results and Analysis
#
# | Method          | Clean Acc | Attacked Acc | Word Sub Rate | NE Sub Rate | Avg Replacement Sim |
# | :-------------: | :-------: | :----------: | :-----------: | :---------: | :-----------------: |
# | Baseline        |    **90.5**   |      92.0    |      5.1      |     8.2     |        0.986        |
# | SN              |    89.5   |      85.0    |      6.9      |     **16.1**    |        0.928        |
# | SN + Bin        |    89.0   |      73.5    |      10.04    |     9.13    |        **0.87**        |
# | SN + Cos + Bin  |    88.0   |      76.5    |      9.25     |     6.53    |        0.97        |
# | SN + Ham + Bin  |    88.5   |      **70.5**    |      **11.64**    |     11.37   |        0.89       |
#
# In the above table we can see that the SN + Ham + Bin gives the best defense results, although it suffers a minor decrease in clean prediction accuracy VS the baseline model. We can see that the binary regression term makes the largest difference in attack defense rates, and in substitution rates compared to the baseline model. It also makes no additional clean accuracy impact VS the model with only SN. Using a direct cosine similarity in the hamming distance maximization, the attacked accuracy receives 6% less benefit VS the discretized loss using the sign of the embeddings.

# %% [markdown]
# ### Results and Analysis: Word Cloud Analysis
#
#
# Below we have word clouds of "original_replacement" for 3 types of attacked networks (Baseline, SN, and SN + Ham + Bin). We can see the base line network attacks have extremely similar word pairs such as (movie, flick), (film, cinema), (excellent, splendid), (life, biography) etc...
#
# For the network trained with spectral norm there is excessive use of the word "seagal" representing Steven Seagal, i.e (holloywood, seagal), (london, seagal), (hitchcock, seagal). There are also a few polar opposite words breaking the semantic constraint set by the algorithm such as (perfect, gross), (awesome, awful). With that said there still exists reasonable substitutions such as (slow, tedious) and (story, narration).
#
# Lastly the spectral norm + binary + hamming loss has excessive use of the words "bad" and "seagal". It has more polar opposites similar to spectral norm i.e (awesome, awful). There do still exists reasonable substitutions such as  (film, cinema), but not many.

# %%
fig, axs = plt.subplots(1, 3, figsize=(16,8))
axs[0].imshow(regWord, interpolation='bilinear')
axs[0].axis('off')
axs[0].set_title("Baseline")
axs[1].imshow(snWord, interpolation='bilinear')
axs[1].axis('off')
axs[1].set_title("Spec Norm")
axs[2].imshow(binWord, interpolation='bilinear')
axs[2].axis('off')
axs[2].set_title("Spec Norm + Ham + Bin")
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(regWord, interpolation='bilinear')
plt.title("Reg")
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(snWord, interpolation='bilinear')
plt.title("Spec Norm")
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(binWord, interpolation='bilinear')
plt.title("Spec Norm + Ham + Bin")
plt.axis('off')
plt.show()

# %% [markdown]
# ### Results and Analysis: Example Analysis
#
# Lastly for our results we leave with an example of an adversarial example generated for all 3 networks. Any substitions are notated "original/replacement". In the example below we can see that both the baseline and spectral norm model are fooled by a single replacement. The spectral norm + binary hamming loss requires several, some of which that are semantic breaking, substitions to generate an adversarial example. For example 3 words in a row, the, final, and seconds are all replaced with "minutes". This sentence now makes 0 sense.
#
# **Baseline**
#
# The film begins with a jaded professor haranguing his class because the students have the audacity to not be as incredibly brilliant as he is! You can tell very quickly that this man is a total cynic--finding the value in practically nothing but sticking to his own inner sense of self-importance. Additionally, he seems tired and bored with the monotony of life.Later in the film, he walks into a bank robbery and manages to annoy the robbers so much that one of them shoots him in the head. Oddly, this is only half-way through the film and what followed was a very bizarre narration of the final seconds of his life. This is when the film becomes exciting because the style of the narration is just like one of this literature professor's novels--one that is intelligently written and says things the way we wish we could all say them.See this weird film--it's **amazingly/astonishingly** compelling and not like anything I've ever seen before.
#
# **Spectral Norm**
#
# The film begins with a jaded professor haranguing his class because the students have the audacity to not be as incredibly **brilliant/bright** as he is! You can tell very quickly that this man is a total cynic--finding the value in practically nothing but sticking to his own inner sense of self-importance. Additionally, he seems tired and bored with the monotony of life.Later in the film, he walks into a bank robbery and manages to annoy the robbers so much that one of them shoots him in the head. Oddly, this is only half-way through the film and what followed was a very bizarre narration of the final seconds of his life. This is when the film becomes exciting because the style of the narration is just like one of this literature professor's novels--one that is intelligently written and says things the way we wish we could all say them.See this weird film--it's amazingly compelling and not like anything I've ever seen before.
#
# **Spec Norm + Binary**
#
# The film begins with a jaded professor haranguing his class because the students have the audacity to not be as incredibly **brilliant/vivid** as he is! You can tell **very/really** quickly that this man is a total cynic--finding the value in practically nothing but sticking to his own **inner/internal** sense of self-importance. Additionally, he seems **tired/old** and bored with the monotony of life. Later in the film, he walks into a **bank/coin** robbery and manages to **annoy/bother** the robbers so much that one of them shoots him in the head. Oddly, this is only half-way through the film and what followed was a very bizarre narration of **the/minutes** **final/minutes** **seconds/minutes** of his **life/biography**. This is when the film becomes exciting because the style of the **narration/yarn** is **just/barely** like **one/zero** of this literature professor's novels--**one/zero** that is intelligently written and says things the way we wish we could all say them.See this weird film--it's amazingly compelling and not like anything I've ever seen before.

# %% [markdown]
# ## Future Work
#
# In this work we only tested on a single simple model, on a small set of data. We also only focused on a single attack, PWWS, which claimed to have made small modifications to the input to adhere to the adversarial property that humans cannot tell the difference after the attack. In addition to this, while our metrics are acceptable by current standards, the adversarial quality of the attacks generated by PWWS after our defense are "questionable". A better evaluation scheme would be to get humans to review generated adversarial attacks and approve their validity. This way we could get a more realistic measure of our defense accuracy. In closing this work could be extended to character models, larger models, and use a more extension (and expensive) evaluation scheme.

# %% [markdown]
# ## Conclusions
#
# While a minor loss in accuracy is suffered on clean examples, our method is much more robust to adversarial attacks generated via PWWS. We believe if humans were to read through the generated adversarial examples, the attack success rate would in reality be quite a bit lower. The hamming word embedding modification + binary normalization loss also improves upon spectral normalization results, as well as the naive cosine similarity based hamming loss.

# %% [markdown]
# ## References
#
# [1] Yoon Kim. Convolutional neural networks for sentence classification. CoRR,
# abs/1408.5882, 2014.
#
# [2] Andrew L. Maas, Raymond E. Daly, Peter T. Pham, Dan Huang, Andrew Y.
# Ng, and Christopher Potts. Learning word vectors for sentiment analysis. In
# Proceedings of the 49th Annual Meeting of the Association for Computational
# Linguistics: Human Language Technologies, pages 142–150, Portland, Oregon,
# USA, June 2011. Association for Computational Linguistics.
#
# [3] Takeru Miyato, Toshiki Kataoka, Masanori Koyama, and Yuichi Yoshida.
# Spectral normalization for generative adversarial networks. CoRR,
# abs/1802.05957, 2018.
#
# [4] Shuhuai Ren, Yihe Deng, Kun He, and Wanxiang Che. Generating natural
# language adversarial examples through probability weighted word saliency.
# In Proceedings of the 57th Annual Meeting of the Association for Computational
# Linguistics, pages 1085–1097, Florence, Italy, July 2019. Association
# for Computational Linguistics.
#
# [5] Xiang Xu, Xiaofang Wang, and Kris M. Kitani. Error correction maximization
# for deep image hashing. CoRR, abs/1808.01942, 2018.

# %% [markdown]
# ## Code

# %%
import os
from read_files import split_imdb_files, split_yahoo_files, split_agnews_files
from read_files import read_imdb_files, read_yahoo_files, read_agnews_files
from word_level_process import word_process, get_tokenizer
from char_level_process import char_process
# from neural_networks import word_cnn, char_cnn, bd_lstm, lstm
import keras
from keras import backend as K
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, LSTM, Bidirectional
from keras.layers import Conv1D, GlobalMaxPooling1D, MaxPool1D, Flatten, Reshape
from SpectralNormalizationKeras import DenseSN, ConvSN2D
import sklearn
import tensorflow as tf
import argparse
from config import config
from sklearn.utils import shuffle
from adversarial_tools import ForwardGradWrapper, adversarial_paraphrase
from unbuffered import Unbuffered
import sys
import time
import numpy as np
import operator
import re
import scipy
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import math
from keras import losses
#import pdb

# Need to run
# python -m spacy download en_core_web_sm
# Then shutdown and restart notebook
# nltk.download("wordnet")

tf_config = tf.ConfigProto(allow_soft_placement=True)
tf_config.gpu_options.allow_growth = True
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
K.set_session(tf.Session(config=tf_config))

# %% [markdown]
# ### Code: Model

# %%
from config import config

def get_embedding_matrix(dataset, num_words, embedding_dims):
    # global num_words, embedding_matrix, word_index
    global embedding_matrix, word_index
    word_index = get_tokenizer(dataset).word_index
    print('Preparing embedding matrix.')
    # num_words = min(num_words, len(word_index))
    embedding_matrix = np.zeros((num_words + 1, embedding_dims))
    for word, i in word_index.items():
        if i > num_words:
            continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    return embedding_matrix, word_index

def word_cnn(dataset, use_glove=False, sn=True, binary=False,
                        hamming = False, cosMod = False):
    filters = 250
    kernel_size = 3
    hidden_dims = 250

    max_len = config.word_max_len[dataset]
    num_classes = config.num_classes[dataset]
    loss = config.loss[dataset]
    activation = config.activation[dataset]
    embedding_dims = config.wordCNN_embedding_dims[dataset]
    num_words = config.num_words[dataset]
#     print(num_words)

    print('Build word_cnn model...')
    model = Sequential()

    if use_glove:
        file_path = r'./glove.6B.{}d.txt'.format(str(embedding_dims))
#         pdb.set_trace()
#         get_embedding_index(file_path)
        embedding_matrix, word_index = get_embedding_matrix(dataset, num_words, embedding_dims)
        model.add(Embedding(  # Layer 0, Start
            input_dim=num_words + 1,  # Size to dictionary, has to be input + 1
            output_dim=embedding_dims,  # Dimensions to generate
            weights=[embedding_matrix],  # Initialize word weights
            input_length=max_len,
            name="embedding_layer",
            trainable=False))
    else:
        # embedding_dims => 50
        word_index = get_tokenizer(dataset).word_index
        model.add(Embedding(num_words, embedding_dims, input_length=max_len))  
    model.add(Dropout(0.2))

    
    if sn:
    ##  with SN  ##
        model.add(Reshape((-1, 400, 50)))
        model.add(ConvSN2D(filters, (1, kernel_size), strides=1, padding='valid', activation='relu'))
        model.add(Reshape((398, 250)))
        model.add(GlobalMaxPooling1D())
        model.add(DenseSN(hidden_dims))
        model.add(Dropout(0.2))
        model.add(Activation('relu'))
        model.add(DenseSN(num_classes))
        model.add(Activation(activation))
    else:
    
    ##  without SN  ##
        model.add(Conv1D(filters, kernel_size, padding='valid', activation='relu', strides=1))
        model.add(GlobalMaxPooling1D())
        model.add(Dense(hidden_dims))
        model.add(Dropout(0.2))
        model.add(Activation('relu'))
        model.add(Dense(num_classes))
        model.add(Activation(activation))
    
    # get threshold
    ## compute Gilbert–Varshamov Bound ##
    def _check_(L, M, d):
        left = 0
        for i in range(0, d):
            left = left + scipy.special.binom(L,i)
        tmp = float(pow(2, int(L))) / left
        return (tmp>M)

    def gvbound(L,M,tight=False):
        d = 1
        while (_check_(L, M, d)): d += 1
        if not tight: d -= 1
        print('Distance for %d classes with %d bits (GV bound): %d' %(M,L,d))
        return d

    ## compute Hamming Bound ##
    def check(L, M, d):
        right = float(pow(2, int(L))) / float(M)
        x = math.floor(float(d - 1) / 2.0)
        left = 0
        for i in range(0, x+1):
            left = left + scipy.special.binom(L,i)
        return (left <= right)
    
    def hammingbound(L,M,tight=False):
        d = 0
        while (check(L, M, d)): d += 1
        if not tight: d -= 1
        print('Distance for %d classes with %d bits (Hamming bound): %d' %(M,L,d))
        return d
    
    embedding_dims = config.wordCNN_embedding_dims[dataset]
    num_words = config.num_words[dataset]
    ham_bound = hammingbound(embedding_dims, num_words)
    gv_bound = gvbound(embedding_dims,num_words)
    bound = ham_bound

    def custom_loss_wrapper(y_true, y_pred):
        # ce-loss
        xent_loss = losses.binary_crossentropy(y_true, y_pred)
        # quantization loss
        embedding_output = model.layers[0].output
        Bbatch = tf.sign(embedding_output)
        quan_l = K.mean(keras.losses.mean_absolute_error(Bbatch,embedding_output))
        # ecoc loss
        centers = model.layers[0].weights[0]
        centers_binary = tf.sign(centers)
        # For cosine
#         norm_centers = tf.math.l2_normalize(centers, axis=1)
#         prod = tf.matmul(norm_centers, tf.transpose(norm_centers)) #5000 x 5000
        prod = tf.matmul(centers, tf.transpose(centers)) #5000 x 5000
        ham_dist = 0.5 * (embedding_dims - prod)
#         marg_loss = K.mean(prod)
#         tmp = K.maximum(0.0, ham_dist - bound)
#         non_zero = K.sum(K.cast(tmp > 0, dtype='float32'))
#         marg_loss = K.sum(tmp) * 1.0/(non_zero+1.0)

        #tmp2 = K.maximum(0.0, gv_bound - ham_dist)
        #non_zero2 = K.sum(K.cast(tmp2 > 0, dtype='float32'))
        #marg_loss2 = K.sum(tmp2) * 1.0/(non_zero2+1.0)
        
        return  xent_loss - ham_dist + 0.1*quan_l
    
    def quan_loss(y_true, y_pred):
        embedding_output = model.layers[0].output
        Bbatch = tf.sign(embedding_output)
        quan_l = K.mean(keras.losses.mean_absolute_error(Bbatch,embedding_output))
        return  quan_l

    def ecoc_loss(y_true, y_pred):
        # ecoc loss
        centers = model.layers[0].weights[0]
        centers_binary = tf.sign(centers)
#         norm_centers = tf.math.l2_normalize(centers, axis=1)
#         prod = tf.matmul(norm_centers, tf.transpose(norm_centers)) #5000 x 5000
        prod = tf.matmul(centers, tf.transpose(centers))
        ham_dist = 0.5 * (embedding_dims - prod)
#         marg_loss = K.mean(prod)
#         tmp = K.maximum(0.0, bound - ham_dist)
#         non_zero = K.sum(K.cast(tmp > 0, dtype='float32'))
#         marg_loss = K.sum(tmp) * 1.0/(non_zero+1.0)
        #tmp = K.maximum(0.0, ham_dist - bound)
        #non_zero = K.sum(K.cast(tmp > 0, dtype='float32'))
        #marg_loss = K.sum(tmp) * 1.0/(non_zero+1.0)
        return  ham_dist

    if binary:
        model.compile(loss=custom_loss_wrapper,
                      optimizer='adam',
                      metrics=['accuracy',quan_loss,ecoc_loss])
    else:
        model.compile(loss=loss,
                      optimizer='adam',
                      metrics=['accuracy'])

    if sn:
        model_path = r'./runs/imdb/word_cnn.dat_15epoch_sn'
        if binary:
            if hamming:
                model_path = r'./runs/imdb/word_cnn.dat_ecoc_v6'
            if cosMod:
                model_path = r'./runs/imdb/word_cnn.dat_cosine_0.1ratio_binary'
            if (hamming == False) and (cosMod == False):
                model_path  = r'./runs/imdb/word_cnn.dat_15epoch_best_binary_sn'  
    else:
        model_path = r'./runs/imdb/word_cnn.dat_15epoch'
        
    #model_path = r'./runs/{}/{}.dat_15epoch_sn'.format(dataset, args.model)
    model.load_weights(model_path)
    return model, model.layers[0].get_weights()

# %% [markdown]
# ### Code: Training Procedure
#
# Following the paper we will train and test on an NLP dataset. Due to time constraints we will only focus on the IMDB sentiment classification dataset as it is the smallest. We also only train the word level CNN model featured below.

# %%
def train_text_classifier(model = "word_cnn", dataset = "imdb", level = "word",
                         use_glove=False, sn=False, binary=False):
    x_train = y_train = x_test = y_test = None
    if dataset == 'imdb':
        train_texts, train_labels, test_texts, test_labels = split_imdb_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    elif dataset == 'agnews':
        train_texts, train_labels, test_texts, test_labels = split_agnews_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    elif dataset == 'yahoo':
        train_texts, train_labels, test_texts, test_labels = split_yahoo_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    x_train, y_train = shuffle(x_train, y_train, random_state=0)

    # Take a look at the shapes
    print('dataset:', dataset, '; model:', model, '; level:', level)
    print('X_train:', x_train.shape)
    print('y_train:', y_train.shape)
    print('X_test:', x_test.shape)
    print('y_test:', y_test.shape)

    log_dir = r'./logs/{}/{}_notebook/'.format(dataset, model)
    tb_callback = keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True)

    model_path = r'./runs/{}/{}_notebook.dat_sn'.format(dataset, model)
    batch_size = epochs = None
#     assert model[:4] == level

    if model == "word_cnn":
        model = word_cnn(dataset, use_glove, sn, binary)
        batch_size = config.wordCNN_batch_size[dataset]
        epochs = config.wordCNN_epochs[dataset]
       
    print(model.summary())
    print('Train...')
    print('batch_size: ', batch_size, "; epochs: ", epochs)
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_split=0.2,
              shuffle=True,
              callbacks=[tb_callback])
    scores = model.evaluate(x_test, y_test)
    print('test_loss: %f, accuracy: %f' % (scores[0], scores[1]))
    print('Saving model weights...')
    model.save_weights(model_path)

# %%
train_text_classifier()
# Out:
# Processing IMDB dataset
# dataset: imdb ; model: word_cnn ; level: word
# X_train: (25000, 400)
# y_train: (25000, 2)
# X_test: (25000, 400)
# y_test: (25000, 2)
# Build word_cnn model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 400, 50)           250000
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 400, 50)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 398, 250)          37750
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 250)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 250)               62750
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 250)               0
# _________________________________________________________________
# activation_3 (Activation)    (None, 250)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 502
# _________________________________________________________________
# activation_4 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 351,002
# Trainable params: 351,002
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train...
# batch_size:  32 ; epochs:  2
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/2
# 20000/20000 [==============================] - 6s 296us/step - loss: 0.4322 - acc: 0.7833 - val_loss: 0.3176 - val_acc: 0.8660
# Epoch 2/2
# 20000/20000 [==============================] - 4s 188us/step - loss: 0.2421 - acc: 0.9026 - val_loss: 0.2703 - val_acc: 0.8879
# 25000/25000 [==============================] - 1s 49us/step
# test_loss: 0.272113, accuracy: 0.887640
# Saving model weights...

# %% [markdown]
# ### Code: Eval

# %%
sys.stdout = Unbuffered(sys.stdout)
tfconfig = tf.ConfigProto(allow_soft_placement=True)
tfconfig.gpu_options.allow_growth = True
K.set_session(tf.Session(config=tfconfig))
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"

def write_origin_input_texts(origin_input_texts_path, test_texts, test_samples_cap=None):
    if test_samples_cap is None:
        test_samples_cap = len(test_texts)
    with open(origin_input_texts_path, 'a') as f:
        for i in range(test_samples_cap):
            f.write(test_texts[i] + '\n')


def fool_text_classifier(clean_samples_cap = 200, dataset="imdb", 
                         level = "word", argsModel = "word_cnn", model_type="sn", binary=False,
                        hamming = False, cosMod = False):
    print('clean_samples_cap:', clean_samples_cap)

    # get tokenizer
    tokenizer = get_tokenizer(dataset)

    # Read data set
    x_test = y_test = None
    test_texts = None
    if dataset == 'imdb':
        train_texts, train_labels, test_texts, test_labels = split_imdb_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    elif dataset == 'agnews':
        train_texts, train_labels, test_texts, test_labels = split_agnews_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    elif dataset == 'yahoo':
        train_texts, train_labels, test_texts, test_labels = split_yahoo_files()
        if level == 'word':
            x_train, y_train, x_test, y_test = word_process(train_texts, train_labels, test_texts, test_labels, dataset)
        elif level == 'char':
            x_train, y_train, x_test, y_test = char_process(train_texts, train_labels, test_texts, test_labels, dataset)
    
    # Write clean examples into a txt file
    clean_texts_path = r'./fool_result/{}/clean_{}_15epoch_sn.txt'.format(dataset, str(clean_samples_cap))
    if not os.path.isfile(clean_texts_path):
        write_origin_input_texts(clean_texts_path, test_texts)

    # Select the model and load the trained weights
    model = None
    if argsModel == "word_cnn":
        if model_type == "sn":
            model, embMat = word_cnn(dataset)
        else:
            model, embMat = word_cnn(dataset, sn=False)
    
    if model_type == "sn":
        model_path = r'./runs/imdb/{}.dat_15epoch_{}'.format(argsModel, model_type)
        if binary:
            if hamming:
                model_path = r'./runs/imdb/word_cnn.dat_ecoc_v6'
            if cosMod:
                model_path = r'./runs/imdb/word_cnn.dat_cosine_0.1ratio_binary'
            if (hamming == False) and (cosMod == False):
                model_path  = r'./runs/imdb/word_cnn.dat_15epoch_best_binary_sn'          
    else:
        model_path = r'./runs/imdb/{}.dat_15epoch'.format(argsModel, model_type)
            
    #model_path = r'./runs/{}/{}.dat_15epoch_sn'.format(dataset, args.model)
    model.load_weights(model_path)
    print('model path:', model_path)
    #model.compile()
    # evaluate classification accuracy of model on clean samples
    scores_origin = model.evaluate(x_test[:clean_samples_cap], y_test[:clean_samples_cap])
    print('clean samples origin test_loss: %f, accuracy: %f' % (scores_origin[0], scores_origin[1]))
    all_scores_origin = model.evaluate(x_test, y_test)
    print('all origin test_loss: %f, accuracy: %f' % (all_scores_origin[0], all_scores_origin[1]))
    
    grad_guide = ForwardGradWrapper(model)
    classes_prediction = grad_guide.predict_classes(x_test[: clean_samples_cap])

    print('Crafting adversarial examples...')
    successful_perturbations = 0
    failed_perturbations = 0
    sub_rate_list = []
    NE_rate_list = []

    start_cpu = time.clock()
    adv_text_path = r'./fool_result/{}/{}/adv_{}_15epoch.txt'.format(dataset, argsModel, str(clean_samples_cap))
    change_tuple_path = r'./fool_result/{}/{}/change_tuple_{}_15epoch.txt'.format(dataset, argsModel, str(clean_samples_cap))
    file_1 = open(adv_text_path, "a")
    file_2 = open(change_tuple_path, "a")
    for index, text in enumerate(test_texts[: clean_samples_cap]):
        sub_rate = 0
        NE_rate = 0
        #if np.argmax(y_test[index]) == classes_prediction[index]:
        # If the ground_true label is the same as the predicted label
        adv_doc, adv_y, sub_rate, NE_rate, change_tuple_list = adversarial_paraphrase(input_text=text,
                                                                                          true_y=np.argmax(y_test[index]),
                                                                                          grad_guide=grad_guide,
                                                                                          tokenizer=tokenizer,
                                                                                          dataset=dataset,
                                                                                          level=level)
        if adv_y != np.argmax(y_test[index]):
            successful_perturbations += 1
            print('{}. Successful example crafted.'.format(index))
        else:
            failed_perturbations += 1
            print('{}. Failure.'.format(index))

        text = adv_doc
        sub_rate_list.append(sub_rate)
        NE_rate_list.append(NE_rate)
        file_2.write(str(index) + str(change_tuple_list) + '\n')
        file_1.write(text + " sub_rate: " + str(sub_rate) + "; NE_rate: " + str(NE_rate) + "\n")

    end_cpu = time.clock()
    print('CPU second:', end_cpu - start_cpu)
    mean_sub_rate = sum(sub_rate_list) / len(sub_rate_list)
    mean_NE_rate = sum(NE_rate_list) / len(NE_rate_list)
    print('mean substitution rate:', mean_sub_rate)
    print('mean NE rate:', mean_NE_rate)
    file_1.close()
    file_2.close()
    print("Failed Examples: {}".format(failed_perturbations))

# %%
# Baseline Model
fool_text_classifier(model_type="reg")
# Out:
# clean_samples_cap: 200
# Processing IMDB dataset
# Build word_cnn model...
# model path: ./fool_result/backup/word_cnn.dat_15epoch
# 200/200 [==============================] - ETA:  - 0s 848us/step
# clean samples origin test_loss: 0.453442, accuracy: 0.905000
# 25000/25000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 1s 53us/step
# all origin test_loss: 0.667997, accuracy: 0.873360
# Crafting adversarial examples...
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:86: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# use 4 substitution; use 0 NE
# Prob before:  0.9999964 . Prob after:  0.04041684 . Prob shift:  0.9595796
# 0. Successful example crafted.
# use 46 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.97520995 . Prob shift:  0.024790049
# 1. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.058819517 . Prob after:  0.005277878 . Prob shift:  0.053541638
# 2. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99999976 . Prob after:  0.46801013 . Prob shift:  0.53198963
# 3. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9909512 . Prob after:  0.02099374 . Prob shift:  0.9699575
# 4. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.0023648469 . Prob after:  1.0809337e-06 . Prob shift:  0.0023637658
# 5. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999571 . Prob after:  0.013925651 . Prob shift:  0.9860314
# 6. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99983156 . Prob after:  0.0031255735 . Prob shift:  0.996706
# 7. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99999666 . Prob after:  0.3292015 . Prob shift:  0.6707952
# 8. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.41948897 . Prob shift:  0.58051103
# 9. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999901 . Prob after:  0.21115991 . Prob shift:  0.78883016
# 10. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.48660073 . Prob after:  0.0002320397 . Prob shift:  0.4863687
# 11. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.998125 . Prob after:  0.007467875 . Prob shift:  0.99065715
# 12. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9996828 . Prob after:  0.23835747 . Prob shift:  0.7613253
# 13. Successful example crafted.
# use 33 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.14334472 . Prob shift:  0.8566553
# 14. Successful example crafted.
# use 20 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.2959882 . Prob shift:  0.7040118
# 15. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9995442 . Prob after:  0.3813511 . Prob shift:  0.6181931
# 16. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99950516 . Prob after:  0.03802711 . Prob shift:  0.96147805
# 17. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.061763503 . Prob after:  2.0280431e-05 . Prob shift:  0.061743222
# 18. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9999844 . Prob after:  0.19245958 . Prob shift:  0.8075248
# 19. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999727 . Prob after:  0.032771304 . Prob shift:  0.9672014
# 20. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9937594 . Prob after:  0.03857399 . Prob shift:  0.9551854
# 21. Successful example crafted.
# use 62 substitution; use 2 NE
# Prob before:  0.99999976 . Prob after:  0.9950787 . Prob shift:  0.0049210787
# 22. Failure.
# use 43 substitution; use 5 NE
# Prob before:  1.0 . Prob after:  0.9991708 . Prob shift:  0.0008292198
# 23. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.9996728 . Prob after:  0.02687803 . Prob shift:  0.9727948
# 24. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999913 . Prob after:  0.00014144238 . Prob shift:  0.99984986
# 25. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9909512 . Prob after:  0.02099374 . Prob shift:  0.9699575
# 26. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.022933785 . Prob shift:  0.9770662
# 27. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999782 . Prob after:  0.10907892 . Prob shift:  0.89089924
# 28. Successful example crafted.
# use 45 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  1.0 . Prob shift:  0.0
# 29. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9998172 . Prob after:  0.0013301938 . Prob shift:  0.998487
# 30. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  4.2375726e-05 . Prob after:  2.6511026e-07 . Prob shift:  4.2110616e-05
# 31. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  1.0 . Prob after:  0.14136815 . Prob shift:  0.85863185
# 32. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.9857556 . Prob after:  0.15158565 . Prob shift:  0.83417
# 33. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99997914 . Prob after:  0.09989235 . Prob shift:  0.90008676
# 34. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.14686385 . Prob shift:  0.8531362
# 35. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9952807 . Prob after:  0.12975511 . Prob shift:  0.8655256
# 36. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9983902 . Prob after:  0.17191781 . Prob shift:  0.8264724
# 37. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.35440117 . Prob after:  2.736535e-05 . Prob shift:  0.3543738
# 38. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9987544 . Prob after:  0.33673713 . Prob shift:  0.6620172
# 39. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99989116 . Prob after:  0.013459902 . Prob shift:  0.98643124
# 40. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.9999999 . Prob after:  0.07560232 . Prob shift:  0.9243976
# 41. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.029876234 . Prob after:  2.920214e-05 . Prob shift:  0.029847031
# 42. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.99999595 . Prob after:  0.16259025 . Prob shift:  0.8374057
# 43. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.855697 . Prob after:  0.012477625 . Prob shift:  0.84321934
# 44. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.3734948 . Prob shift:  0.6265052
# 45. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  3.8858743e-05 . Prob after:  7.987335e-09 . Prob shift:  3.8850754e-05
# 46. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9968881 . Prob after:  0.0056526996 . Prob shift:  0.9912354
# 47. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.99999475 . Prob after:  0.06300685 . Prob shift:  0.9369879
# 48. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.030081244 . Prob shift:  0.9699187
# 49. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.999998 . Prob after:  0.27631977 . Prob shift:  0.72367823
# 50. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99982774 . Prob after:  0.17504033 . Prob shift:  0.8247874
# 51. Successful example crafted.
# use 45 substitution; use 5 NE
# Prob before:  1.0 . Prob after:  0.28950167 . Prob shift:  0.71049833
# 52. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99998474 . Prob after:  0.1664998 . Prob shift:  0.83348495
# 53. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9998869 . Prob after:  0.33909786 . Prob shift:  0.660789
# 54. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.98476285 . Prob after:  0.08083254 . Prob shift:  0.9039303
# 55. Successful example crafted.
# use 22 substitution; use 2 NE
# Prob before:  0.9999999 . Prob after:  0.48110983 . Prob shift:  0.51889
# 56. Successful example crafted.
# use 7 substitution; use 1 NE
# Prob before:  0.99999964 . Prob after:  0.19541965 . Prob shift:  0.80458
# 57. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9999927 . Prob after:  0.052547745 . Prob shift:  0.947445
# 58. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4166689 . Prob after:  1.66257e-05 . Prob shift:  0.41665226
# 59. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9995567 . Prob after:  0.0617743 . Prob shift:  0.9377824
# 60. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.11921841 . Prob shift:  0.8807816
# 61. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.9999976 . Prob after:  0.060083974 . Prob shift:  0.93991363
# 62. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.9999956 . Prob after:  0.005499788 . Prob shift:  0.9944958
# 63. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99996066 . Prob after:  0.24749966 . Prob shift:  0.752461
# 64. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.999959 . Prob after:  0.07775301 . Prob shift:  0.922206
# 65. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.98988336 . Prob after:  0.12149762 . Prob shift:  0.86838573
# 66. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.70838016 . Prob after:  0.0275789 . Prob shift:  0.6808013
# 67. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99997365 . Prob after:  0.04990403 . Prob shift:  0.9500696
# 68. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99991405 . Prob after:  0.051844668 . Prob shift:  0.9480694
# 69. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.022854635 . Prob after:  5.10025e-05 . Prob shift:  0.022803633
# 70. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999994 . Prob after:  0.12733044 . Prob shift:  0.872669
# 71. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.9999976 . Prob shift:  2.3841858e-06
# 72. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9627323 . Prob after:  0.033945035 . Prob shift:  0.9287873
# 73. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.16995563 . Prob shift:  0.8300444
# 74. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.3469694 . Prob shift:  0.65303063
# 75. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.24764255 . Prob shift:  0.7523575
# 76. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.0002317328 . Prob after:  1.4486585e-07 . Prob shift:  0.00023158794
# 77. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999999 . Prob after:  0.23424289 . Prob shift:  0.76575696
# 78. Successful example crafted.
# use 100 substitution; use 10 NE
# Prob before:  1.0 . Prob after:  0.87437993 . Prob shift:  0.12562007
# 79. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.99999976 . Prob after:  0.20633632 . Prob shift:  0.79366344
# 80. Successful example crafted.
# use 11 substitution; use 1 NE
# Prob before:  0.9999999 . Prob after:  0.0022497592 . Prob shift:  0.9977501
# 81. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.99999964 . Prob after:  0.2716061 . Prob shift:  0.72839355
# 82. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.99999976 . Prob after:  0.15243696 . Prob shift:  0.8475628
# 83. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.9999999 . Prob after:  0.13529342 . Prob shift:  0.86470646
# 84. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.00055797794 . Prob after:  3.370594e-09 . Prob shift:  0.00055797456
# 85. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.98074657 . Prob after:  0.17582537 . Prob shift:  0.8049212
# 86. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.12908067 . Prob shift:  0.87091935
# 87. Successful example crafted.
# use 26 substitution; use 2 NE
# Prob before:  1.0 . Prob after:  0.47289246 . Prob shift:  0.52710754
# 88. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99999964 . Prob after:  0.026862448 . Prob shift:  0.9731372
# 89. Successful example crafted.
# use 22 substitution; use 3 NE
# Prob before:  0.9999255 . Prob after:  0.47224474 . Prob shift:  0.52768075
# 90. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99512225 . Prob after:  0.0002383221 . Prob shift:  0.99488395
# 91. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99969506 . Prob after:  0.05058931 . Prob shift:  0.94910574
# 92. Successful example crafted.
# use 15 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.44996393 . Prob shift:  0.5500361
# 93. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9995696 . Prob after:  0.11925694 . Prob shift:  0.8803127
# 94. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999236 . Prob after:  0.009973688 . Prob shift:  0.9899499
# 95. Successful example crafted.
# use 7 substitution; use 0 NE
# Prob before:  0.99999547 . Prob after:  0.056027897 . Prob shift:  0.9439676
# 96. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.9999982 . Prob after:  0.40289688 . Prob shift:  0.59710133
# 97. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99999976 . Prob after:  0.10103324 . Prob shift:  0.89896655
# 98. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999653 . Prob after:  0.074549265 . Prob shift:  0.92541605
# 99. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9999989 . Prob after:  0.4899218 . Prob shift:  0.5100771
# 100. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.98137456 . Prob after:  0.06894332 . Prob shift:  0.91243124
# 101. Successful example crafted.
# use 14 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.4113297 . Prob shift:  0.5886703
# 102. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.075744644 . Prob shift:  0.9242554
# 103. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999794 . Prob after:  0.3586619 . Prob shift:  0.6413175
# 104. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.1727946 . Prob after:  6.504715e-05 . Prob shift:  0.17272955
# 105. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99744666 . Prob after:  0.2624776 . Prob shift:  0.734969
# 106. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99999523 . Prob after:  0.012111397 . Prob shift:  0.9878838
# 107. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.09157496 . Prob shift:  0.90842503
# 108. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.9999995 . Prob after:  0.30313966 . Prob shift:  0.69685984
# 109. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.99999857 . Prob after:  0.18438357 . Prob shift:  0.815615
# 110. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9998647 . Prob after:  0.45665395 . Prob shift:  0.54321074
# 111. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9905563 . Prob after:  0.027235353 . Prob shift:  0.963321
# 112. Successful example crafted.
# use 82 substitution; use 7 NE
# Prob before:  1.0 . Prob after:  0.00087918853 . Prob shift:  0.99912083
# 113. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.72569895 . Prob after:  3.2473294e-05 . Prob shift:  0.72566646
# 114. Successful example crafted.
# use 49 substitution; use 8 NE
# Prob before:  1.0 . Prob after:  0.9999968 . Prob shift:  3.2186508e-06
# 115. Failure.
# use 5 substitution; use 0 NE
# Prob before:  0.99987257 . Prob after:  0.110535525 . Prob shift:  0.88933706
# 116. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.99999976 . Prob after:  0.43356103 . Prob shift:  0.56643873
# 117. Successful example crafted.
# use 65 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.31890914 . Prob shift:  0.68109083
# 118. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99364215 . Prob after:  0.004912582 . Prob shift:  0.9887296
# 119. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.16674772 . Prob shift:  0.8332523
# 120. Successful example crafted.
# use 28 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.4231567 . Prob shift:  0.57684326
# 121. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.0021594914 . Prob after:  4.451353e-06 . Prob shift:  0.0021550402
# 122. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.29303756 . Prob shift:  0.70696247
# 123. Successful example crafted.
# use 20 substitution; use 0 NE
# Prob before:  0.9999994 . Prob after:  0.42728022 . Prob shift:  0.5727192
# 124. Successful example crafted.
# use 13 substitution; use 0 NE
# Prob before:  0.9999999 . Prob after:  0.44805077 . Prob shift:  0.55194914
# 125. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.9999982 . Prob after:  0.9939594 . Prob shift:  0.006038785
# 126. Failure.
# use 56 substitution; use 5 NE
# Prob before:  1.0 . Prob after:  0.9926958 . Prob shift:  0.0073041916
# 127. Failure.
# use 4 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.31934187 . Prob shift:  0.6806581
# 128. Successful example crafted.
# use 109 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.9999988 . Prob shift:  1.1920929e-06
# 129. Failure.
# use 51 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.99999166 . Prob shift:  8.34465e-06
# 130. Failure.
# use 5 substitution; use 2 NE
# Prob before:  0.9999999 . Prob after:  0.13228819 . Prob shift:  0.86771166
# 131. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999932 . Prob after:  0.21442224 . Prob shift:  0.785571
# 132. Successful example crafted.
# use 12 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  1.0 . Prob shift:  0.0
# 133. Failure.
# use 16 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.9998306 . Prob shift:  0.0001693964
# 134. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9998615 . Prob after:  0.110020496 . Prob shift:  0.88984096
# 135. Successful example crafted.
# use 28 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.9973941 . Prob shift:  0.002605915
# 136. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.0009329204 . Prob after:  6.0772977e-06 . Prob shift:  0.0009268431
# 137. Successful example crafted.
# use 20 substitution; use 4 NE
# Prob before:  0.99967027 . Prob after:  0.43690822 . Prob shift:  0.562762
# 138. Successful example crafted.
# use 40 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.2679469 . Prob shift:  0.7320531
# 139. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.9915529 . Prob after:  0.25604707 . Prob shift:  0.7355058
# 140. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99996793 . Prob after:  0.33780852 . Prob shift:  0.66215944
# 141. Successful example crafted.
# use 8 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.33802977 . Prob shift:  0.66197026
# 142. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.99989593 . Prob after:  0.0766682 . Prob shift:  0.9232277
# 143. Successful example crafted.
# use 8 substitution; use 0 NE
# Prob before:  0.9999964 . Prob after:  0.1410418 . Prob shift:  0.8589546
# 144. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999995 . Prob after:  0.016550243 . Prob shift:  0.9834493
# 145. Successful example crafted.
# use 44 substitution; use 5 NE
# Prob before:  0.99999785 . Prob after:  0.13178968 . Prob shift:  0.86820817
# 146. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9999995 . Prob after:  0.29630435 . Prob shift:  0.7036952
# 147. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99365425 . Prob after:  0.30511633 . Prob shift:  0.68853796
# 148. Successful example crafted.
# use 7 substitution; use 2 NE
# Prob before:  0.99997723 . Prob after:  0.2052299 . Prob shift:  0.79474735
# 149. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999945 . Prob after:  0.06758469 . Prob shift:  0.9324098
# 150. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.29792646 . Prob shift:  0.7020736
# 151. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9995654 . Prob after:  0.0010410646 . Prob shift:  0.99852437
# 152. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  1.0 . Prob after:  0.0030836395 . Prob shift:  0.99691635
# 153. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9993538 . Prob after:  0.19845219 . Prob shift:  0.80090165
# 154. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.99999905 . Prob after:  0.36016342 . Prob shift:  0.6398356
# 155. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.99998593 . Prob after:  0.46041235 . Prob shift:  0.53957355
# 156. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.998757 . Prob after:  0.41380635 . Prob shift:  0.5849507
# 157. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2244078 . Prob after:  0.0026080084 . Prob shift:  0.2217998
# 158. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.00038394803 . Prob after:  0.00013189789 . Prob shift:  0.00025205014
# 159. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9997788 . Prob after:  0.14301778 . Prob shift:  0.85676104
# 160. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8669616 . Prob after:  0.00036727253 . Prob shift:  0.8665943
# 161. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99999964 . Prob after:  0.019878438 . Prob shift:  0.9801212
# 162. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9999987 . Prob after:  0.2644172 . Prob shift:  0.7355815
# 163. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.12337415 . Prob shift:  0.87662584
# 164. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.15403368 . Prob shift:  0.84596634
# 165. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999976 . Prob after:  0.1317863 . Prob shift:  0.8682113
# 166. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9995472 . Prob after:  0.034073688 . Prob shift:  0.9654735
# 167. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9993573 . Prob after:  0.13717216 . Prob shift:  0.8621851
# 168. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99262166 . Prob after:  0.072348155 . Prob shift:  0.9202735
# 169. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.9999982 . Prob after:  0.9939594 . Prob shift:  0.006038785
# 170. Failure.
# use 5 substitution; use 0 NE
# Prob before:  0.99999046 . Prob after:  0.3617059 . Prob shift:  0.63828456
# 171. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9780449 . Prob after:  0.019991703 . Prob shift:  0.95805323
# 172. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999275 . Prob after:  0.3486512 . Prob shift:  0.65127635
# 173. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9548518 . Prob after:  0.19663633 . Prob shift:  0.7582155
# 174. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9999845 . Prob after:  0.05383601 . Prob shift:  0.9461485
# 175. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9994134 . Prob after:  0.091246285 . Prob shift:  0.90816706
# 176. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  0.009958881 . Prob shift:  0.99004114
# 177. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  1.0 . Prob after:  7.2827526e-05 . Prob shift:  0.99992716
# 178. Successful example crafted.
# use 87 substitution; use 4 NE
# Prob before:  1.0 . Prob after:  0.95728606 . Prob shift:  0.04271394
# 179. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9999974 . Prob after:  0.007955832 . Prob shift:  0.9920415
# 180. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.031773474 . Prob after:  3.6063312e-07 . Prob shift:  0.031773113
# 181. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99998593 . Prob after:  0.48570377 . Prob shift:  0.51428217
# 182. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.972854 . Prob after:  0.17233358 . Prob shift:  0.8005204
# 183. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  1.0 . Prob after:  0.19311053 . Prob shift:  0.8068895
# 184. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999999 . Prob after:  0.34889546 . Prob shift:  0.65110445
# 185. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999963 . Prob after:  0.09752981 . Prob shift:  0.9024665
# 186. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9999987 . Prob after:  0.29898438 . Prob shift:  0.7010143
# 187. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999939 . Prob after:  0.10216759 . Prob shift:  0.8978263
# 188. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999908 . Prob after:  0.47811466 . Prob shift:  0.52187616
# 189. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9999757 . Prob after:  0.097802706 . Prob shift:  0.902173
# 190. Successful example crafted.
# use 8 substitution; use 1 NE
# Prob before:  0.9999999 . Prob after:  0.06369018 . Prob shift:  0.9363097
# 191. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.99999857 . Prob after:  0.287305 . Prob shift:  0.7126936
# 192. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99999547 . Prob after:  0.4924428 . Prob shift:  0.5075527
# 193. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.99505854 . Prob after:  0.017706724 . Prob shift:  0.9773518
# 194. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.99651897 . Prob after:  0.1306283 . Prob shift:  0.8658907
# 195. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  0.9999999 . Prob after:  0.084682204 . Prob shift:  0.91531765
# 196. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.018279616 . Prob after:  0.0002773709 . Prob shift:  0.018002246
# 197. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9999937 . Prob after:  0.17240314 . Prob shift:  0.8275905
# 198. Successful example crafted.
# use 8 substitution; use 1 NE
# Prob before:  0.9999999 . Prob after:  0.44389883 . Prob shift:  0.5561011
# 199. Successful example crafted.
# CPU second: 92399.75689099998
# mean substitution rate: 0.05094020204770626
# mean NE rate: 0.08156605539017006
# Failed Examples: 16
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:115: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
# Baseline Model + SN
fool_text_classifier(model_type="sn")
# Out:
# clean_samples_cap: 200
# Processing IMDB dataset
# Build word_cnn model...
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# model path: ./fool_result/backup/word_cnn.dat_15epoch_sn
# 200/200 [==============================] - ETA:  - 2s 9ms/step
# clean samples origin test_loss: 0.289439, accuracy: 0.895000
# 25000/25000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 81us/step
# all origin test_loss: 0.343144, accuracy: 0.851240
# Crafting adversarial examples...
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:82: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# use 7 substitution; use 1 NE
# Prob before:  0.9227084 . Prob after:  0.46576768 . Prob shift:  0.4569407
# 0. Successful example crafted.
# use 7 substitution; use 2 NE
# Prob before:  0.9670988 . Prob after:  0.48654208 . Prob shift:  0.4805567
# 1. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.070512734 . Prob after:  0.048530526 . Prob shift:  0.021982208
# 2. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.76436305 . Prob after:  0.482183 . Prob shift:  0.28218004
# 3. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.96956944 . Prob after:  0.37088782 . Prob shift:  0.5986816
# 4. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.54016936 . Prob after:  0.18408923 . Prob shift:  0.3560801
# 5. Successful example crafted.
# use 8 substitution; use 1 NE
# Prob before:  0.9214516 . Prob after:  0.41671044 . Prob shift:  0.5047412
# 6. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  0.9636881 . Prob after:  0.47790727 . Prob shift:  0.4857808
# 7. Successful example crafted.
# use 21 substitution; use 4 NE
# Prob before:  0.96646625 . Prob after:  0.41099384 . Prob shift:  0.5554724
# 8. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5578096 . Prob after:  0.18911867 . Prob shift:  0.3686909
# 9. Successful example crafted.
# use 98 substitution; use 1 NE
# Prob before:  0.9595028 . Prob after:  0.8326561 . Prob shift:  0.12684673
# 10. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5903906 . Prob after:  0.20993498 . Prob shift:  0.38045564
# 11. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.80877846 . Prob after:  0.3504076 . Prob shift:  0.45837086
# 12. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.75068575 . Prob after:  0.41698444 . Prob shift:  0.3337013
# 13. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.97082525 . Prob after:  0.38562045 . Prob shift:  0.58520484
# 14. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.966689 . Prob after:  0.34638265 . Prob shift:  0.6203064
# 15. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.29531655 . Prob after:  0.10148809 . Prob shift:  0.19382846
# 16. Successful example crafted.
# use 62 substitution; use 5 NE
# Prob before:  0.9763692 . Prob after:  0.7077666 . Prob shift:  0.2686026
# 17. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.3057071 . Prob after:  0.1281411 . Prob shift:  0.17756599
# 18. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.8293048 . Prob after:  0.47425085 . Prob shift:  0.35505396
# 19. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7592026 . Prob after:  0.49854013 . Prob shift:  0.26066247
# 20. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.7920678 . Prob after:  0.48121217 . Prob shift:  0.31085566
# 21. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5708585 . Prob after:  0.30513048 . Prob shift:  0.265728
# 22. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.9057234 . Prob after:  0.47921517 . Prob shift:  0.42650822
# 23. Successful example crafted.
# use 2 substitution; use 2 NE
# Prob before:  0.94814223 . Prob after:  0.39246807 . Prob shift:  0.5556742
# 24. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8037298 . Prob after:  0.280111 . Prob shift:  0.52361876
# 25. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.96956944 . Prob after:  0.3708878 . Prob shift:  0.5986817
# 26. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.7998038 . Prob after:  0.44579357 . Prob shift:  0.35401022
# 27. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.95054716 . Prob after:  0.3941255 . Prob shift:  0.55642164
# 28. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.9466331 . Prob after:  0.48778605 . Prob shift:  0.45884705
# 29. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.55104786 . Prob after:  0.26713392 . Prob shift:  0.28391394
# 30. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.8556902 . Prob after:  0.4972761 . Prob shift:  0.35841408
# 31. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.8232861 . Prob after:  0.36573353 . Prob shift:  0.45755258
# 32. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.87812173 . Prob after:  0.3958535 . Prob shift:  0.48226824
# 33. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5093686 . Prob after:  0.1814603 . Prob shift:  0.32790828
# 34. Successful example crafted.
# use 73 substitution; use 6 NE
# Prob before:  0.9861688 . Prob after:  0.37501377 . Prob shift:  0.61115503
# 35. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.9611735 . Prob after:  0.37639144 . Prob shift:  0.584782
# 36. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.7851242 . Prob after:  0.27375636 . Prob shift:  0.5113678
# 37. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.84360385 . Prob after:  0.4081314 . Prob shift:  0.43547246
# 38. Successful example crafted.
# use 185 substitution; use 41 NE
# Prob before:  0.94339705 . Prob after:  0.7250212 . Prob shift:  0.21837586
# 39. Failure.
# use 13 substitution; use 3 NE
# Prob before:  0.94398355 . Prob after:  0.39613143 . Prob shift:  0.54785216
# 40. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9302832 . Prob after:  0.26660338 . Prob shift:  0.66367984
# 41. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9227036 . Prob after:  0.31839517 . Prob shift:  0.6043085
# 42. Successful example crafted.
# use 63 substitution; use 4 NE
# Prob before:  0.9775569 . Prob after:  0.9203743 . Prob shift:  0.05718261
# 43. Failure.
# use 68 substitution; use 3 NE
# Prob before:  0.9256686 . Prob after:  0.77376586 . Prob shift:  0.15190274
# 44. Failure.
# use 16 substitution; use 2 NE
# Prob before:  0.912291 . Prob after:  0.40303215 . Prob shift:  0.50925887
# 45. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.19930969 . Prob after:  0.16795541 . Prob shift:  0.03135428
# 46. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8198197 . Prob after:  0.2939238 . Prob shift:  0.5258959
# 47. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.7255818 . Prob after:  0.4916361 . Prob shift:  0.23394573
# 48. Successful example crafted.
# use 5 substitution; use 2 NE
# Prob before:  0.99177986 . Prob after:  0.39654008 . Prob shift:  0.59523976
# 49. Successful example crafted.
# use 12 substitution; use 0 NE
# Prob before:  0.9626833 . Prob after:  0.4864668 . Prob shift:  0.47621652
# 50. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.44242415 . Prob after:  0.34012777 . Prob shift:  0.10229638
# 51. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8938005 . Prob after:  0.47993636 . Prob shift:  0.41386414
# 52. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.26230142 . Prob after:  0.09457428 . Prob shift:  0.16772714
# 53. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.613192 . Prob after:  0.43815348 . Prob shift:  0.17503855
# 54. Successful example crafted.
# use 16 substitution; use 0 NE
# Prob before:  0.7091609 . Prob after:  0.5828732 . Prob shift:  0.1262877
# 55. Failure.
# use 52 substitution; use 5 NE
# Prob before:  0.9629909 . Prob after:  0.4414921 . Prob shift:  0.5214988
# 56. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8663921 . Prob after:  0.4431325 . Prob shift:  0.4232596
# 57. Successful example crafted.
# use 6 substitution; use 4 NE
# Prob before:  0.96499556 . Prob after:  0.49161097 . Prob shift:  0.4733846
# 58. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.69838804 . Prob after:  0.23818903 . Prob shift:  0.460199
# 59. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8966541 . Prob after:  0.46568525 . Prob shift:  0.43096888
# 60. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.94778657 . Prob after:  0.46029925 . Prob shift:  0.48748732
# 61. Successful example crafted.
# use 24 substitution; use 5 NE
# Prob before:  0.94886094 . Prob after:  0.49458483 . Prob shift:  0.4542761
# 62. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.8885094 . Prob after:  0.38147613 . Prob shift:  0.5070332
# 63. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7894907 . Prob after:  0.4901145 . Prob shift:  0.2993762
# 64. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6841896 . Prob after:  0.3780069 . Prob shift:  0.3061827
# 65. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8014423 . Prob after:  0.43917602 . Prob shift:  0.3622663
# 66. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.23866446 . Prob after:  0.16077846 . Prob shift:  0.077886
# 67. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7228187 . Prob after:  0.28445876 . Prob shift:  0.43835992
# 68. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.83478016 . Prob after:  0.3982425 . Prob shift:  0.43653765
# 69. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2881773 . Prob after:  0.15828843 . Prob shift:  0.12988888
# 70. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.915023 . Prob after:  0.4619698 . Prob shift:  0.45305324
# 71. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  0.9799167 . Prob after:  0.93871826 . Prob shift:  0.041198432
# 72. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.57907754 . Prob after:  0.2815067 . Prob shift:  0.29757085
# 73. Successful example crafted.
# use 10 substitution; use 1 NE
# Prob before:  0.97620517 . Prob after:  0.4605537 . Prob shift:  0.51565146
# 74. Successful example crafted.
# use 25 substitution; use 1 NE
# Prob before:  0.9806013 . Prob after:  0.6718317 . Prob shift:  0.30876958
# 75. Failure.
# use 51 substitution; use 2 NE
# Prob before:  0.9839288 . Prob after:  0.90173084 . Prob shift:  0.082197964
# 76. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.1106301 . Prob after:  0.07753198 . Prob shift:  0.033098124
# 77. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.81503195 . Prob after:  0.29334146 . Prob shift:  0.5216905
# 78. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.9056291 . Prob after:  0.48200285 . Prob shift:  0.42362624
# 79. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  0.9503043 . Prob after:  0.4405914 . Prob shift:  0.50971293
# 80. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.87095314 . Prob after:  0.40140033 . Prob shift:  0.46955281
# 81. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.867044 . Prob after:  0.48618925 . Prob shift:  0.38085473
# 82. Successful example crafted.
# use 18 substitution; use 3 NE
# Prob before:  0.87469834 . Prob after:  0.45755148 . Prob shift:  0.41714686
# 83. Successful example crafted.
# use 122 substitution; use 8 NE
# Prob before:  0.6982153 . Prob after:  0.8516405 . Prob shift:  -0.15342522
# 84. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.07124839 . Prob after:  0.045491043 . Prob shift:  0.025757346
# 85. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.39152348 . Prob after:  0.11513386 . Prob shift:  0.27638963
# 86. Successful example crafted.
# use 33 substitution; use 3 NE
# Prob before:  0.97452635 . Prob after:  0.32505676 . Prob shift:  0.6494696
# 87. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.98730683 . Prob after:  0.4726624 . Prob shift:  0.51464444
# 88. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7295624 . Prob after:  0.3121244 . Prob shift:  0.417438
# 89. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.87752974 . Prob after:  0.48650122 . Prob shift:  0.39102852
# 90. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8465278 . Prob after:  0.49238595 . Prob shift:  0.35414186
# 91. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.6035022 . Prob after:  0.25870118 . Prob shift:  0.34480104
# 92. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.9158332 . Prob after:  0.4724771 . Prob shift:  0.44335607
# 93. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7213295 . Prob after:  0.26377857 . Prob shift:  0.45755094
# 94. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.57991296 . Prob after:  0.16531295 . Prob shift:  0.4146
# 95. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.93269444 . Prob after:  0.47514415 . Prob shift:  0.4575503
# 96. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.9775933 . Prob after:  0.41939735 . Prob shift:  0.55819595
# 97. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9529219 . Prob after:  0.46961653 . Prob shift:  0.4833054
# 98. Successful example crafted.
# use 65 substitution; use 3 NE
# Prob before:  0.88100904 . Prob after:  0.65899515 . Prob shift:  0.22201389
# 99. Failure.
# use 74 substitution; use 8 NE
# Prob before:  0.9703307 . Prob after:  0.40074694 . Prob shift:  0.5695838
# 100. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.93260276 . Prob after:  0.47938064 . Prob shift:  0.45322213
# 101. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9570063 . Prob after:  0.48387155 . Prob shift:  0.47313473
# 102. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9712352 . Prob after:  0.45561022 . Prob shift:  0.515625
# 103. Successful example crafted.
# use 86 substitution; use 3 NE
# Prob before:  0.9634748 . Prob after:  0.3949171 . Prob shift:  0.56855774
# 104. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.8685083 . Prob after:  0.38416857 . Prob shift:  0.4843397
# 105. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.5365658 . Prob after:  0.17760593 . Prob shift:  0.35895985
# 106. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.9396725 . Prob after:  0.28247407 . Prob shift:  0.6571984
# 107. Successful example crafted.
# use 30 substitution; use 2 NE
# Prob before:  0.8907762 . Prob after:  0.4535896 . Prob shift:  0.43718663
# 108. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9621206 . Prob after:  0.4990101 . Prob shift:  0.4631105
# 109. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9016183 . Prob after:  0.3695471 . Prob shift:  0.53207123
# 110. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7397513 . Prob after:  0.3469803 . Prob shift:  0.39277098
# 111. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6290995 . Prob after:  0.22514054 . Prob shift:  0.40395895
# 112. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.9746756 . Prob after:  0.25743294 . Prob shift:  0.71724266
# 113. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6238801 . Prob after:  0.4155299 . Prob shift:  0.20835018
# 114. Successful example crafted.
# use 49 substitution; use 8 NE
# Prob before:  0.9453579 . Prob after:  0.747255 . Prob shift:  0.19810289
# 115. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.75495785 . Prob after:  0.33037576 . Prob shift:  0.4245821
# 116. Successful example crafted.
# use 138 substitution; use 5 NE
# Prob before:  0.9561016 . Prob after:  0.57642454 . Prob shift:  0.37967706
# 117. Failure.
# use 3 substitution; use 1 NE
# Prob before:  0.95739084 . Prob after:  0.39330763 . Prob shift:  0.5640832
# 118. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.28266928 . Prob after:  0.19271505 . Prob shift:  0.08995423
# 119. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.9681542 . Prob after:  0.4842025 . Prob shift:  0.4839517
# 120. Successful example crafted.
# use 16 substitution; use 1 NE
# Prob before:  0.83285797 . Prob after:  0.44491267 . Prob shift:  0.3879453
# 121. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.26912642 . Prob after:  0.22094215 . Prob shift:  0.04818426
# 122. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.97595406 . Prob after:  0.4894858 . Prob shift:  0.48646826
# 123. Successful example crafted.
# use 33 substitution; use 5 NE
# Prob before:  0.95669055 . Prob after:  0.49826536 . Prob shift:  0.4584252
# 124. Successful example crafted.
# use 29 substitution; use 5 NE
# Prob before:  0.92827433 . Prob after:  0.48709258 . Prob shift:  0.44118175
# 125. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.9222174 . Prob after:  0.7643663 . Prob shift:  0.1578511
# 126. Failure.
# use 4 substitution; use 0 NE
# Prob before:  0.98201513 . Prob after:  0.4490803 . Prob shift:  0.53293484
# 127. Successful example crafted.
# use 6 substitution; use 2 NE
# Prob before:  0.98625284 . Prob after:  0.49752313 . Prob shift:  0.48872972
# 128. Successful example crafted.
# use 109 substitution; use 4 NE
# Prob before:  0.990763 . Prob after:  0.93028915 . Prob shift:  0.06047386
# 129. Failure.
# use 51 substitution; use 1 NE
# Prob before:  0.9503862 . Prob after:  0.53360605 . Prob shift:  0.41678017
# 130. Failure.
# use 3 substitution; use 2 NE
# Prob before:  0.96209705 . Prob after:  0.35536578 . Prob shift:  0.6067313
# 131. Successful example crafted.
# use 22 substitution; use 0 NE
# Prob before:  0.9880294 . Prob after:  0.84119064 . Prob shift:  0.14683878
# 132. Failure.
# use 12 substitution; use 0 NE
# Prob before:  0.9569006 . Prob after:  0.8709027 . Prob shift:  0.08599788
# 133. Failure.
# use 16 substitution; use 1 NE
# Prob before:  0.8609963 . Prob after:  0.5675418 . Prob shift:  0.29345453
# 134. Failure.
# use 13 substitution; use 1 NE
# Prob before:  0.90163034 . Prob after:  0.47481018 . Prob shift:  0.42682016
# 135. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.93894 . Prob after:  0.48688173 . Prob shift:  0.45205826
# 136. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.48926654 . Prob after:  0.28390685 . Prob shift:  0.2053597
# 137. Successful example crafted.
# use 2 substitution; use 2 NE
# Prob before:  0.937587 . Prob after:  0.3546711 . Prob shift:  0.5829159
# 138. Successful example crafted.
# use 7 substitution; use 0 NE
# Prob before:  0.9629502 . Prob after:  0.36681962 . Prob shift:  0.5961306
# 139. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  0.9112068 . Prob after:  0.4872789 . Prob shift:  0.42392787
# 140. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.9203527 . Prob after:  0.4188717 . Prob shift:  0.501481
# 141. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.92742085 . Prob after:  0.49122694 . Prob shift:  0.4361939
# 142. Successful example crafted.
# use 15 substitution; use 2 NE
# Prob before:  0.96287096 . Prob after:  0.94403946 . Prob shift:  0.018831491
# 143. Failure.
# use 75 substitution; use 2 NE
# Prob before:  0.9468964 . Prob after:  0.6782513 . Prob shift:  0.26864505
# 144. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.61145514 . Prob after:  0.44625184 . Prob shift:  0.1652033
# 145. Successful example crafted.
# use 44 substitution; use 5 NE
# Prob before:  0.9828378 . Prob after:  0.7340167 . Prob shift:  0.24882108
# 146. Failure.
# use 88 substitution; use 1 NE
# Prob before:  0.9514125 . Prob after:  0.640491 . Prob shift:  0.3109215
# 147. Failure.
# use 38 substitution; use 2 NE
# Prob before:  0.9250682 . Prob after:  0.82457644 . Prob shift:  0.10049176
# 148. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.8976892 . Prob after:  0.45932162 . Prob shift:  0.4383676
# 149. Successful example crafted.
# use 14 substitution; use 0 NE
# Prob before:  0.909279 . Prob after:  0.39041558 . Prob shift:  0.51886344
# 150. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.8979761 . Prob after:  0.3116058 . Prob shift:  0.5863703
# 151. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6350527 . Prob after:  0.31240237 . Prob shift:  0.3226503
# 152. Successful example crafted.
# use 2 substitution; use 2 NE
# Prob before:  0.9295416 . Prob after:  0.3142052 . Prob shift:  0.6153364
# 153. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.17188649 . Prob after:  0.076061204 . Prob shift:  0.095825285
# 154. Successful example crafted.
# use 8 substitution; use 1 NE
# Prob before:  0.9545353 . Prob after:  0.47593784 . Prob shift:  0.47859746
# 155. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9531872 . Prob after:  0.49751168 . Prob shift:  0.45567554
# 156. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.49559528 . Prob after:  0.17087635 . Prob shift:  0.32471892
# 157. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.33193403 . Prob after:  0.1748728 . Prob shift:  0.15706123
# 158. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.07157303 . Prob after:  0.030767208 . Prob shift:  0.040805817
# 159. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8146459 . Prob after:  0.45789674 . Prob shift:  0.35674915
# 160. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.8789986 . Prob after:  0.33425644 . Prob shift:  0.5447421
# 161. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.80910116 . Prob after:  0.36146656 . Prob shift:  0.4476346
# 162. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6368777 . Prob after:  0.35658047 . Prob shift:  0.28029725
# 163. Successful example crafted.
# use 9 substitution; use 0 NE
# Prob before:  0.9771161 . Prob after:  0.4871251 . Prob shift:  0.489991
# 164. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.9552175 . Prob after:  0.47188228 . Prob shift:  0.4833352
# 165. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.96224827 . Prob after:  0.46993077 . Prob shift:  0.4923175
# 166. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.822061 . Prob after:  0.44480595 . Prob shift:  0.37725505
# 167. Successful example crafted.
# use 119 substitution; use 8 NE
# Prob before:  0.8620821 . Prob after:  0.48405972 . Prob shift:  0.3780224
# 168. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5765981 . Prob after:  0.18858892 . Prob shift:  0.3880092
# 169. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.9222174 . Prob after:  0.76436627 . Prob shift:  0.15785116
# 170. Failure.
# use 3 substitution; use 1 NE
# Prob before:  0.856751 . Prob after:  0.39471754 . Prob shift:  0.46203348
# 171. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.43240416 . Prob after:  0.3465001 . Prob shift:  0.08590406
# 172. Successful example crafted.
# use 49 substitution; use 0 NE
# Prob before:  0.9762089 . Prob after:  0.78970057 . Prob shift:  0.18650836
# 173. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5931213 . Prob after:  0.41907728 . Prob shift:  0.17404401
# 174. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.93951064 . Prob after:  0.44928148 . Prob shift:  0.49022916
# 175. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.42972356 . Prob after:  0.2293381 . Prob shift:  0.20038547
# 176. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9306345 . Prob after:  0.27753162 . Prob shift:  0.6531029
# 177. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  0.97622925 . Prob after:  0.4097114 . Prob shift:  0.56651783
# 178. Successful example crafted.
# use 87 substitution; use 4 NE
# Prob before:  0.9786038 . Prob after:  0.5988622 . Prob shift:  0.3797416
# 179. Failure.
# use 5 substitution; use 0 NE
# Prob before:  0.9681825 . Prob after:  0.44858798 . Prob shift:  0.51959455
# 180. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.63224244 . Prob after:  0.14387967 . Prob shift:  0.4883628
# 181. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.75984156 . Prob after:  0.49760777 . Prob shift:  0.2622338
# 182. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6013509 . Prob after:  0.1973607 . Prob shift:  0.4039902
# 183. Successful example crafted.
# use 7 substitution; use 1 NE
# Prob before:  0.9300036 . Prob after:  0.4911455 . Prob shift:  0.4388581
# 184. Successful example crafted.
# use 15 substitution; use 3 NE
# Prob before:  0.9615921 . Prob after:  0.44918475 . Prob shift:  0.5124073
# 185. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.377988 . Prob after:  0.18235715 . Prob shift:  0.19563086
# 186. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.60864323 . Prob after:  0.323722 . Prob shift:  0.28492123
# 187. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7394611 . Prob after:  0.43486995 . Prob shift:  0.30459118
# 188. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.90626234 . Prob after:  0.46926945 . Prob shift:  0.43699288
# 189. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.68291986 . Prob after:  0.4546326 . Prob shift:  0.22828725
# 190. Successful example crafted.
# use 9 substitution; use 2 NE
# Prob before:  0.9870323 . Prob after:  0.4902973 . Prob shift:  0.496735
# 191. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7342141 . Prob after:  0.3195076 . Prob shift:  0.41470653
# 192. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8231231 . Prob after:  0.48976037 . Prob shift:  0.33336273
# 193. Successful example crafted.
# use 130 substitution; use 10 NE
# Prob before:  0.8088303 . Prob after:  0.7424356 . Prob shift:  0.06639475
# 194. Failure.
# use 160 substitution; use 21 NE
# Prob before:  0.96077883 . Prob after:  0.5451491 . Prob shift:  0.41562974
# 195. Failure.
# use 5 substitution; use 0 NE
# Prob before:  0.9436719 . Prob after:  0.4940163 . Prob shift:  0.4496556
# 196. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.7951533 . Prob after:  0.3554254 . Prob shift:  0.43972793
# 197. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8278244 . Prob after:  0.32165572 . Prob shift:  0.5061687
# 198. Successful example crafted.
# use 20 substitution; use 3 NE
# Prob before:  0.8911094 . Prob after:  0.72583485 . Prob shift:  0.16527456
# 199. Failure.
# CPU second: 95159.041415
# mean substitution rate: 0.06926702752707424
# mean NE rate: 0.16126091472231746
# Failed Examples: 30
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:111: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
# SN + Binary
fool_text_classifier(model_type="sn", binary=True)
# Out:
# clean_samples_cap: 200
# Processing IMDB dataset
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# model path: ./runs/imdb/word_cnn.dat_15epoch_best_binary_sn
# 200/200 [==============================] - ETA: 10 - 2s 10ms/step
# clean samples origin test_loss: 0.265406, accuracy: 0.890000
# 25000/25000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 83us/step
# all origin test_loss: 0.352449, accuracy: 0.848260
# Crafting adversarial examples...
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# use 52 substitution; use 7 NE
# Prob before:  0.935804 . Prob after:  0.6719888 . Prob shift:  0.26381522
# 0. Failure.
# use 46 substitution; use 4 NE
# Prob before:  0.9626144 . Prob after:  0.50941503 . Prob shift:  0.4531994
# 1. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.23716903 . Prob after:  0.17429106 . Prob shift:  0.06287797
# 2. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8871709 . Prob after:  0.49673215 . Prob shift:  0.39043877
# 3. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.9447567 . Prob after:  0.32600117 . Prob shift:  0.6187555
# 4. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6359266 . Prob after:  0.2577547 . Prob shift:  0.3781719
# 5. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9208375 . Prob after:  0.4088749 . Prob shift:  0.51196265
# 6. Successful example crafted.
# use 41 substitution; use 4 NE
# Prob before:  0.9645822 . Prob after:  0.5739314 . Prob shift:  0.3906508
# 7. Failure.
# use 53 substitution; use 4 NE
# Prob before:  0.96924186 . Prob after:  0.47176933 . Prob shift:  0.49747252
# 8. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8060362 . Prob after:  0.19172774 . Prob shift:  0.6143084
# 9. Successful example crafted.
# use 98 substitution; use 1 NE
# Prob before:  0.9027763 . Prob after:  0.8587091 . Prob shift:  0.044067204
# 10. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5387008 . Prob after:  0.34358025 . Prob shift:  0.19512057
# 11. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.82007504 . Prob after:  0.3309841 . Prob shift:  0.48909095
# 12. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.83181053 . Prob after:  0.48270902 . Prob shift:  0.3491015
# 13. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.96785516 . Prob after:  0.22917034 . Prob shift:  0.73868483
# 14. Successful example crafted.
# use 72 substitution; use 8 NE
# Prob before:  0.97198796 . Prob after:  0.5267783 . Prob shift:  0.44520968
# 15. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.26541746 . Prob after:  0.114939466 . Prob shift:  0.15047799
# 16. Successful example crafted.
# use 62 substitution; use 5 NE
# Prob before:  0.9653959 . Prob after:  0.5100385 . Prob shift:  0.45535743
# 17. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.55570155 . Prob after:  0.20254794 . Prob shift:  0.35315362
# 18. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8585756 . Prob after:  0.46715063 . Prob shift:  0.39142495
# 19. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.638916 . Prob after:  0.41497672 . Prob shift:  0.2239393
# 20. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.68946344 . Prob after:  0.46937117 . Prob shift:  0.22009227
# 21. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8398751 . Prob after:  0.48656493 . Prob shift:  0.35331017
# 22. Successful example crafted.
# use 43 substitution; use 5 NE
# Prob before:  0.8777227 . Prob after:  0.6289596 . Prob shift:  0.24876308
# 23. Failure.
# use 3 substitution; use 1 NE
# Prob before:  0.9740592 . Prob after:  0.33024868 . Prob shift:  0.6438105
# 24. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8407512 . Prob after:  0.4995583 . Prob shift:  0.34119287
# 25. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.9447567 . Prob after:  0.32600117 . Prob shift:  0.6187555
# 26. Successful example crafted.
# use 7 substitution; use 2 NE
# Prob before:  0.94674057 . Prob after:  0.43809423 . Prob shift:  0.50864637
# 27. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.95382214 . Prob after:  0.39698464 . Prob shift:  0.5568375
# 28. Successful example crafted.
# use 45 substitution; use 0 NE
# Prob before:  0.953063 . Prob after:  0.59325796 . Prob shift:  0.35980505
# 29. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.7267043 . Prob after:  0.39339614 . Prob shift:  0.33330816
# 30. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.80844826 . Prob after:  0.437338 . Prob shift:  0.37111026
# 31. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8253256 . Prob after:  0.48561147 . Prob shift:  0.33971414
# 32. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8270598 . Prob after:  0.4876779 . Prob shift:  0.3393819
# 33. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7424104 . Prob after:  0.27180883 . Prob shift:  0.4706016
# 34. Successful example crafted.
# use 79 substitution; use 6 NE
# Prob before:  0.9738608 . Prob after:  0.61305976 . Prob shift:  0.36080104
# 35. Failure.
# use 19 substitution; use 3 NE
# Prob before:  0.9244072 . Prob after:  0.456298 . Prob shift:  0.4681092
# 36. Successful example crafted.
# use 65 substitution; use 0 NE
# Prob before:  0.94806576 . Prob after:  0.61138934 . Prob shift:  0.33667642
# 37. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.8019223 . Prob after:  0.43170884 . Prob shift:  0.37021348
# 38. Successful example crafted.
# use 185 substitution; use 41 NE
# Prob before:  0.8137281 . Prob after:  0.55405277 . Prob shift:  0.25967532
# 39. Failure.
# use 12 substitution; use 3 NE
# Prob before:  0.95274293 . Prob after:  0.39163768 . Prob shift:  0.56110525
# 40. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9433967 . Prob after:  0.35041943 . Prob shift:  0.5929773
# 41. Successful example crafted.
# use 5 substitution; use 2 NE
# Prob before:  0.881796 . Prob after:  0.27913332 . Prob shift:  0.6026627
# 42. Successful example crafted.
# use 63 substitution; use 4 NE
# Prob before:  0.9654565 . Prob after:  0.89862627 . Prob shift:  0.06683022
# 43. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.622384 . Prob after:  0.48814616 . Prob shift:  0.13423786
# 44. Successful example crafted.
# use 7 substitution; use 0 NE
# Prob before:  0.89626724 . Prob after:  0.44843894 . Prob shift:  0.4478283
# 45. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.29162678 . Prob after:  0.18164924 . Prob shift:  0.10997754
# 46. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8334627 . Prob after:  0.45454115 . Prob shift:  0.37892157
# 47. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.71354145 . Prob after:  0.4158073 . Prob shift:  0.29773414
# 48. Successful example crafted.
# use 11 substitution; use 1 NE
# Prob before:  0.9676091 . Prob after:  0.49381644 . Prob shift:  0.47379267
# 49. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9503141 . Prob after:  0.43511355 . Prob shift:  0.51520056
# 50. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.54467666 . Prob after:  0.31334382 . Prob shift:  0.23133284
# 51. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7793369 . Prob after:  0.26474658 . Prob shift:  0.5145904
# 52. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.44475654 . Prob after:  0.22194645 . Prob shift:  0.22281009
# 53. Successful example crafted.
# use 23 substitution; use 5 NE
# Prob before:  0.9403162 . Prob after:  0.4823138 . Prob shift:  0.4580024
# 54. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.6735947 . Prob after:  0.49133503 . Prob shift:  0.18225968
# 55. Successful example crafted.
# use 54 substitution; use 5 NE
# Prob before:  0.89322114 . Prob after:  0.5473579 . Prob shift:  0.34586322
# 56. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.94335425 . Prob after:  0.48050097 . Prob shift:  0.46285328
# 57. Successful example crafted.
# use 22 substitution; use 5 NE
# Prob before:  0.85597867 . Prob after:  0.36879873 . Prob shift:  0.48717993
# 58. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4174216 . Prob after:  0.26959535 . Prob shift:  0.14782625
# 59. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.92800903 . Prob after:  0.35346684 . Prob shift:  0.57454216
# 60. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8668111 . Prob after:  0.48185855 . Prob shift:  0.38495255
# 61. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.927499 . Prob after:  0.43621442 . Prob shift:  0.49128458
# 62. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.9174651 . Prob after:  0.46507096 . Prob shift:  0.45239413
# 63. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8108227 . Prob after:  0.34713897 . Prob shift:  0.46368375
# 64. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7614219 . Prob after:  0.4943307 . Prob shift:  0.2670912
# 65. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.8934369 . Prob after:  0.48003715 . Prob shift:  0.41339976
# 66. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.23163524 . Prob after:  0.2286105 . Prob shift:  0.003024742
# 67. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.78428227 . Prob after:  0.4085055 . Prob shift:  0.37577677
# 68. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9187582 . Prob after:  0.3894385 . Prob shift:  0.5293197
# 69. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6974999 . Prob after:  0.4559739 . Prob shift:  0.24152598
# 70. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9348803 . Prob after:  0.4441709 . Prob shift:  0.49070942
# 71. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  0.95190686 . Prob after:  0.83736646 . Prob shift:  0.1145404
# 72. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.614251 . Prob after:  0.322832 . Prob shift:  0.29141903
# 73. Successful example crafted.
# use 10 substitution; use 1 NE
# Prob before:  0.96577317 . Prob after:  0.41425908 . Prob shift:  0.5515141
# 74. Successful example crafted.
# use 25 substitution; use 1 NE
# Prob before:  0.9853007 . Prob after:  0.8422701 . Prob shift:  0.14303064
# 75. Failure.
# use 51 substitution; use 2 NE
# Prob before:  0.9860299 . Prob after:  0.9333448 . Prob shift:  0.05268514
# 76. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.10977673 . Prob after:  0.07096019 . Prob shift:  0.03881654
# 77. Successful example crafted.
# use 58 substitution; use 0 NE
# Prob before:  0.9294447 . Prob after:  0.7728745 . Prob shift:  0.1565702
# 78. Failure.
# use 100 substitution; use 10 NE
# Prob before:  0.8974523 . Prob after:  0.5871745 . Prob shift:  0.31027782
# 79. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.87220365 . Prob after:  0.47799748 . Prob shift:  0.39420617
# 80. Successful example crafted.
# use 8 substitution; use 0 NE
# Prob before:  0.91694397 . Prob after:  0.48776093 . Prob shift:  0.42918304
# 81. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.8936928 . Prob after:  0.4568263 . Prob shift:  0.4368665
# 82. Successful example crafted.
# use 142 substitution; use 17 NE
# Prob before:  0.95206773 . Prob after:  0.49607012 . Prob shift:  0.45599762
# 83. Successful example crafted.
# use 122 substitution; use 8 NE
# Prob before:  0.95690674 . Prob after:  0.6801997 . Prob shift:  0.27670705
# 84. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.08196325 . Prob after:  0.07603877 . Prob shift:  0.005924478
# 85. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.57947373 . Prob after:  0.29422563 . Prob shift:  0.2852481
# 86. Successful example crafted.
# use 10 substitution; use 1 NE
# Prob before:  0.96179736 . Prob after:  0.35088235 . Prob shift:  0.610915
# 87. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.98194695 . Prob after:  0.36013132 . Prob shift:  0.6218156
# 88. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.81681764 . Prob after:  0.4231939 . Prob shift:  0.39362374
# 89. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  0.93281704 . Prob after:  0.39880788 . Prob shift:  0.53400916
# 90. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5789417 . Prob after:  0.484183 . Prob shift:  0.09475869
# 91. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.43668577 . Prob after:  0.16127853 . Prob shift:  0.27540725
# 92. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.9268948 . Prob after:  0.44760934 . Prob shift:  0.47928545
# 93. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.736531 . Prob after:  0.4800604 . Prob shift:  0.25647062
# 94. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.42774254 . Prob after:  0.16935408 . Prob shift:  0.25838846
# 95. Successful example crafted.
# use 69 substitution; use 1 NE
# Prob before:  0.9381783 . Prob after:  0.6523285 . Prob shift:  0.2858498
# 96. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.96931916 . Prob after:  0.46798387 . Prob shift:  0.50133526
# 97. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.98108244 . Prob after:  0.48232588 . Prob shift:  0.49875656
# 98. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.62687266 . Prob after:  0.38386008 . Prob shift:  0.24301258
# 99. Successful example crafted.
# use 76 substitution; use 8 NE
# Prob before:  0.94433606 . Prob after:  0.7928998 . Prob shift:  0.15143627
# 100. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.95471597 . Prob after:  0.24746698 . Prob shift:  0.707249
# 101. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9777296 . Prob after:  0.4911784 . Prob shift:  0.48655123
# 102. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9505495 . Prob after:  0.4030505 . Prob shift:  0.54749894
# 103. Successful example crafted.
# use 97 substitution; use 3 NE
# Prob before:  0.9281079 . Prob after:  0.58426744 . Prob shift:  0.34384048
# 104. Failure.
# use 7 substitution; use 1 NE
# Prob before:  0.8252401 . Prob after:  0.3014593 . Prob shift:  0.52378076
# 105. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.6889454 . Prob after:  0.37663063 . Prob shift:  0.31231478
# 106. Successful example crafted.
# use 11 substitution; use 0 NE
# Prob before:  0.9424447 . Prob after:  0.33440217 . Prob shift:  0.6080425
# 107. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.88327223 . Prob after:  0.41149548 . Prob shift:  0.47177675
# 108. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8327981 . Prob after:  0.36674055 . Prob shift:  0.46605757
# 109. Successful example crafted.
# use 62 substitution; use 1 NE
# Prob before:  0.9686602 . Prob after:  0.6147665 . Prob shift:  0.3538937
# 110. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.7305133 . Prob after:  0.3752023 . Prob shift:  0.35531098
# 111. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5635235 . Prob after:  0.2030967 . Prob shift:  0.36042678
# 112. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.93257064 . Prob after:  0.39448884 . Prob shift:  0.53808177
# 113. Successful example crafted.
# use 64 substitution; use 5 NE
# Prob before:  0.88040096 . Prob after:  0.5631827 . Prob shift:  0.31721824
# 114. Failure.
# use 49 substitution; use 8 NE
# Prob before:  0.92860615 . Prob after:  0.6420909 . Prob shift:  0.28651524
# 115. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.61120087 . Prob after:  0.3300509 . Prob shift:  0.28114998
# 116. Successful example crafted.
# use 138 substitution; use 5 NE
# Prob before:  0.9676412 . Prob after:  0.83029604 . Prob shift:  0.13734514
# 117. Failure.
# use 25 substitution; use 3 NE
# Prob before:  0.96738595 . Prob after:  0.46672246 . Prob shift:  0.5006635
# 118. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.46770594 . Prob after:  0.24758665 . Prob shift:  0.22011928
# 119. Successful example crafted.
# use 80 substitution; use 3 NE
# Prob before:  0.9523857 . Prob after:  0.71571773 . Prob shift:  0.23666799
# 120. Failure.
# use 128 substitution; use 5 NE
# Prob before:  0.9439279 . Prob after:  0.6428753 . Prob shift:  0.30105257
# 121. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.3244446 . Prob after:  0.20453408 . Prob shift:  0.11991051
# 122. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9624177 . Prob after:  0.23625644 . Prob shift:  0.7261613
# 123. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.7932367 . Prob after:  0.24664395 . Prob shift:  0.5465927
# 124. Successful example crafted.
# use 14 substitution; use 1 NE
# Prob before:  0.90307885 . Prob after:  0.39828235 . Prob shift:  0.5047965
# 125. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.82513493 . Prob after:  0.72950673 . Prob shift:  0.0956282
# 126. Failure.
# use 25 substitution; use 3 NE
# Prob before:  0.97670823 . Prob after:  0.3220266 . Prob shift:  0.6546816
# 127. Successful example crafted.
# use 76 substitution; use 5 NE
# Prob before:  0.9378389 . Prob after:  0.63442117 . Prob shift:  0.30341774
# 128. Failure.
# use 109 substitution; use 4 NE
# Prob before:  0.97432905 . Prob after:  0.9356948 . Prob shift:  0.03863424
# 129. Failure.
# use 51 substitution; use 1 NE
# Prob before:  0.9849924 . Prob after:  0.5580057 . Prob shift:  0.4269867
# 130. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.7351509 . Prob after:  0.3749907 . Prob shift:  0.36016017
# 131. Successful example crafted.
# use 22 substitution; use 0 NE
# Prob before:  0.9814082 . Prob after:  0.83362913 . Prob shift:  0.14777905
# 132. Failure.
# use 12 substitution; use 0 NE
# Prob before:  0.96969414 . Prob after:  0.81531435 . Prob shift:  0.15437979
# 133. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.8315912 . Prob after:  0.47466767 . Prob shift:  0.35692352
# 134. Successful example crafted.
# use 11 substitution; use 1 NE
# Prob before:  0.9571147 . Prob after:  0.44194642 . Prob shift:  0.5151683
# 135. Successful example crafted.
# use 28 substitution; use 4 NE
# Prob before:  0.9602699 . Prob after:  0.7028868 . Prob shift:  0.2573831
# 136. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.49631923 . Prob after:  0.1424158 . Prob shift:  0.3539034
# 137. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  0.8356999 . Prob after:  0.37600014 . Prob shift:  0.45969978
# 138. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.89164495 . Prob after:  0.384783 . Prob shift:  0.5068619
# 139. Successful example crafted.
# use 29 substitution; use 3 NE
# Prob before:  0.9694838 . Prob after:  0.707915 . Prob shift:  0.26156878
# 140. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.92457366 . Prob after:  0.38239443 . Prob shift:  0.5421792
# 141. Successful example crafted.
# use 37 substitution; use 2 NE
# Prob before:  0.97563034 . Prob after:  0.35585964 . Prob shift:  0.6197707
# 142. Successful example crafted.
# use 15 substitution; use 2 NE
# Prob before:  0.9603815 . Prob after:  0.9393042 . Prob shift:  0.021077335
# 143. Failure.
# use 75 substitution; use 2 NE
# Prob before:  0.9558457 . Prob after:  0.7528736 . Prob shift:  0.20297211
# 144. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.8585819 . Prob after:  0.30370042 . Prob shift:  0.55488145
# 145. Successful example crafted.
# use 44 substitution; use 5 NE
# Prob before:  0.99163634 . Prob after:  0.7791724 . Prob shift:  0.21246392
# 146. Failure.
# use 88 substitution; use 1 NE
# Prob before:  0.9524249 . Prob after:  0.824971 . Prob shift:  0.12745386
# 147. Failure.
# use 38 substitution; use 2 NE
# Prob before:  0.97185135 . Prob after:  0.92585874 . Prob shift:  0.045992613
# 148. Failure.
# use 12 substitution; use 0 NE
# Prob before:  0.903441 . Prob after:  0.44536877 . Prob shift:  0.45807225
# 149. Successful example crafted.
# use 12 substitution; use 0 NE
# Prob before:  0.86811984 . Prob after:  0.37747025 . Prob shift:  0.49064958
# 150. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8755589 . Prob after:  0.47525656 . Prob shift:  0.40030235
# 151. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2716501 . Prob after:  0.1697016 . Prob shift:  0.1019485
# 152. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.93811923 . Prob after:  0.33926064 . Prob shift:  0.5988586
# 153. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.53703195 . Prob after:  0.18232033 . Prob shift:  0.35471162
# 154. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.9498044 . Prob after:  0.46184927 . Prob shift:  0.48795515
# 155. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.93409634 . Prob after:  0.48633695 . Prob shift:  0.4477594
# 156. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4562579 . Prob after:  0.1911581 . Prob shift:  0.26509982
# 157. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.22174893 . Prob after:  0.09611092 . Prob shift:  0.12563801
# 158. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.12127644 . Prob after:  0.059580997 . Prob shift:  0.06169544
# 159. Successful example crafted.
# use 50 substitution; use 1 NE
# Prob before:  0.9586886 . Prob after:  0.65157306 . Prob shift:  0.30711555
# 160. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.71199477 . Prob after:  0.4674612 . Prob shift:  0.24453357
# 161. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.94935316 . Prob after:  0.47756055 . Prob shift:  0.4717926
# 162. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.89843917 . Prob after:  0.23757043 . Prob shift:  0.66086876
# 163. Successful example crafted.
# use 18 substitution; use 0 NE
# Prob before:  0.9814494 . Prob after:  0.16810603 . Prob shift:  0.8133434
# 164. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  0.96780527 . Prob after:  0.74093425 . Prob shift:  0.22687101
# 165. Failure.
# use 7 substitution; use 0 NE
# Prob before:  0.97611225 . Prob after:  0.46796963 . Prob shift:  0.5081426
# 166. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8562701 . Prob after:  0.39792964 . Prob shift:  0.45834044
# 167. Successful example crafted.
# use 123 substitution; use 9 NE
# Prob before:  0.94846624 . Prob after:  0.5057371 . Prob shift:  0.44272912
# 168. Failure.
# use 6 substitution; use 0 NE
# Prob before:  0.83447886 . Prob after:  0.446958 . Prob shift:  0.38752085
# 169. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.82513493 . Prob after:  0.72885215 . Prob shift:  0.09628278
# 170. Failure.
# use 15 substitution; use 5 NE
# Prob before:  0.8569969 . Prob after:  0.4628657 . Prob shift:  0.39413118
# 171. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.45595762 . Prob after:  0.3273451 . Prob shift:  0.12861252
# 172. Successful example crafted.
# use 49 substitution; use 0 NE
# Prob before:  0.9555268 . Prob after:  0.85004723 . Prob shift:  0.1054796
# 173. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.61681 . Prob after:  0.429254 . Prob shift:  0.18755603
# 174. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.7942485 . Prob after:  0.44386524 . Prob shift:  0.35038328
# 175. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.3786844 . Prob after:  0.28352883 . Prob shift:  0.09515557
# 176. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.952001 . Prob after:  0.48584953 . Prob shift:  0.46615145
# 177. Successful example crafted.
# use 40 substitution; use 7 NE
# Prob before:  0.9684797 . Prob after:  0.731473 . Prob shift:  0.23700666
# 178. Failure.
# use 87 substitution; use 4 NE
# Prob before:  0.9640734 . Prob after:  0.6968504 . Prob shift:  0.267223
# 179. Failure.
# use 64 substitution; use 4 NE
# Prob before:  0.9661481 . Prob after:  0.4099206 . Prob shift:  0.55622745
# 180. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.38935152 . Prob after:  0.15263028 . Prob shift:  0.23672123
# 181. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.68700415 . Prob after:  0.46733317 . Prob shift:  0.21967098
# 182. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.24373217 . Prob after:  0.11181357 . Prob shift:  0.13191861
# 183. Successful example crafted.
# use 59 substitution; use 10 NE
# Prob before:  0.96642226 . Prob after:  0.4461918 . Prob shift:  0.5202305
# 184. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.94428694 . Prob after:  0.45647022 . Prob shift:  0.48781672
# 185. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.53158116 . Prob after:  0.43205497 . Prob shift:  0.0995262
# 186. Successful example crafted.

# %%
fool_text_classifier(model_type="sn", binary=True, cosMod=True)
# Out:
# clean_samples_cap: 200
# Processing IMDB dataset
# Build word_cnn model...
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# model path: ./runs/imdb/word_cnn.dat_cosine_0.1ratio_binary
# 200/200 [==============================] - ETA:  - 2s 9ms/step
# clean samples origin test_loss: 0.317479, accuracy: 0.880000
# 25000/25000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 75us/step
# all origin test_loss: 0.372194, accuracy: 0.843020
# Crafting adversarial examples...
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:89: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# use 40 substitution; use 5 NE
# Prob before:  0.9431079 . Prob after:  0.46059254 . Prob shift:  0.48251536
# 0. Successful example crafted.
# use 46 substitution; use 4 NE
# Prob before:  0.93931866 . Prob after:  0.591051 . Prob shift:  0.34826767
# 1. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.14368764 . Prob after:  0.10581525 . Prob shift:  0.03787239
# 2. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6919015 . Prob after:  0.41981432 . Prob shift:  0.2720872
# 3. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.898345 . Prob after:  0.41762835 . Prob shift:  0.48071665
# 4. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4491381 . Prob after:  0.30479285 . Prob shift:  0.14434525
# 5. Successful example crafted.
# use 20 substitution; use 2 NE
# Prob before:  0.8317333 . Prob after:  0.44450805 . Prob shift:  0.38722524
# 6. Successful example crafted.
# use 31 substitution; use 3 NE
# Prob before:  0.9075879 . Prob after:  0.34314916 . Prob shift:  0.5644387
# 7. Successful example crafted.
# use 14 substitution; use 1 NE
# Prob before:  0.95251864 . Prob after:  0.4190117 . Prob shift:  0.53350693
# 8. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.54049754 . Prob after:  0.2712545 . Prob shift:  0.26924303
# 9. Successful example crafted.
# use 98 substitution; use 1 NE
# Prob before:  0.9624058 . Prob after:  0.8818126 . Prob shift:  0.08059323
# 10. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.61279523 . Prob after:  0.34734282 . Prob shift:  0.2654524
# 11. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.67016417 . Prob after:  0.2173217 . Prob shift:  0.45284247
# 12. Successful example crafted.
# use 105 substitution; use 3 NE
# Prob before:  0.80253226 . Prob after:  0.52549046 . Prob shift:  0.2770418
# 13. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9518999 . Prob after:  0.3553791 . Prob shift:  0.5965208
# 14. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.905491 . Prob after:  0.3311245 . Prob shift:  0.57436645
# 15. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.11488018 . Prob after:  0.08719212 . Prob shift:  0.027688064
# 16. Successful example crafted.
# use 62 substitution; use 5 NE
# Prob before:  0.97455907 . Prob after:  0.593584 . Prob shift:  0.38097507
# 17. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.59907734 . Prob after:  0.3496395 . Prob shift:  0.24943784
# 18. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8583466 . Prob after:  0.47799474 . Prob shift:  0.38035184
# 19. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5722128 . Prob after:  0.35271564 . Prob shift:  0.21949717
# 20. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7848693 . Prob after:  0.39999345 . Prob shift:  0.38487586
# 21. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.85312104 . Prob after:  0.49317786 . Prob shift:  0.35994318
# 22. Successful example crafted.
# use 43 substitution; use 5 NE
# Prob before:  0.8631583 . Prob after:  0.58171815 . Prob shift:  0.28144014
# 23. Failure.
# use 90 substitution; use 9 NE
# Prob before:  0.9260749 . Prob after:  0.54047745 . Prob shift:  0.38559747
# 24. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.61189 . Prob after:  0.24740288 . Prob shift:  0.36448714
# 25. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.898345 . Prob after:  0.41762835 . Prob shift:  0.48071665
# 26. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.8928443 . Prob after:  0.402532 . Prob shift:  0.4903123
# 27. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.94487554 . Prob after:  0.4365158 . Prob shift:  0.50835973
# 28. Successful example crafted.
# use 23 substitution; use 0 NE
# Prob before:  0.9203498 . Prob after:  0.48085755 . Prob shift:  0.43949223
# 29. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6964239 . Prob after:  0.14788754 . Prob shift:  0.54853636
# 30. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.44244993 . Prob after:  0.36800805 . Prob shift:  0.07444188
# 31. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.70055526 . Prob after:  0.48763317 . Prob shift:  0.2129221
# 32. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.93875295 . Prob after:  0.40014657 . Prob shift:  0.5386064
# 33. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.50845224 . Prob after:  0.27323875 . Prob shift:  0.23521349
# 34. Successful example crafted.
# use 79 substitution; use 6 NE
# Prob before:  0.9436856 . Prob after:  0.52742755 . Prob shift:  0.41625804
# 35. Failure.
# use 141 substitution; use 9 NE
# Prob before:  0.96080995 . Prob after:  0.63250357 . Prob shift:  0.32830638
# 36. Failure.
# use 65 substitution; use 0 NE
# Prob before:  0.9315914 . Prob after:  0.5522647 . Prob shift:  0.3793267
# 37. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.69005704 . Prob after:  0.43731144 . Prob shift:  0.2527456
# 38. Successful example crafted.
# use 101 substitution; use 22 NE
# Prob before:  0.8686336 . Prob after:  0.4965427 . Prob shift:  0.37209094
# 39. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8299894 . Prob after:  0.43260357 . Prob shift:  0.3973858
# 40. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.86741364 . Prob after:  0.29632443 . Prob shift:  0.5710892
# 41. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.854346 . Prob after:  0.42649382 . Prob shift:  0.42785215
# 42. Successful example crafted.
# use 63 substitution; use 4 NE
# Prob before:  0.9774499 . Prob after:  0.95342445 . Prob shift:  0.02402544
# 43. Failure.
# use 68 substitution; use 3 NE
# Prob before:  0.8417486 . Prob after:  0.58364856 . Prob shift:  0.25810003
# 44. Failure.
# use 16 substitution; use 2 NE
# Prob before:  0.8185496 . Prob after:  0.48523036 . Prob shift:  0.33331922
# 45. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2526599 . Prob after:  0.15173495 . Prob shift:  0.10092494
# 46. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.771731 . Prob after:  0.40386698 . Prob shift:  0.36786404
# 47. Successful example crafted.
# use 130 substitution; use 18 NE
# Prob before:  0.9035659 . Prob after:  0.72047395 . Prob shift:  0.18309194
# 48. Failure.
# use 36 substitution; use 2 NE
# Prob before:  0.9711935 . Prob after:  0.31814355 . Prob shift:  0.65304995
# 49. Successful example crafted.
# use 6 substitution; use 0 NE
# Prob before:  0.8183783 . Prob after:  0.44080457 . Prob shift:  0.37757376
# 50. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.39152142 . Prob after:  0.30434433 . Prob shift:  0.0871771
# 51. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8373798 . Prob after:  0.14869556 . Prob shift:  0.6886842
# 52. Successful example crafted.
# use 8 substitution; use 0 NE
# Prob before:  0.63602024 . Prob after:  0.49877 . Prob shift:  0.13725024
# 53. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6991206 . Prob after:  0.4584115 . Prob shift:  0.24070907
# 54. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.55112267 . Prob after:  0.46147522 . Prob shift:  0.08964744
# 55. Successful example crafted.
# use 54 substitution; use 5 NE
# Prob before:  0.8690239 . Prob after:  0.7906954 . Prob shift:  0.07832849
# 56. Failure.
# use 4 substitution; use 0 NE
# Prob before:  0.92586434 . Prob after:  0.4688999 . Prob shift:  0.45696443
# 57. Successful example crafted.
# use 12 substitution; use 2 NE
# Prob before:  0.6916971 . Prob after:  0.49963424 . Prob shift:  0.19206288
# 58. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7439719 . Prob after:  0.38839486 . Prob shift:  0.35557702
# 59. Successful example crafted.
# use 10 substitution; use 2 NE
# Prob before:  0.82587785 . Prob after:  0.46298108 . Prob shift:  0.36289677
# 60. Successful example crafted.
# use 146 substitution; use 11 NE
# Prob before:  0.97753155 . Prob after:  0.8462197 . Prob shift:  0.13131183
# 61. Failure.
# use 113 substitution; use 7 NE
# Prob before:  0.9012656 . Prob after:  0.5404542 . Prob shift:  0.3608114
# 62. Failure.
# use 4 substitution; use 0 NE
# Prob before:  0.72642785 . Prob after:  0.49372685 . Prob shift:  0.232701
# 63. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8475851 . Prob after:  0.29593512 . Prob shift:  0.5516499
# 64. Successful example crafted.
# use 41 substitution; use 4 NE
# Prob before:  0.8641971 . Prob after:  0.4791832 . Prob shift:  0.38501388
# 65. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.8473495 . Prob after:  0.45254996 . Prob shift:  0.39479956
# 66. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.19396411 . Prob after:  0.17595498 . Prob shift:  0.018009126
# 67. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5742815 . Prob after:  0.32850555 . Prob shift:  0.24577597
# 68. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.76571965 . Prob after:  0.39364967 . Prob shift:  0.37206998
# 69. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.44875684 . Prob after:  0.31127098 . Prob shift:  0.13748586
# 70. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.66533774 . Prob after:  0.4216132 . Prob shift:  0.24372455
# 71. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  0.9046582 . Prob after:  0.7754895 . Prob shift:  0.12916869
# 72. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5065575 . Prob after:  0.31264365 . Prob shift:  0.19391388
# 73. Successful example crafted.
# use 11 substitution; use 1 NE
# Prob before:  0.8371458 . Prob after:  0.49724042 . Prob shift:  0.33990538
# 74. Successful example crafted.
# use 25 substitution; use 1 NE
# Prob before:  0.95559853 . Prob after:  0.82043576 . Prob shift:  0.13516277
# 75. Failure.
# use 51 substitution; use 2 NE
# Prob before:  0.96950746 . Prob after:  0.56815606 . Prob shift:  0.4013514
# 76. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.18957615 . Prob after:  0.16335954 . Prob shift:  0.026216611
# 77. Successful example crafted.
# use 58 substitution; use 0 NE
# Prob before:  0.7913712 . Prob after:  0.775822 . Prob shift:  0.0155492425
# 78. Failure.
# use 4 substitution; use 1 NE
# Prob before:  0.80758274 . Prob after:  0.49694285 . Prob shift:  0.3106399
# 79. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8939063 . Prob after:  0.27876967 . Prob shift:  0.6151366
# 80. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8593626 . Prob after:  0.33476102 . Prob shift:  0.5246016
# 81. Successful example crafted.
# use 25 substitution; use 1 NE
# Prob before:  0.9093834 . Prob after:  0.73098963 . Prob shift:  0.17839378
# 82. Failure.
# use 149 substitution; use 17 NE
# Prob before:  0.9647484 . Prob after:  0.6206095 . Prob shift:  0.34413886
# 83. Failure.
# use 122 substitution; use 8 NE
# Prob before:  0.842753 . Prob after:  0.5976958 . Prob shift:  0.24505717
# 84. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.114777595 . Prob after:  0.10561689 . Prob shift:  0.009160705
# 85. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.53608716 . Prob after:  0.17496185 . Prob shift:  0.3611253
# 86. Successful example crafted.
# use 31 substitution; use 2 NE
# Prob before:  0.95889145 . Prob after:  0.4878491 . Prob shift:  0.47104236
# 87. Successful example crafted.
# use 40 substitution; use 3 NE
# Prob before:  0.9689378 . Prob after:  0.51657134 . Prob shift:  0.45236647
# 88. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5452265 . Prob after:  0.40097168 . Prob shift:  0.14425483
# 89. Successful example crafted.
# use 39 substitution; use 4 NE
# Prob before:  0.8766069 . Prob after:  0.67171293 . Prob shift:  0.20489395
# 90. Failure.
# use 3 substitution; use 0 NE
# Prob before:  0.7994907 . Prob after:  0.46853057 . Prob shift:  0.33096012
# 91. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.54168963 . Prob after:  0.14784577 . Prob shift:  0.39384386
# 92. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.8727468 . Prob after:  0.41317028 . Prob shift:  0.45957655
# 93. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4699266 . Prob after:  0.29159614 . Prob shift:  0.17833045
# 94. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.70554966 . Prob after:  0.24921599 . Prob shift:  0.45633367
# 95. Successful example crafted.
# use 69 substitution; use 1 NE
# Prob before:  0.9241302 . Prob after:  0.8504321 . Prob shift:  0.0736981
# 96. Failure.
# use 3 substitution; use 0 NE
# Prob before:  0.9793609 . Prob after:  0.33651525 . Prob shift:  0.64284563
# 97. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  0.94586337 . Prob after:  0.78764176 . Prob shift:  0.1582216
# 98. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.79086107 . Prob after:  0.45202434 . Prob shift:  0.33883673
# 99. Successful example crafted.
# use 7 substitution; use 1 NE
# Prob before:  0.9236824 . Prob after:  0.47577348 . Prob shift:  0.4479089
# 100. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.9292861 . Prob after:  0.1322484 . Prob shift:  0.7970377
# 101. Successful example crafted.
# use 10 substitution; use 0 NE
# Prob before:  0.923505 . Prob after:  0.4897764 . Prob shift:  0.4337286
# 102. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9211807 . Prob after:  0.31411806 . Prob shift:  0.6070627
# 103. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.90650004 . Prob after:  0.46673387 . Prob shift:  0.43976617
# 104. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.69676733 . Prob after:  0.42417678 . Prob shift:  0.27259055
# 105. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.4865477 . Prob after:  0.31860664 . Prob shift:  0.16794106
# 106. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.81204844 . Prob after:  0.40621683 . Prob shift:  0.4058316
# 107. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.93781364 . Prob after:  0.30385184 . Prob shift:  0.6339618
# 108. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7726734 . Prob after:  0.49690494 . Prob shift:  0.2757685
# 109. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9604048 . Prob after:  0.4711709 . Prob shift:  0.4892339
# 110. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.86034995 . Prob after:  0.35351565 . Prob shift:  0.50683427
# 111. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7422364 . Prob after:  0.26295775 . Prob shift:  0.47927862
# 112. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.9284305 . Prob after:  0.44497046 . Prob shift:  0.48346004
# 113. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.8258015 . Prob after:  0.4296272 . Prob shift:  0.39617428
# 114. Successful example crafted.
# use 49 substitution; use 8 NE
# Prob before:  0.92988056 . Prob after:  0.7688036 . Prob shift:  0.16107696
# 115. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.47020766 . Prob after:  0.30377072 . Prob shift:  0.16643694
# 116. Successful example crafted.
# use 138 substitution; use 5 NE
# Prob before:  0.9525418 . Prob after:  0.83777535 . Prob shift:  0.11476648
# 117. Failure.
# use 60 substitution; use 5 NE
# Prob before:  0.89811933 . Prob after:  0.3121249 . Prob shift:  0.5859944
# 118. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.19911887 . Prob after:  0.11723268 . Prob shift:  0.08188619
# 119. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.77222097 . Prob after:  0.41337097 . Prob shift:  0.35885
# 120. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  0.8564181 . Prob after:  0.5000362 . Prob shift:  0.3563819
# 121. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.27308017 . Prob after:  0.16090705 . Prob shift:  0.112173125
# 122. Successful example crafted.
# use 8 substitution; use 0 NE
# Prob before:  0.9638545 . Prob after:  0.49217495 . Prob shift:  0.47167954
# 123. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.84030277 . Prob after:  0.39188197 . Prob shift:  0.4484208
# 124. Successful example crafted.
# use 22 substitution; use 2 NE
# Prob before:  0.89553326 . Prob after:  0.49357477 . Prob shift:  0.4019585
# 125. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.8345547 . Prob after:  0.65183645 . Prob shift:  0.18271822
# 126. Failure.
# use 4 substitution; use 0 NE
# Prob before:  0.9641613 . Prob after:  0.3796264 . Prob shift:  0.5845349
# 127. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.9804072 . Prob after:  0.38431174 . Prob shift:  0.59609544
# 128. Successful example crafted.
# use 109 substitution; use 4 NE
# Prob before:  0.93379843 . Prob after:  0.8205765 . Prob shift:  0.11322194
# 129. Failure.
# use 51 substitution; use 1 NE
# Prob before:  0.9066626 . Prob after:  0.8066927 . Prob shift:  0.099969864
# 130. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.6510859 . Prob after:  0.17898716 . Prob shift:  0.47209877
# 131. Successful example crafted.
# use 22 substitution; use 0 NE
# Prob before:  0.8652213 . Prob after:  0.62413704 . Prob shift:  0.24108428
# 132. Failure.
# use 12 substitution; use 0 NE
# Prob before:  0.8972878 . Prob after:  0.5747238 . Prob shift:  0.322564
# 133. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.69823426 . Prob after:  0.4113873 . Prob shift:  0.28684697
# 134. Successful example crafted.
# use 9 substitution; use 1 NE
# Prob before:  0.8568061 . Prob after:  0.48954704 . Prob shift:  0.36725906
# 135. Successful example crafted.
# use 28 substitution; use 4 NE
# Prob before:  0.9423159 . Prob after:  0.7697352 . Prob shift:  0.17258066
# 136. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.49175698 . Prob after:  0.14964166 . Prob shift:  0.3421153
# 137. Successful example crafted.
# use 9 substitution; use 2 NE
# Prob before:  0.8419541 . Prob after:  0.49762017 . Prob shift:  0.34433395
# 138. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.8078365 . Prob after:  0.47663543 . Prob shift:  0.33120105
# 139. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9367412 . Prob after:  0.41081214 . Prob shift:  0.52592903
# 140. Successful example crafted.
# use 12 substitution; use 3 NE
# Prob before:  0.8803414 . Prob after:  0.49776095 . Prob shift:  0.38258046
# 141. Successful example crafted.
# use 36 substitution; use 1 NE
# Prob before:  0.96597034 . Prob after:  0.45035318 . Prob shift:  0.51561713
# 142. Successful example crafted.
# use 15 substitution; use 2 NE
# Prob before:  0.9240338 . Prob after:  0.7829189 . Prob shift:  0.14111495
# 143. Failure.
# use 75 substitution; use 2 NE
# Prob before:  0.9154734 . Prob after:  0.57119614 . Prob shift:  0.34427726
# 144. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.751304 . Prob after:  0.4947943 . Prob shift:  0.25650966
# 145. Successful example crafted.
# use 44 substitution; use 5 NE
# Prob before:  0.98247623 . Prob after:  0.8127277 . Prob shift:  0.16974854
# 146. Failure.
# use 88 substitution; use 1 NE
# Prob before:  0.9120284 . Prob after:  0.6843942 . Prob shift:  0.22763419
# 147. Failure.
# use 5 substitution; use 0 NE
# Prob before:  0.7291876 . Prob after:  0.49972567 . Prob shift:  0.22946194
# 148. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.82851046 . Prob after:  0.46944377 . Prob shift:  0.3590667
# 149. Successful example crafted.
# use 20 substitution; use 0 NE
# Prob before:  0.87766975 . Prob after:  0.37299877 . Prob shift:  0.504671
# 150. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.75452393 . Prob after:  0.30141422 . Prob shift:  0.4531097
# 151. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6260121 . Prob after:  0.31978345 . Prob shift:  0.30622864
# 152. Successful example crafted.
# use 3 substitution; use 2 NE
# Prob before:  0.95280945 . Prob after:  0.45350525 . Prob shift:  0.4993042
# 153. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.46836948 . Prob after:  0.37819824 . Prob shift:  0.09017125
# 154. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.91506076 . Prob after:  0.4652553 . Prob shift:  0.44980547
# 155. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.86117697 . Prob after:  0.17636116 . Prob shift:  0.6848158
# 156. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.26804024 . Prob after:  0.25433326 . Prob shift:  0.013706982
# 157. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5372115 . Prob after:  0.2538263 . Prob shift:  0.2833852
# 158. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2985186 . Prob after:  0.221596 . Prob shift:  0.076922596
# 159. Successful example crafted.
# use 50 substitution; use 1 NE
# Prob before:  0.9187613 . Prob after:  0.5775472 . Prob shift:  0.34121412
# 160. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.63008296 . Prob after:  0.46014988 . Prob shift:  0.16993308
# 161. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.7559551 . Prob after:  0.4853704 . Prob shift:  0.2705847
# 162. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7375565 . Prob after:  0.34715173 . Prob shift:  0.3904048
# 163. Successful example crafted.
# use 13 substitution; use 1 NE
# Prob before:  0.96793616 . Prob after:  0.44971886 . Prob shift:  0.5182173
# 164. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  0.94750035 . Prob after:  0.82709694 . Prob shift:  0.12040341
# 165. Failure.
# use 17 substitution; use 0 NE
# Prob before:  0.9451186 . Prob after:  0.47578117 . Prob shift:  0.46933743
# 166. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.65931475 . Prob after:  0.18495417 . Prob shift:  0.4743606
# 167. Successful example crafted.
# use 123 substitution; use 9 NE
# Prob before:  0.955473 . Prob after:  0.54498243 . Prob shift:  0.41049057
# 168. Failure.
# use 13 substitution; use 4 NE
# Prob before:  0.9026668 . Prob after:  0.46528703 . Prob shift:  0.43737978
# 169. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.8345545 . Prob after:  0.65158355 . Prob shift:  0.18297094
# 170. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5642995 . Prob after:  0.4760026 . Prob shift:  0.08829692
# 171. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.354676 . Prob after:  0.36556956 . Prob shift:  -0.0108935535
# 172. Successful example crafted.
# use 49 substitution; use 0 NE
# Prob before:  0.9226029 . Prob after:  0.70458925 . Prob shift:  0.21801364
# 173. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.6312389 . Prob after:  0.40498397 . Prob shift:  0.22625491
# 174. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.8449508 . Prob after:  0.4519083 . Prob shift:  0.3930425
# 175. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6664148 . Prob after:  0.4757197 . Prob shift:  0.1906951
# 176. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.94706076 . Prob after:  0.43282816 . Prob shift:  0.51423264
# 177. Successful example crafted.
# use 40 substitution; use 7 NE
# Prob before:  0.95451117 . Prob after:  0.63760865 . Prob shift:  0.31690252
# 178. Failure.
# use 87 substitution; use 4 NE
# Prob before:  0.93929803 . Prob after:  0.8145831 . Prob shift:  0.12471491
# 179. Failure.
# use 3 substitution; use 0 NE
# Prob before:  0.90370977 . Prob after:  0.40378347 . Prob shift:  0.4999263
# 180. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.38519418 . Prob after:  0.13823976 . Prob shift:  0.24695443
# 181. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.64052933 . Prob after:  0.40476534 . Prob shift:  0.235764
# 182. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.19964284 . Prob after:  0.11679163 . Prob shift:  0.08285121
# 183. Successful example crafted.
# use 16 substitution; use 1 NE
# Prob before:  0.90313554 . Prob after:  0.45724162 . Prob shift:  0.4458939
# 184. Successful example crafted.
# use 61 substitution; use 7 NE
# Prob before:  0.9546698 . Prob after:  0.47840774 . Prob shift:  0.47626203
# 185. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4523421 . Prob after:  0.23451945 . Prob shift:  0.21782264
# 186. Successful example crafted.
# use 6 substitution; use 1 NE
# Prob before:  0.7146341 . Prob after:  0.48209232 . Prob shift:  0.2325418
# 187. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5853445 . Prob after:  0.37026602 . Prob shift:  0.21507847
# 188. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.73419684 . Prob after:  0.4894128 . Prob shift:  0.24478403
# 189. Successful example crafted.
# use 95 substitution; use 6 NE
# Prob before:  0.9026304 . Prob after:  0.4932868 . Prob shift:  0.4093436
# 190. Successful example crafted.
# use 27 substitution; use 3 NE
# Prob before:  0.968895 . Prob after:  0.4071515 . Prob shift:  0.5617435
# 191. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.46347722 . Prob after:  0.19925694 . Prob shift:  0.2642203
# 192. Successful example crafted.
# use 147 substitution; use 18 NE
# Prob before:  0.83091444 . Prob after:  0.58570975 . Prob shift:  0.24520469
# 193. Failure.
# use 130 substitution; use 10 NE
# Prob before:  0.8914105 . Prob after:  0.87389255 . Prob shift:  0.017517984
# 194. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.7638192 . Prob after:  0.4967011 . Prob shift:  0.26711813
# 195. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.7967637 . Prob after:  0.39002404 . Prob shift:  0.40673968
# 196. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.61794996 . Prob after:  0.46911377 . Prob shift:  0.1488362
# 197. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8153981 . Prob after:  0.44463804 . Prob shift:  0.37076005
# 198. Successful example crafted.
# use 4 substitution; use 1 NE
# Prob before:  0.8053411 . Prob after:  0.49272594 . Prob shift:  0.3126152
# 199. Successful example crafted.
# CPU second: 105411.128405
# mean substitution rate: 0.09296387373447354
# mean NE rate: 0.0653859826093286
# Failed Examples: 47
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:118: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %%
# SN + Binary + Ham
fool_text_classifier(model_type="sn", binary=True, hamming=True)
# Out:
# clean_samples_cap: 200
# Processing IMDB dataset
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# model path: ./runs/imdb/word_cnn.dat_ecoc_v6
# 200/200 [==============================] - ETA:  - 0s 1ms/step
# clean samples origin test_loss: 0.302437, accuracy: 0.885000
# 25000/25000 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 2s 86us/step
# all origin test_loss: 0.355098, accuracy: 0.851740
# Crafting adversarial examples...
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:92: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
# use 8 substitution; use 1 NE
# Prob before:  0.89424413 . Prob after:  0.48391408 . Prob shift:  0.41033006
# 0. Successful example crafted.
# use 46 substitution; use 4 NE
# Prob before:  0.9049018 . Prob after:  0.63647133 . Prob shift:  0.26843047
# 1. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.09434451 . Prob after:  0.07638107 . Prob shift:  0.01796344
# 2. Successful example crafted.
# use 62 substitution; use 1 NE
# Prob before:  0.944809 . Prob after:  0.82573575 . Prob shift:  0.11907327
# 3. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.75506765 . Prob after:  0.40402162 . Prob shift:  0.35104603
# 4. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.52055186 . Prob after:  0.30446273 . Prob shift:  0.21608913
# 5. Successful example crafted.
# use 5 substitution; use 0 NE
# Prob before:  0.89547706 . Prob after:  0.44313872 . Prob shift:  0.45233834
# 6. Successful example crafted.
# use 35 substitution; use 3 NE
# Prob before:  0.9274104 . Prob after:  0.47431028 . Prob shift:  0.45310014
# 7. Successful example crafted.
# use 32 substitution; use 2 NE
# Prob before:  0.9712894 . Prob after:  0.45318106 . Prob shift:  0.51810837
# 8. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.5508757 . Prob after:  0.3128397 . Prob shift:  0.23803604
# 9. Successful example crafted.
# use 98 substitution; use 1 NE
# Prob before:  0.93235 . Prob after:  0.8766612 . Prob shift:  0.0556888
# 10. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.66204095 . Prob after:  0.39821818 . Prob shift:  0.26382276
# 11. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.59512156 . Prob after:  0.23113641 . Prob shift:  0.36398515
# 12. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.66426176 . Prob after:  0.42874992 . Prob shift:  0.23551184
# 13. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9282177 . Prob after:  0.2646289 . Prob shift:  0.6635888
# 14. Successful example crafted.
# use 8 substitution; use 2 NE
# Prob before:  0.9215085 . Prob after:  0.29636857 . Prob shift:  0.62513995
# 15. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.17768162 . Prob after:  0.14490835 . Prob shift:  0.03277327
# 16. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.93405044 . Prob after:  0.42765498 . Prob shift:  0.50639546
# 17. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7456609 . Prob after:  0.3733656 . Prob shift:  0.3722953
# 18. Successful example crafted.
# use 122 substitution; use 5 NE
# Prob before:  0.8333825 . Prob after:  0.6436375 . Prob shift:  0.18974501
# 19. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.7117606 . Prob after:  0.47185892 . Prob shift:  0.23990166
# 20. Successful example crafted.
# use 5 substitution; use 3 NE
# Prob before:  0.9246825 . Prob after:  0.28833443 . Prob shift:  0.63634807
# 21. Successful example crafted.
# use 62 substitution; use 2 NE
# Prob before:  0.93638754 . Prob after:  0.50064504 . Prob shift:  0.4357425
# 22. Failure.
# use 43 substitution; use 5 NE
# Prob before:  0.9489805 . Prob after:  0.6325375 . Prob shift:  0.31644303
# 23. Failure.
# use 4 substitution; use 2 NE
# Prob before:  0.9666677 . Prob after:  0.4911167 . Prob shift:  0.475551
# 24. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7839889 . Prob after:  0.33272687 . Prob shift:  0.45126203
# 25. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.75506765 . Prob after:  0.4040216 . Prob shift:  0.35104606
# 26. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.9218763 . Prob after:  0.34571064 . Prob shift:  0.5761657
# 27. Successful example crafted.
# use 10 substitution; use 0 NE
# Prob before:  0.84931225 . Prob after:  0.42709273 . Prob shift:  0.4222195
# 28. Successful example crafted.
# use 45 substitution; use 0 NE
# Prob before:  0.9723298 . Prob after:  0.8457912 . Prob shift:  0.12653857
# 29. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5734416 . Prob after:  0.11779823 . Prob shift:  0.4556434
# 30. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.70006603 . Prob after:  0.41796178 . Prob shift:  0.28210425
# 31. Successful example crafted.
# use 7 substitution; use 1 NE
# Prob before:  0.7417381 . Prob after:  0.40923902 . Prob shift:  0.33249906
# 32. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.88025135 . Prob after:  0.48428318 . Prob shift:  0.39596817
# 33. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.3767223 . Prob after:  0.21018939 . Prob shift:  0.16653292
# 34. Successful example crafted.
# use 79 substitution; use 6 NE
# Prob before:  0.9630999 . Prob after:  0.69698966 . Prob shift:  0.26611024
# 35. Failure.
# use 141 substitution; use 9 NE
# Prob before:  0.96131635 . Prob after:  0.58579326 . Prob shift:  0.3755231
# 36. Failure.
# use 65 substitution; use 0 NE
# Prob before:  0.88804585 . Prob after:  0.6941295 . Prob shift:  0.19391632
# 37. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.8654786 . Prob after:  0.46284157 . Prob shift:  0.402637
# 38. Successful example crafted.
# use 185 substitution; use 41 NE
# Prob before:  0.836398 . Prob after:  0.6358787 . Prob shift:  0.20051932
# 39. Failure.
# use 12 substitution; use 3 NE
# Prob before:  0.8864941 . Prob after:  0.47408065 . Prob shift:  0.41241345
# 40. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.86060315 . Prob after:  0.4507647 . Prob shift:  0.40983847
# 41. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.83673584 . Prob after:  0.3641176 . Prob shift:  0.47261825
# 42. Successful example crafted.
# use 63 substitution; use 4 NE
# Prob before:  0.9133627 . Prob after:  0.8286822 . Prob shift:  0.0846805
# 43. Failure.
# use 68 substitution; use 3 NE
# Prob before:  0.9124603 . Prob after:  0.81898284 . Prob shift:  0.09347749
# 44. Failure.
# use 9 substitution; use 1 NE
# Prob before:  0.8677011 . Prob after:  0.3497935 . Prob shift:  0.5179076
# 45. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.24778442 . Prob after:  0.20988317 . Prob shift:  0.037901253
# 46. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8270897 . Prob after:  0.3749609 . Prob shift:  0.45212883
# 47. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.7292524 . Prob after:  0.4981958 . Prob shift:  0.2310566
# 48. Successful example crafted.
# use 36 substitution; use 2 NE
# Prob before:  0.93506724 . Prob after:  0.49306756 . Prob shift:  0.44199967
# 49. Successful example crafted.
# use 8 substitution; use 0 NE
# Prob before:  0.89008933 . Prob after:  0.44334862 . Prob shift:  0.44674072
# 50. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.14950894 . Prob after:  0.11637753 . Prob shift:  0.033131406
# 51. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7549403 . Prob after:  0.18122508 . Prob shift:  0.5737152
# 52. Successful example crafted.
# use 4 substitution; use 0 NE
# Prob before:  0.6076378 . Prob after:  0.48701447 . Prob shift:  0.12062335
# 53. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.602256 . Prob after:  0.47762424 . Prob shift:  0.12463176
# 54. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.63896734 . Prob after:  0.47794852 . Prob shift:  0.16101882
# 55. Successful example crafted.
# use 8 substitution; use 2 NE
# Prob before:  0.8223892 . Prob after:  0.49494997 . Prob shift:  0.32743922
# 56. Successful example crafted.
# use 44 substitution; use 2 NE
# Prob before:  0.92892945 . Prob after:  0.33134735 . Prob shift:  0.5975821
# 57. Successful example crafted.
# use 2 substitution; use 1 NE
# Prob before:  0.941439 . Prob after:  0.43149492 . Prob shift:  0.5099441
# 58. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.4324524 . Prob after:  0.30992505 . Prob shift:  0.12252736
# 59. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.8143779 . Prob after:  0.42037708 . Prob shift:  0.39400083
# 60. Successful example crafted.
# use 146 substitution; use 11 NE
# Prob before:  0.9139819 . Prob after:  0.7556629 . Prob shift:  0.158319
# 61. Failure.
# use 15 substitution; use 3 NE
# Prob before:  0.8968021 . Prob after:  0.49933618 . Prob shift:  0.39746594
# 62. Successful example crafted.
# use 41 substitution; use 1 NE
# Prob before:  0.87603575 . Prob after:  0.49666962 . Prob shift:  0.37936613
# 63. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.72243863 . Prob after:  0.35100263 . Prob shift:  0.371436
# 64. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.6734746 . Prob after:  0.30677417 . Prob shift:  0.36670044
# 65. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7566331 . Prob after:  0.43836084 . Prob shift:  0.31827226
# 66. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.28011632 . Prob after:  0.23351115 . Prob shift:  0.04660517
# 67. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.63810676 . Prob after:  0.42646536 . Prob shift:  0.2116414
# 68. Successful example crafted.
# use 27 substitution; use 2 NE
# Prob before:  0.7152541 . Prob after:  0.35523313 . Prob shift:  0.360021
# 69. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.36664727 . Prob after:  0.28447866 . Prob shift:  0.08216861
# 70. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.88064957 . Prob after:  0.3048556 . Prob shift:  0.575794
# 71. Successful example crafted.
# use 17 substitution; use 1 NE
# Prob before:  0.96310115 . Prob after:  0.87377346 . Prob shift:  0.08932769
# 72. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.37792873 . Prob after:  0.18033491 . Prob shift:  0.19759382
# 73. Successful example crafted.
# use 12 substitution; use 1 NE
# Prob before:  0.92676234 . Prob after:  0.40401092 . Prob shift:  0.52275145
# 74. Successful example crafted.
# use 25 substitution; use 1 NE
# Prob before:  0.93189174 . Prob after:  0.6538038 . Prob shift:  0.2780879
# 75. Failure.
# use 51 substitution; use 2 NE
# Prob before:  0.93594706 . Prob after:  0.69044626 . Prob shift:  0.2455008
# 76. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.16207726 . Prob after:  0.09687314 . Prob shift:  0.06520412
# 77. Successful example crafted.
# use 58 substitution; use 0 NE
# Prob before:  0.86045504 . Prob after:  0.80621016 . Prob shift:  0.054244876
# 78. Failure.
# use 5 substitution; use 2 NE
# Prob before:  0.9320215 . Prob after:  0.41954297 . Prob shift:  0.51247853
# 79. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.9347779 . Prob after:  0.40052968 . Prob shift:  0.53424823
# 80. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7934238 . Prob after:  0.21123333 . Prob shift:  0.58219045
# 81. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.8549157 . Prob after:  0.48513865 . Prob shift:  0.36977702
# 82. Successful example crafted.
# use 149 substitution; use 17 NE
# Prob before:  0.96720093 . Prob after:  0.83217806 . Prob shift:  0.13502288
# 83. Failure.
# use 7 substitution; use 0 NE
# Prob before:  0.7517477 . Prob after:  0.49435818 . Prob shift:  0.25738955
# 84. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.20122577 . Prob after:  0.14832143 . Prob shift:  0.052904338
# 85. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.3340452 . Prob after:  0.082872316 . Prob shift:  0.2511729
# 86. Successful example crafted.
# use 61 substitution; use 3 NE
# Prob before:  0.9447956 . Prob after:  0.7343686 . Prob shift:  0.21042699
# 87. Failure.
# use 40 substitution; use 3 NE
# Prob before:  0.97703576 . Prob after:  0.74278516 . Prob shift:  0.2342506
# 88. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.7257095 . Prob after:  0.44648388 . Prob shift:  0.27922562
# 89. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.80392486 . Prob after:  0.4435034 . Prob shift:  0.36042145
# 90. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.71356016 . Prob after:  0.4888604 . Prob shift:  0.22469977
# 91. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.65897864 . Prob after:  0.3088917 . Prob shift:  0.35008693
# 92. Successful example crafted.
# use 64 substitution; use 2 NE
# Prob before:  0.8905165 . Prob after:  0.50397426 . Prob shift:  0.38654226
# 93. Failure.
# use 66 substitution; use 5 NE
# Prob before:  0.5681765 . Prob after:  0.48407376 . Prob shift:  0.08410275
# 94. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.83921397 . Prob after:  0.20668684 . Prob shift:  0.6325271
# 95. Successful example crafted.
# use 69 substitution; use 1 NE
# Prob before:  0.7329508 . Prob after:  0.61874473 . Prob shift:  0.114206076
# 96. Failure.
# use 2 substitution; use 0 NE
# Prob before:  0.96851796 . Prob after:  0.44111264 . Prob shift:  0.5274053
# 97. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  0.97412395 . Prob after:  0.7488081 . Prob shift:  0.22531587
# 98. Failure.
# use 65 substitution; use 3 NE
# Prob before:  0.7262009 . Prob after:  0.6650067 . Prob shift:  0.06119418
# 99. Failure.
# use 76 substitution; use 8 NE
# Prob before:  0.9622462 . Prob after:  0.8571975 . Prob shift:  0.10504866
# 100. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.8617798 . Prob after:  0.2495499 . Prob shift:  0.61222994
# 101. Successful example crafted.
# use 133 substitution; use 4 NE
# Prob before:  0.93411577 . Prob after:  0.8500054 . Prob shift:  0.08411038
# 102. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.9106917 . Prob after:  0.17057686 . Prob shift:  0.7401148
# 103. Successful example crafted.
# use 97 substitution; use 3 NE
# Prob before:  0.92383987 . Prob after:  0.631907 . Prob shift:  0.29193288
# 104. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.8506975 . Prob after:  0.33160156 . Prob shift:  0.51909596
# 105. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.74171335 . Prob after:  0.3565895 . Prob shift:  0.38512385
# 106. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.92504114 . Prob after:  0.3847654 . Prob shift:  0.54027575
# 107. Successful example crafted.
# use 106 substitution; use 4 NE
# Prob before:  0.8684414 . Prob after:  0.4906746 . Prob shift:  0.37776682
# 108. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6776248 . Prob after:  0.47868526 . Prob shift:  0.19893956
# 109. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.95633465 . Prob after:  0.47854787 . Prob shift:  0.47778678
# 110. Successful example crafted.
# use 10 substitution; use 2 NE
# Prob before:  0.8787196 . Prob after:  0.35826042 . Prob shift:  0.5204592
# 111. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.89279234 . Prob after:  0.37505153 . Prob shift:  0.51774085
# 112. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.9659422 . Prob after:  0.4768242 . Prob shift:  0.489118
# 113. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.77731216 . Prob after:  0.43115425 . Prob shift:  0.3461579
# 114. Successful example crafted.
# use 49 substitution; use 8 NE
# Prob before:  0.97199756 . Prob after:  0.84625983 . Prob shift:  0.12573773
# 115. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.7471353 . Prob after:  0.44310778 . Prob shift:  0.3040275
# 116. Successful example crafted.
# use 138 substitution; use 5 NE
# Prob before:  0.9677548 . Prob after:  0.87235516 . Prob shift:  0.09539962
# 117. Failure.
# use 3 substitution; use 1 NE
# Prob before:  0.830984 . Prob after:  0.49017134 . Prob shift:  0.34081265
# 118. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.21356988 . Prob after:  0.16949777 . Prob shift:  0.044072106
# 119. Successful example crafted.
# use 80 substitution; use 3 NE
# Prob before:  0.98198354 . Prob after:  0.9508579 . Prob shift:  0.031125665
# 120. Failure.
# use 22 substitution; use 1 NE
# Prob before:  0.9085146 . Prob after:  0.4963785 . Prob shift:  0.4121361
# 121. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.14351247 . Prob after:  0.11087422 . Prob shift:  0.03263825
# 122. Successful example crafted.
# use 13 substitution; use 1 NE
# Prob before:  0.9780677 . Prob after:  0.49637285 . Prob shift:  0.48169485
# 123. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.6832039 . Prob after:  0.4658219 . Prob shift:  0.21738198
# 124. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.93613076 . Prob after:  0.4832005 . Prob shift:  0.45293027
# 125. Successful example crafted.
# use 52 substitution; use 5 NE
# Prob before:  0.9206418 . Prob after:  0.74960274 . Prob shift:  0.17103904
# 126. Failure.
# use 34 substitution; use 2 NE
# Prob before:  0.9758539 . Prob after:  0.4175848 . Prob shift:  0.55826914
# 127. Successful example crafted.
# use 6 substitution; use 2 NE
# Prob before:  0.9448544 . Prob after:  0.40598714 . Prob shift:  0.53886724
# 128. Successful example crafted.
# use 109 substitution; use 4 NE
# Prob before:  0.9542347 . Prob after:  0.897911 . Prob shift:  0.056323707
# 129. Failure.
# use 51 substitution; use 1 NE
# Prob before:  0.9562604 . Prob after:  0.7109263 . Prob shift:  0.24533409
# 130. Failure.
# use 2 substitution; use 1 NE
# Prob before:  0.7624695 . Prob after:  0.26736015 . Prob shift:  0.49510932
# 131. Successful example crafted.
# use 22 substitution; use 0 NE
# Prob before:  0.9252643 . Prob after:  0.787265 . Prob shift:  0.1379993
# 132. Failure.
# use 12 substitution; use 0 NE
# Prob before:  0.97752964 . Prob after:  0.77945673 . Prob shift:  0.19807291
# 133. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.7262923 . Prob after:  0.434068 . Prob shift:  0.29222432
# 134. Successful example crafted.
# use 10 substitution; use 1 NE
# Prob before:  0.93440807 . Prob after:  0.46775407 . Prob shift:  0.466654
# 135. Successful example crafted.
# use 28 substitution; use 4 NE
# Prob before:  0.9339166 . Prob after:  0.8970552 . Prob shift:  0.03686142
# 136. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.47850594 . Prob after:  0.09867321 . Prob shift:  0.37983274
# 137. Successful example crafted.
# use 1 substitution; use 1 NE
# Prob before:  0.85796124 . Prob after:  0.48174754 . Prob shift:  0.3762137
# 138. Successful example crafted.
# use 3 substitution; use 0 NE
# Prob before:  0.89314604 . Prob after:  0.49148282 . Prob shift:  0.4016632
# 139. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.97016656 . Prob after:  0.4124862 . Prob shift:  0.55768037
# 140. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.9409873 . Prob after:  0.41563812 . Prob shift:  0.52534914
# 141. Successful example crafted.
# use 145 substitution; use 11 NE
# Prob before:  0.9723474 . Prob after:  0.73565906 . Prob shift:  0.23668832
# 142. Failure.
# use 15 substitution; use 2 NE
# Prob before:  0.9091524 . Prob after:  0.8274437 . Prob shift:  0.08170867
# 143. Failure.
# use 75 substitution; use 2 NE
# Prob before:  0.87255514 . Prob after:  0.69193476 . Prob shift:  0.18062037
# 144. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.55990106 . Prob after:  0.44849676 . Prob shift:  0.1114043
# 145. Successful example crafted.
# use 44 substitution; use 5 NE
# Prob before:  0.9650239 . Prob after:  0.81609285 . Prob shift:  0.14893103
# 146. Failure.
# use 88 substitution; use 1 NE
# Prob before:  0.9178788 . Prob after:  0.8459418 . Prob shift:  0.071937025
# 147. Failure.
# use 38 substitution; use 2 NE
# Prob before:  0.9247188 . Prob after:  0.8461127 . Prob shift:  0.07860607
# 148. Failure.
# use 25 substitution; use 4 NE
# Prob before:  0.7971711 . Prob after:  0.3538203 . Prob shift:  0.44335082
# 149. Successful example crafted.
# use 129 substitution; use 6 NE
# Prob before:  0.9215413 . Prob after:  0.67561257 . Prob shift:  0.2459287
# 150. Failure.
# use 1 substitution; use 1 NE
# Prob before:  0.74569327 . Prob after:  0.29146075 . Prob shift:  0.4542325
# 151. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.43207878 . Prob after:  0.3074981 . Prob shift:  0.12458068
# 152. Successful example crafted.
# use 4 substitution; use 2 NE
# Prob before:  0.9596038 . Prob after:  0.2889736 . Prob shift:  0.6706302
# 153. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.39607573 . Prob after:  0.23797545 . Prob shift:  0.15810028
# 154. Successful example crafted.
# use 37 substitution; use 1 NE
# Prob before:  0.8805502 . Prob after:  0.48542792 . Prob shift:  0.3951223
# 155. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.86531514 . Prob after:  0.27202955 . Prob shift:  0.59328556
# 156. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.2924348 . Prob after:  0.19927868 . Prob shift:  0.09315613
# 157. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.33603904 . Prob after:  0.11286797 . Prob shift:  0.22317107
# 158. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.23027816 . Prob after:  0.21605825 . Prob shift:  0.01421991
# 159. Successful example crafted.
# use 50 substitution; use 1 NE
# Prob before:  0.9705161 . Prob after:  0.74740696 . Prob shift:  0.22310913
# 160. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.6673339 . Prob after:  0.41037688 . Prob shift:  0.25695702
# 161. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.7907986 . Prob after:  0.41422272 . Prob shift:  0.3765759
# 162. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7423233 . Prob after:  0.3772986 . Prob shift:  0.3650247
# 163. Successful example crafted.
# use 59 substitution; use 4 NE
# Prob before:  0.9659533 . Prob after:  0.25962868 . Prob shift:  0.7063246
# 164. Successful example crafted.
# use 44 substitution; use 4 NE
# Prob before:  0.97123814 . Prob after:  0.81204236 . Prob shift:  0.15919578
# 165. Failure.
# use 66 substitution; use 1 NE
# Prob before:  0.9810827 . Prob after:  0.74044734 . Prob shift:  0.24063534
# 166. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.5835646 . Prob after:  0.26815835 . Prob shift:  0.31540623
# 167. Successful example crafted.
# use 5 substitution; use 1 NE
# Prob before:  0.91803086 . Prob after:  0.47835886 . Prob shift:  0.439672
# 168. Successful example crafted.
# use 115 substitution; use 9 NE
# Prob before:  0.6635892 . Prob after:  0.5885426 . Prob shift:  0.0750466
# 169. Failure.
# use 52 substitution; use 5 NE
# Prob before:  0.92064166 . Prob after:  0.7440453 . Prob shift:  0.17659634
# 170. Failure.
# use 54 substitution; use 5 NE
# Prob before:  0.59879357 . Prob after:  0.49874994 . Prob shift:  0.100043625
# 171. Successful example crafted.
# use 57 substitution; use 5 NE
# Prob before:  0.7055921 . Prob after:  0.4805445 . Prob shift:  0.22504759
# 172. Successful example crafted.
# use 49 substitution; use 0 NE
# Prob before:  0.9397966 . Prob after:  0.8304639 . Prob shift:  0.10933274
# 173. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.755074 . Prob after:  0.4610996 . Prob shift:  0.29397443
# 174. Successful example crafted.
# use 19 substitution; use 2 NE
# Prob before:  0.96959275 . Prob after:  0.4233865 . Prob shift:  0.54620624
# 175. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.61980444 . Prob after:  0.42245483 . Prob shift:  0.19734961
# 176. Successful example crafted.
# use 12 substitution; use 2 NE
# Prob before:  0.9473149 . Prob after:  0.49838513 . Prob shift:  0.4489298
# 177. Successful example crafted.
# use 40 substitution; use 7 NE
# Prob before:  0.9565387 . Prob after:  0.7945133 . Prob shift:  0.16202539
# 178. Failure.
# use 87 substitution; use 4 NE
# Prob before:  0.9427666 . Prob after:  0.8004929 . Prob shift:  0.14227372
# 179. Failure.
# use 4 substitution; use 0 NE
# Prob before:  0.92331463 . Prob after:  0.36816272 . Prob shift:  0.55515194
# 180. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.3638917 . Prob after:  0.08593097 . Prob shift:  0.27796072
# 181. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.7409128 . Prob after:  0.44039884 . Prob shift:  0.30051395
# 182. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.37872314 . Prob after:  0.18039584 . Prob shift:  0.1983273
# 183. Successful example crafted.
# use 86 substitution; use 11 NE
# Prob before:  0.984443 . Prob after:  0.6128751 . Prob shift:  0.3715679
# 184. Failure.
# use 80 substitution; use 10 NE
# Prob before:  0.9778454 . Prob after:  0.37417644 . Prob shift:  0.6036689
# 185. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.77871025 . Prob after:  0.37049013 . Prob shift:  0.4082201
# 186. Successful example crafted.
# use 3 substitution; use 1 NE
# Prob before:  0.6802816 . Prob after:  0.4780677 . Prob shift:  0.20221388
# 187. Successful example crafted.
# use 1 substitution; use 0 NE
# Prob before:  0.37740976 . Prob after:  0.2841553 . Prob shift:  0.09325445
# 188. Successful example crafted.
# use 110 substitution; use 4 NE
# Prob before:  0.9165973 . Prob after:  0.70575935 . Prob shift:  0.21083796
# 189. Failure.
# use 143 substitution; use 8 NE
# Prob before:  0.838146 . Prob after:  0.66438115 . Prob shift:  0.17376482
# 190. Failure.
# use 21 substitution; use 5 NE
# Prob before:  0.9695255 . Prob after:  0.43925136 . Prob shift:  0.53027415
# 191. Successful example crafted.
# use 76 substitution; use 1 NE
# Prob before:  0.8204276 . Prob after:  0.761015 . Prob shift:  0.0594126
# 192. Failure.
# use 14 substitution; use 0 NE
# Prob before:  0.9056642 . Prob after:  0.49360594 . Prob shift:  0.41205826
# 193. Successful example crafted.
# use 130 substitution; use 10 NE
# Prob before:  0.8199774 . Prob after:  0.82833606 . Prob shift:  -0.008358657
# 194. Failure.
# use 21 substitution; use 6 NE
# Prob before:  0.8881867 . Prob after:  0.4989655 . Prob shift:  0.3892212
# 195. Successful example crafted.
# use 19 substitution; use 1 NE
# Prob before:  0.89980257 . Prob after:  0.6694092 . Prob shift:  0.23039335
# 196. Failure.
# use 1 substitution; use 0 NE
# Prob before:  0.6287985 . Prob after:  0.36450502 . Prob shift:  0.26429346
# 197. Successful example crafted.
# use 2 substitution; use 0 NE
# Prob before:  0.94072586 . Prob after:  0.47661662 . Prob shift:  0.46410924
# 198. Successful example crafted.
# use 20 substitution; use 3 NE
# Prob before:  0.8903895 . Prob after:  0.5991416 . Prob shift:  0.2912479
# 199. Failure.
# CPU second: 89680.31245
# mean substitution rate: 0.11639443698820928
# mean NE rate: 0.11371569940370727
# Failed Examples: 59
# /local-scratch4/kevin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:121: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %% [markdown]
# ### Code: Compute Means and Viz

# %%
def get_tokenizer(dataset):
    texts = None
    if dataset == 'imdb':
        texts, _ = read_imdb_files('train')
    elif dataset == 'yahoo':
        texts, _, _ = read_yahoo_files()
    elif dataset == 'agnews':
        texts, _, _ = read_agnews_files('train')
    # first 12500 are postive review, second 12500 are negative review
#     print(config.num_words[dataset])
    tokenizer = Tokenizer(num_words=config.num_words[dataset])
    tokenizer.fit_on_texts(texts)
    return tokenizer

# %%
from config import config
def getMu_WordCloud(useSN, binary=False, cosMod = False, hamming=False):
    snModel, snEmbs = word_cnn("imdb", use_glove=False, sn=useSN, binary=binary, cosMod=cosMod, hamming=hamming)
    t = get_tokenizer("imdb")
    embMat = snEmbs[0]
    sorted_d = sorted(t.word_counts.items(), key=operator.itemgetter(1))
    topWords = sorted_d[-5000:][::-1]

    wordToDex = {}
    for wordDex, wordTup in enumerate(topWords):
        wordToDex[wordTup[0]] = wordDex + 1
        
    if useSN:
        fName = "./fool_result/backup/change_tuple_200_15epoch_sn.txt"
        if binary:
            if hamming:
                fName = "./fool_result/backup/change_tuple_200_ecoc_v6.txt"
            if cosMod:
                fName = './fool_result/backup/change_tuple_200_cosine_0.1ratio_binary.txt'
            if (hamming == False) and (cosMod == False):
                fName = './fool_result/backup/change_tuple_200_15epoch_best_binary_sn.txt'       
    else:
        fName = "./fool_result/backup/change_tuple_200_15epoch.txt"

    replaceSims = []
    replacePairs = []
    with open(fName, 'r') as f:
        lines = f.readlines()
        for lineDex, line in enumerate(lines):
            if lineDex <= 9:
                line = line[1:]
            else:
                line = line[2:]

            searchObj = re.findall( r"\(([0-9]*), '([A-Za-z]*)', SubstitutionCandidate\(token_position=[0-9]*, similarity_rank=[0-9]*, original_token=[A-Za-z]*, candidate_word='([A-Za-z]*)'\), [0-9]*.[0-9]*, '[A-Z]*'\)", line)
            tups = []

            for m in searchObj:
                if m[-1] == ",":
                    tups.append(m[:-1])
                else:
                    tups.append(m)

            searchObj = re.findall( r"\(([0-9]*), '([A-Za-z]*)', SubstitutionCandidate\(token_position=[0-9]*, similarity_rank=None, original_token=[A-Za-z]*, candidate_word='([A-Za-z]*)'\), [0-9]*.[0-9]*, '[A-Z]*'\)", line)
            for m in searchObj:
                if m[-1] == ",":
                    tups.append(m[:-1])
                else:
                    tups.append(m)

            for tup in tups:
                orgWord = tup[1].lower()
                replace = tup[2].lower()
                replacePairs.append(orgWord + "_" + replace)
                if orgWord in wordToDex and replace in wordToDex:
                    orgDex = wordToDex[orgWord]
                    repDex = wordToDex[replace]
                    sim = scipy.spatial.distance.cosine(embMat[orgDex, :], embMat[repDex, :])
                    replaceSims.append(sim)

    replaceSims = np.array(replaceSims)
    mu = replaceSims.mean()
    std = replaceSims.std()
    
    wCloudRep = " ".join(replacePairs)
    wordcloud = WordCloud().generate(wCloudRep)
    
    return mu, std, wordcloud

# %%
regMu, regStd, regWord = getMu_WordCloud(useSN=False, binary=False, hamming=False, cosMod=False)
snMu, snStd, snWord = getMu_WordCloud(useSN=True, binary=False, hamming=False, cosMod=False)
binMu, binStd, binWord = getMu_WordCloud(useSN=True, binary=True, hamming=False, cosMod=False)
cosMu, cosStd, cosWord = getMu_WordCloud(useSN=True, binary=True, hamming=False, cosMod=True)
hamMu, hamStd, hamWord = getMu_WordCloud(useSN=True, binary=True, hamming=True, cosMod=False)
# Out:
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13
# Build word_cnn model...
# Distance for 5000 classes with 50 bits (Hamming bound): 26
# Distance for 5000 classes with 50 bits (GV bound): 13

# %%
print("Reg Mu: {} SN Mu: {} SN Bin Mu: {} Cos Mu: {} Ham Mu: {}".format(regMu, snMu, binMu, cosMu, hamMu))
# Out:
# Reg Mu: 0.9859629060666278 SN Mu: 0.9276315625598257 SN Bin Mu: 0.8727621165465583 Cos Mu: 0.9662152581267163 Ham Mu: 0.891051974777611

# %%
fig, axs = plt.subplots(1, 3, figsize=(16,8))
axs[0].imshow(regWord, interpolation='bilinear')
axs[0].axis('off')
axs[0].set_title("Baseline")
axs[1].imshow(snWord, interpolation='bilinear')
axs[1].axis('off')
axs[1].set_title("Spec Norm")
axs[2].imshow(hamWord, interpolation='bilinear')
axs[2].axis('off')
axs[2].set_title("Spec Norm + Ham + Bin")
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(regWord, interpolation='bilinear')
plt.title("Reg")
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(snWord, interpolation='bilinear')
plt.title("Spec Norm")
plt.axis('off')
plt.show()

# %%
fig = plt.figure(figsize=(16,8))
plt.imshow(hamWord, interpolation='bilinear')
plt.title("Spec Norm + Ham + Bin")
plt.axis('off')
plt.show()
