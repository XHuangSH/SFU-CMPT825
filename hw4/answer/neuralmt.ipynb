# %% [markdown]
# # neuralmt notebook from skh
# ## 1, Default program

# %%
# -*- coding: utf-8 -*-
# Python version: 3
#
# SFU CMPT413/825 Fall 2019, HW4
# default solution
# Simon Fraser University
# Jetic Gū
#
#
import os
import re
import sys
import optparse
from tqdm import tqdm

import torch
from torch import nn

import pandas as pd
from torchtext import data

#import support.hyperparams as hp
#import support.datasets as ds

# hyperparameters
class hp:
    # vocab
    pad_idx = 1
    sos_idx = 2

    # architecture
    hidden_dim = 256
    embed_dim = 256
    n_layers = 2
    dropout = 0.2
    batch_size = 32
    num_epochs = 10
    lexicon_cap = 25000

    # training
    max_lr = 1e-4
    cycle_length = 3000

    # generation
    max_len = 50

    # system
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---YOUR ASSIGNMENT---
# -- Step 1: Baseline ---
# The attention module is completely broken now. Fix it using the definition
# given in the HW description.
class AttentionModule(nn.Module):
    def __init__(self, attention_dim):
        """
        You shouldn't deleted/change any of the following defs, they are
        essential for successfully loading the saved model.
        """
        super(AttentionModule, self).__init__()
        self.W_enc = nn.Linear(attention_dim, attention_dim, bias=False)
        self.W_dec = nn.Linear(attention_dim, attention_dim, bias=False)
        self.V_att = nn.Linear(attention_dim, 1, bias=False)
        return

    # Start working from here, both 'calcAlpha' and 'forward' need to be fixed
    def calcAlpha(self, decoder_hidden, encoder_out):
        """
        param encoder_out: (seq, batch, dim),
        param decoder_hidden: (seq, batch, dim)
        """
        seq, batch, dim = encoder_out.shape
        scores = torch.Tensor([seq * [batch * [1]]]).permute(2, 1, 0)
        alpha = torch.nn.functional.softmax(scores, dim=1)
        return alpha

    def forward(self, decoder_hidden, encoder_out):
        """
        encoder_out: (seq, batch, dim),
        decoder_hidden: (seq, batch, dim)
        """
        alpha = self.calcAlpha(decoder_hidden, encoder_out)
        seq, _, dim = encoder_out.shape
        context = (torch.sum(encoder_out, dim=0) / seq).reshape(1, 1, dim)
        return context, alpha.permute(2, 0, 1)


# -- Step 2: Improvements ---
# Implement UNK replacement, BeamSearch, translation termination criteria here,
# you can change 'greedyDecoder' and 'translate'.
def greedyDecoder(decoder, encoder_out, encoder_hidden, maxLen,
                  eos_index):
    seq1_len, batch_size, _ = encoder_out.size()
    target_vocab_size = decoder.target_vocab_size

    outputs = torch.autograd.Variable(
        encoder_out.data.new(maxLen, batch_size, target_vocab_size))
    alphas = torch.zeros(maxLen, batch_size, seq1_len)
    # take what we need from encoder
    decoder_hidden = encoder_hidden[-decoder.n_layers:]
    # start token (ugly hack)
    output = torch.autograd.Variable(
        outputs.data.new(1, batch_size).fill_(eos_index).long())
    for t in range(maxLen):
        output, decoder_hidden, alpha = decoder(
            output, encoder_out, decoder_hidden)
        outputs[t] = output
        alphas[t] = alpha.data
        output = torch.autograd.Variable(output.data.max(dim=2)[1])
        if int(output.data) == eos_index:
            break
    return outputs, alphas.permute(1, 2, 0)


def translate(model, test_iter):
    results = []
    for i, batch in tqdm(enumerate(test_iter)):
        output, attention = model(batch.src)
        output = output.topk(1)[1]
        output = model.tgt2txt(output[:, 0].data).strip().split('<EOS>')[0]
        results.append(output)
    return results


# ---Model Definition etc.---
# DO NOT MODIFY ANYTHING BELOW HERE


class Encoder(nn.Module):
    """
    Encoder class
    """
    def __init__(self, source_vocab_size, embed_dim, hidden_dim,
                 n_layers, dropout):
        super(Encoder, self).__init__()
        self.hidden_dim = hidden_dim
        self.embed = nn.Embedding(source_vocab_size, embed_dim,
                                  padding_idx=hp.pad_idx)
        self.rnn = nn.GRU(embed_dim,
                          hidden_dim,
                          n_layers,
                          dropout=dropout,
                          bidirectional=True)

    def forward(self, source, hidden=None):
        """
        param source: batched input indices
        param hidden: initial hidden value of self.rnn
        output (encoder_out, encoder_hidden):
            encoder_hidden: the encoder RNN states of length len(source)
            encoder_out: the final encoder states, both direction summed up
                together h^{forward} + h^{backward}
        """
        embedded = self.embed(source)  # (batch_size, seq_len, embed_dim)
        # get encoded states (encoder_hidden)
        encoder_out, encoder_hidden = self.rnn(embedded, hidden)

        # sum bidirectional outputs
        encoder_final = (encoder_out[:, :, :self.hidden_dim] +  # forward
                         encoder_out[:, :, self.hidden_dim:])   # backward

        # encoder_final:  (seq_len, batch_size, hidden_dim)
        # encoder_hidden: (n_layers * num_directions, batch_size, hidden_dim)
        return encoder_final, encoder_hidden


class Decoder(nn.Module):
    def __init__(self, target_vocab_size,
                 embed_dim, hidden_dim,
                 n_layers,
                 dropout):
        super(Decoder, self).__init__()
        self.target_vocab_size = target_vocab_size
        self.n_layers = n_layers
        self.embed = nn.Embedding(target_vocab_size,
                                  embed_dim,
                                  padding_idx=hp.pad_idx)
        self.attention = AttentionModule(hidden_dim)

        self.rnn = nn.GRU(embed_dim + hidden_dim,
                          hidden_dim,
                          n_layers,
                          dropout=dropout)

        self.out = nn.Linear(hidden_dim * 2, target_vocab_size)

    def forward(self, output, encoder_out, decoder_hidden):
        """
        decodes one output frame
        """
        embedded = self.embed(output)  # (1, batch, embed_dim)
        context, alpha = self.attention(decoder_hidden[-1:], encoder_out)
        # 1, 1, 50 (seq, batch, hidden_dim)
        rnn_output, decoder_hidden =\
            self.rnn(torch.cat([embedded, context], dim=2), decoder_hidden)
        output = self.out(torch.cat([rnn_output, context], 2))
        return output, decoder_hidden, alpha


class Seq2Seq(nn.Module):
    def __init__(self, fields=None, srcLex=None, tgtLex=None, build=True):
        super(Seq2Seq, self).__init__()
        # If we are loading the model, we don't build it here
        if build is True:
            self.params = {
                'srcLexSize': len(srcLex.vocab),
                'tgtLexSize': len(tgtLex.vocab),
                'embed_dim': hp.embed_dim,
                'hidden_dim': hp.hidden_dim,
                'n_layers': hp.n_layers,
                'dropout': hp.dropout,
                'fields': fields,
                'maxLen': hp.max_len,
            }
            self.build()

    def build(self):
        # self.params are loaded, start building the model accordingly
        self.encoder = Encoder(
            source_vocab_size=self.params['srcLexSize'],
            embed_dim=self.params['embed_dim'],
            hidden_dim=self.params['hidden_dim'],
            n_layers=self.params['n_layers'],
            dropout=self.params['dropout'])
        self.decoder = Decoder(
            target_vocab_size=self.params['tgtLexSize'],
            embed_dim=self.params['embed_dim'],
            hidden_dim=self.params['hidden_dim'],
            n_layers=self.params['n_layers'],
            dropout=self.params['dropout'])
        self.fields = self.params['fields']
        self.maxLen = self.params['maxLen']

    def forward(self, source, maxLen=None, eos_index=2):
        """
        This method implements greedy decoding
        param source: batched input indices
        param maxLen: maximum length of generated output
        param eos_index: <EOS> token's index
        """
        if maxLen is None:
            maxLen = self.maxLen
        encoder_out, encoder_hidden = self.encoder(source)

        return greedyDecoder(self.decoder, encoder_out, encoder_hidden,
                             maxLen, eos_index)

    def tgt2txt(self, tgt):
        return " ".join([self.fields['tgt'].vocab.itos[int(i)] for i in tgt])

    def save(self, file):
        torch.save((self.params, self.state_dict()), file)

    def load(self, file):
        self.params, state_dict = torch.load(file, map_location='cpu')
        self.build()
        self.load_state_dict(state_dict)

class DataFrameDataset(data.Dataset):
    """Class for using pandas DataFrames as a datasource"""
    def __init__(self, examples, fields, filter_pred=None):
        """
        Create a dataset from a pandas dataframe of examples and Fields
        Arguments:
            examples pd.DataFrame: DataFrame of examples
            fields {str: Field}: The Fields to use in this tuple. The
                string is a field name, and the Field is the associated field.
            filter_pred (callable or None): use only exanples for which
                filter_pred(example) is true, or use all examples if None.
                Default is None
        """
        fields = dict(fields)
        self.examples = examples.apply(
            SeriesExample.fromSeries, args=(fields,), axis=1).tolist()
        if filter_pred is not None:
            self.examples = filter(filter_pred, self.examples)
        self.fields = dict(fields)
        # Unpack field tuples
        for n, f in list(self.fields.items()):
            if isinstance(n, tuple):
                self.fields.update(zip(n, f))
                del self.fields[n]

class SeriesExample(data.Example):
    """Class to convert a pandas Series to an Example"""

    @classmethod
    def fromSeries(cls, data, fields):
        return cls.fromdict(data.to_dict(), fields)

    @classmethod
    def fromdict(cls, data, fields):
        ex = cls()

        for key, field in fields.items():
            if key not in data:
                raise ValueError(
                    f"Specified key {key} was not found in the input data")
            if field is not None:
                setattr(ex, key, field.preprocess(data[key]))
            else:
                setattr(ex, key, data[key])
        return ex

def biload(src_file, tgt_file, linesToLoad=50000, verbose=False):
    src = open(src_file).read().strip().split("\n")
    tgt = open(tgt_file).read().strip().split("\n")
    return list(map(lambda x: (x[0].strip().split(), x[1].strip().split()), zip(src, tgt)))[:linesToLoad]

def bitext2Dataset(src, tgt, srcLex, tgtLex,
                   linesToLoad=50000, maxLen=hp.max_len):
    data = biload(src, tgt, linesToLoad=linesToLoad, verbose=False)
    data = [(f, e) for f, e in data if len(f) <= maxLen and len(e) <= maxLen]
    data = {'src': [f for f, e in data],
            'tgt': [e for f, e in data]}

    df = pd.DataFrame(data, columns=["src", "tgt"])
    dataset = DataFrameDataset(df, [('src', srcLex), ('tgt', tgtLex)])
    return dataset

def loadData(batch_size, device=0,
             trainNum=sys.maxsize, testNum=sys.maxsize):
    def tokenize(x):
        return x.split()

    srcLex = data.Field()
    tgtLex = data.Field(init_token="<SOS>", eos_token="<EOS>")

    train = bitext2Dataset('./data/train.tok.de',
                           './data/train.tok.en', srcLex, tgtLex,
                           linesToLoad=trainNum)
    val = bitext2Dataset('./data/val.tok.de',
                         './data/val.tok.en', srcLex, tgtLex)
    test = bitext2Dataset('./data/input/dev.txt',
                          './data/reference/dev.out', srcLex, tgtLex,
                          linesToLoad=testNum,
                          maxLen=sys.maxsize)

    srcLex.build_vocab(train.src, max_size=hp.lexicon_cap)
    tgtLex.build_vocab(train.tgt, max_size=hp.lexicon_cap)

    train_iter, = data.BucketIterator.splits(
        (train,),
        batch_size=batch_size,
        sort_key=lambda x: len(x.src),
        device=device,
        repeat=False)

    val_iter, = data.BucketIterator.splits(
        (val,),
        batch_size=batch_size,
        device=device,
        repeat=False)

    test_iter = data.Iterator(
        test,
        batch_size=1,
        device=device,
        sort=False,
        sort_within_batch=False,
        shuffle=False,
        repeat=False)

    return train_iter, val_iter, test_iter, srcLex, tgtLex

def loadTestData(srcFile, srcLex, device=0, linesToLoad=sys.maxsize):
    def tokenize(x):
        return x.split()
    test = bitext2Dataset(srcFile,
                          srcFile, srcLex, srcLex, linesToLoad,
                          maxLen=sys.maxsize)
    test_iter = data.Iterator(
        test,
        batch_size=1,
        device=device,
        sort=False,
        sort_within_batch=False,
        shuffle=False,
        repeat=False)
    return test_iter

# %% [markdown]
# ### Run the default solution on dev

# %%
model = Seq2Seq(build=False)
model.load(os.path.join('../data', 'seq2seq_E049.pt'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# loading test dataset
test_iter = loadTestData(os.path.join('../data', 'input', 'dev.txt'), model.fields['src'],
                            device=device, linesToLoad=sys.maxsize)
results = translate(model, test_iter) # Warning: will take >5mins depending on your machine
print("\n".join(results))
# Out:
# 1305it [00:48, 26.84it/s]
# i had my own , , i had my own . .
# <unk> was <unk> <unk> , and <unk> <unk> .
# <unk> was a <unk> <unk> .
# and she was , and she was <unk> , and she was <unk> , and she was <unk> , and she <unk> , and she was <unk> , and she <unk> , and she <unk> , and she <unk> .
# i was , i was , i was , i was .
# and so , a first - <unk> , , a <unk> , a <unk> .
# and i was going to talk about the , and i wanted to talk about the <unk> .
# i i , i i , i .
# i did n't have it .
# and , the the , , , the , , , was to the <unk> , , and the <unk> , and the <unk> , and the <unk> , and the <unk> , and it was <unk> to
# i was , , " , " , " , " , " and , "
# later came later , later came later later came later later came later later came later later later came later later later later later later later later later later later later later later later later later later later later later later later later later later later later .
# and i did n't like , like , and i did n't have a <unk> like
# i was to <unk> my <unk> , <unk> .
# it was <unk> .
# she 's not going to , she 's , , she 's , , she 's , , she 's <unk> , she 's <unk> ,
# and , , , " , " , " , " , "
# the 's the the , the 's the to the .
# it 's what 's call a <unk> .
# i was n't the the that was the the that i was the .
# so , the <unk> , , the <unk> , , , , the <unk> , , , which is the <unk> , ,
# and we went and and and , and , and , and and , and and <unk> .
# and , , , , , , , , , , , <unk> , , and <unk> , , and <unk> , <unk> , and <unk> .
# in the , , in the , the <unk> , the <unk> <unk> in the <unk> .
# if you 're , , , , , you , , , you know , , , you know , , you know , , you know , , you know , , you know , , you know ,
# if you you you , you you .
# you can see a couple of .
# yeah , yeah , all , , .
# i 'm going to you you , , you , , , , , you know , , you know , you 're going to , you know , you 're going to .
# so , the the , , the , , the , , the , , the , , the , , the , , the , , the , , the , , the , , the , , the <unk> , the <unk> ,
# my is is <unk> is my <unk> .
# in fact , the - to - to - to - to - to - to - to - .
# so , , , , , , , , , , , , , , , , , , , , , , , ,
# you 're not talking about you 're talking about .
# i think it 's going to be , , i think ,
# now , the a of of a , that you have a a is that you have a a of
# the 's a that 's that 's a <unk> that 's a <unk> , or the <unk> , or the <unk> .
# and , to the , the , the to , and , to the , , and that 's what it 's going to be , and that 's what it 's going to
# and the the , the the , the the , the the , and the the , and the the the , and the the
# and so , the the , the <unk> , and the <unk> , and the <unk> .
# and we think of the , we think of the , we think of the , we think of the , we think , we know , the <unk> , we think of the
# and the has a <unk> , the <unk> , the <unk> , the <unk> .
# so , there 's a little bit about the there 's a little bit about that , and there 's a little bit about that .
# you know , the the the , the the .
# the <unk> 's <unk> about the <unk> .
# the 's a <unk> - <unk> .
# and 's called <unk> <unk> , the <unk> , and <unk> .
# it 's true .
# now , the is the the - <unk> , , which is what we have , the now ,
# and , a little bit of a , and a a little bit of a , and a a little bit of a .
# does n't that ? ?
# so , if you have a , , , , , , , , , , , you know , , you , "
# nothing 's nothing .
# and the <unk> is the <unk> , and it 's <unk> .
# and , , , , , , , , , , , , , and , and , , , , and , and , , and , and , , and , and , and , and , and , .
# i 've been doing , , , , , , , , " i , " i , "
# and so , , , , , , and it 's like , , and it 's like , "
# i had had had had had a <unk> , had had a <unk> .
# so , like , , , , the <unk> , , like , <unk> .
# and then , , , , , and they , and they , and they were , and they were <unk> , and they were <unk> , and they were <unk> ,
# i was , the , , , , , , , the <unk> , , and i , the <unk> .
# in the , , are the the ?
# not n't that .
# so , 's a , , it 's a lot of , , it 's a lot of , , because it 's a lot .
# a a a , a a , , a a , , a , a , a , a , a , a , a , a , a , a .
# and so , , the <unk> and the <unk> , and the <unk> and and <unk> .
# and 's not to buy a <unk> .
# you can make you want to make you you can do .
# you ca n't have to do that , you ca n't have to do that , you ca n't want to be able to do .
# i 've been thinking , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and
# and what 's going to do what the the is doing what the
# it 's a that 's a .
# the is is the <unk> of .
# she was she was , she she had , she had , she had , she had , she had , she had , she had .
# and they 'd n't have the , , , , and they would n't have , , , they would n't have , , , and they would n't have , , they would n't have ,
# she was <unk> , , she was <unk> , , and she was <unk> , her <unk> ,
# and were were , they were were , they were were , their were were were .
# and , , , and , , , and , but , but , and , and , and , and , and , and , "
# and , , , , , , , , , , , and , and .
# and the the , , the , , , the <unk> , , , and the <unk> , , and <unk> , the <unk> , and <unk> , <unk> , and <unk> , <unk> .
# i was going to be when i got , , and when i got , , and i got a <unk> ,
# i 'm going to have when i 'm going to ? "
# and i was n't to to to say , " to say , "
# they were n't really care about , they really did n't care .
# i was a , , and i was a , , and i was a <unk> .
# so , <unk> , , <unk> , , <unk> , <unk> , <unk> <unk> , <unk> <unk> .
# and , , , , , , , , , , , , and , and , <unk> , , and , <unk> ,
# i had n't been a , , , , , , and i , , , and she would n't , ,
# i 'd like to to you , and i would like to to you .
# and what 's to be a is something that you to be a .
# now , the <unk> , , the <unk> , , and know , <unk> , <unk> .
# so , this is , this is , this is , this is , this is , this is ,
# but , not the , not the , not not the , , but not not not the
# <unk> is <unk> .
# <unk> , <unk> , <unk> , <unk> , <unk> .
# and i , i , , , i , i , .
# they 're to , they , they , they , they , they , they 're , , they 're , , they 're , , they 're , , they 're , , they 're , , they 're , ,
# and then , the <unk> of the , of the , , of the , of the , , and the <unk> .
# so <unk> <unk> <unk> <unk> <unk> , <unk> <unk> , <unk> <unk> .
# now , <unk> is not <unk> , , or <unk> .
# and it 's not <unk> , and it 's <unk> , and they
# so , the <unk> <unk> , , <unk> , <unk> , <unk> .
# <unk> is a <unk> . .
# so , the <unk> , the , , , but the <unk> , the <unk> ,
# and , when she was , , she 's a , , she 's a , , she 's a , , and she 's a , ,
# and , the , , , , , , , , , <unk> .
# and , to do , , to do , , to do , , and that 's how to do it ,
# if you 're , , , , , you , , , you , , you 're not going to be , you 're , , you 're , , you 're not going to be , you 're ,
# so , to the , , to the , , to the , , to the , , to the , , to the .
# and , , , , , , , , and , , and , , and , and , and , and , and , and , and ,
# so , how did it happened ?
# and she was a a a <unk> , and she was a a <unk> in a <unk> , and a <unk> in a <unk> .
# there 's a a , , get a a , and get a a .
# she had her her to her her , and she her her her her .
# it 's a , , 's a <unk> , , <unk> ,
# she 's got a <unk> that she has a .
# and the the , the <unk> , the <unk> , , and the <unk> , and the <unk> , and the <unk> , and the <unk> , "
# so , 's what it 's like , , it 's like , , it 's like .
# so 's why to help them .
# and 's just <unk> , and , and the <unk> , and <unk> , and <unk> .
# and if you can do a , you can do a , , you can do a <unk> , or a <unk> ,
# so , a a , , a a , , a a , , a a , , a a , , a <unk> , , a <unk> ,
# so , 's a that that 's a that that 's a that that 's a .
# i think , as a way to say , as i
# so , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
# not not , not , not , not , not .
# now now , now , now .
# <unk> .
# and so , the the , , we , the the , , we , and we the the , , and we the the , and the <unk> , and the
# and so , , a little bit of a , , and a little bit of a , and a little bit of a .
# so if i was , , , if i was , ,
# what would look like me look like .
# so , the the , , , the , , , the , and , the <unk> .
# and can can can can <unk> the <unk> of the - <unk> , and can can can can <unk> <unk> .
# so the <unk> was the <unk> , so that 's the .
# and we still remain the the <unk> of our <unk> .
# and we can the the with the the , and with the <unk> , and the the
# and i was a <unk> <unk> , <unk> <unk> , <unk> <unk> , and <unk> <unk> , <unk> <unk> , <unk> <unk> , <unk> <unk> .
# and , the the , , the , the , , and the <unk> , and the <unk> , and the <unk> , and the <unk> , and <unk> .
# you can a a a a , and you a a a , and you a a a <unk> ,
# and , by the , , , and you can <unk> it by the <unk> , and you can .
# and can can their their and their their <unk> .
# so , we 're going to put this into this , and we 're going to to this .
# and what would we do to do that , and how we we do it ?
# and so , to have a lot of <unk> , and , and , and , and , and <unk> .
# now , do n't have to do that anymore .
# i 've got a . "
# if you 're a <unk> , , you get a <unk> , , you get a <unk> of the , , you know , the <unk> , the <unk> ,
# and so , , i , i , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and , and ,
# would it look like a a look like ?
# i 've been <unk> <unk> , <unk> , <unk> , <unk> <unk> , <unk> <unk> , <unk> <unk> .
the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> .
# why did they go to the ? ?
# so , , , , , , , and , and , and , and , and , and , and , and , and that 's <unk> .
# and so , the <unk> , the <unk> , , because the <unk> had <unk> <unk> , because they had the <unk> .
# you can give a <unk> on a <unk> of <unk> <unk> .
# the was was a <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> <unk> .
# the the of the <unk> of the <unk> <unk> , the <unk> <unk> of the <unk> .
# it was a little bit of the because it was a .
# and a a <unk> , a long - <unk> <unk> <unk> .
# the the - <unk> , the <unk> , the <unk> , the <unk> , and the <unk> .
# and the <unk> were the <unk> , and the <unk> .
# and what 's called a <unk> , a <unk> , a <unk> .
# we could n't - a - - - - - - - - - - - - - - - - - - - - - - - - - - - - - <unk> - <unk> - <unk> - <unk> - <unk> - <unk> - <unk> - <unk> -
# no more <unk> were n't <unk> on the .
# and the the , , the , the , the , , the , , the , , the , , the , , the <unk> , , the <unk> , , the <unk> , , the <unk> , , and the <unk> ,
# i remember , remember , remember , remember , remember ,
# i was looking at the the , and i saw the <unk> , and the <unk> , and the <unk> , and the <unk> .
# i was going to be the , that i had to be the , that i had to be the .
# so , 's a to a , , , a a , , , and a <unk> ,
# it 's all over .
# in the last case , the last <unk> , the last
# and , , , , , , , , and , and <unk> , , and <unk> , and <unk> , <unk> .
# and 's not the wrong with that .
# we have a and and <unk> .
# the the of the , the the the .
# what is happened ?
# in fact , the <unk> , , the <unk> , , , <unk> , , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> , <unk> .
# the , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> , the <unk> .
# and , , , , , , , , , and , and , and , and , and , and , and ,
# and that 's not enough to me .
# what 's not with with is not <unk> with .
# and <unk> <unk> <unk> <unk> <unk> , <unk> <unk> , <unk> <unk> .
# and , , , , , , , , , , , , , , , , , , , , and , , and , , and <unk> , , and <unk> , , and <unk> ,
# and , , , we can , we can do , , we can do a , , , and we can do n't , ,
# we 're not going to think of the large - scale .
# if we could fly , we want to fly .
# it 's actually designed a a . .
# so , to be a <unk> , , and it 's never going to be a <unk> , and
# so , there 's be a , , , , because there 's be a , ,
# we can not solve the , because we do n't solve the , because we do n't solve the .
# so , , , , , , , , , , , , , , , , , , , , , , , , , , , , , and <unk> , and <unk> ,
# and 's cheaper and <unk> and and and and <unk> and <unk> and <unk> and
# they can n't make the , , , and they can .
# and , the , of the , , , the <unk> of the , , , and <unk> , the <unk> of the <unk> , and <unk> , and <unk> , and <unk> <unk> , and <unk> .
# and the , the the , the the , the <unk> , the <unk> , and the <unk> , and the <unk> .
# so , , , , , , , , , , , , ,
# the the the that the the the the <unk> that the the <unk> .
# so , have have <unk> that have have <unk> that have have <unk> that have have <unk> that have have <unk> .
# and 's a , , , and , , and <unk> , , and <unk> , , and <unk> , <unk> ,
# we 're n't going to be the , because of the , , because we do n't get the .
# so , the the , of the , , , the , , , and the <unk> , , and the <unk> , the <unk> , , and the <unk> , the <unk> , the <unk> , and the <unk> ,
# and 's hard - <unk> .
# we ca n't n't do that with a problem .
# and we have to to to , , to have to , , and we need to be able to do it , , and we need to to be able to do it ,
# and the to to the , to the , to the , to the , to the , to the <unk> , to the <unk> ,
# and 's not a <unk> that 's can be in .
# and it 's , " the <unk> , " it says , "
# and the the , the <unk> , the <unk> , the <unk> .

# %% [markdown]
# ### Evaluate the default output

# %%
from bleu_check import bleu
ref_t = []
with open(os.path.join('../data','reference','dev.out')) as r:
    ref_t = r.read().strip().splitlines()
print(bleu(ref_t, results))
# Out:
# BLEU = 2.49 28.3/5.4/1.3/0.4 (BP = 0.854 ratio = 0.863 hyp_len = 21502 ref_len = 24902)

# %% [markdown]
# ## 2, Fixed attention
# ### For baseline 1, we fix the broken attention module by properly multiplying the hidden state with weight matrix and generate the attention after passing through a softmax function

# %%
import os
import re
import sys
import optparse
from tqdm import tqdm

import torch
from torch import nn

import pandas as pd
from torchtext import data

#import support.hyperparams as hp
#import support.datasets as ds

# hyperparameters
class hp:
    # vocab
    pad_idx = 1
    sos_idx = 2

    # architecture
    hidden_dim = 256
    embed_dim = 256
    n_layers = 2
    dropout = 0.2
    batch_size = 32
    num_epochs = 10
    lexicon_cap = 25000

    # training
    max_lr = 1e-4
    cycle_length = 3000

    # generation
    max_len = 50

    # system
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ---YOUR ASSIGNMENT---
# -- Step 1: Baseline ---
# The attention module is completely broken now. Fix it using the definition
# given in the HW description.
class AttentionModule(nn.Module):
    def __init__(self, attention_dim):
        """
        You shouldn't deleted/change any of the following defs, they are
        essential for successfully loading the saved model.
        """
        super(AttentionModule, self).__init__()
        self.W_enc = nn.Linear(attention_dim, attention_dim, bias=False)
        self.W_dec = nn.Linear(attention_dim, attention_dim, bias=False)
        self.V_att = nn.Linear(attention_dim, 1, bias=False)
        return

    # Start working from here, both 'calcAlpha' and 'forward' need to be fixed
    def calcAlpha(self, decoder_hidden, encoder_out):
        """
        param encoder_out: (seq, batch, dim),
        param decoder_hidden: (seq, batch, dim)
        """
        seq, batch, dim = encoder_out.shape
        wEnc = self.W_enc(encoder_out)
        wDec = self.W_dec(decoder_hidden)
        scores = self.V_att(torch.tanh(wEnc + wDec))
        # Permute to [Dim, batch, seq]
        scores = scores.permute(2, 1, 0)
        # Take softmax over Seq
        alpha = torch.nn.functional.softmax(scores, dim=-1)
        #print(alpha)
        return alpha

    def forward(self, decoder_hidden, encoder_out):
        """
        encoder_out: (seq, batch, dim),
        decoder_hidden: (seq, batch, dim)
        """
        alpha = self.calcAlpha(decoder_hidden, encoder_out)
        seq, _, dim = encoder_out.shape
        # Needs to be [batch, seq, dim] as when multipled by alpha pf [Dim, batch , seq]
        # We get [batch, 1, dim]
        encoder_out = encoder_out.permute(1, 0, 2)
        context = torch.matmul(alpha, encoder_out).reshape(_, 1, dim)
        #context = (torch.sum(encoder_out, dim=0) / seq).reshape(1, 1, dim)
        return context, alpha.permute(2, 0, 1)


# -- Step 2: Improvements ---
# Implement UNK replacement, BeamSearch, translation termination criteria here,
# you can change 'greedyDecoder' and 'translate'.
def greedyDecoder(decoder, encoder_out, encoder_hidden, maxLen,
                  eos_index):
    seq1_len, batch_size, _ = encoder_out.size()
    target_vocab_size = decoder.target_vocab_size

    outputs = torch.autograd.Variable(
        encoder_out.data.new(maxLen, batch_size, target_vocab_size))
    alphas = torch.zeros(maxLen, batch_size, seq1_len)
    # take what we need from encoder
    decoder_hidden = encoder_hidden[-decoder.n_layers:]
    # start token (ugly hack)
    output = torch.autograd.Variable(
        outputs.data.new(1, batch_size).fill_(eos_index).long())
    for t in range(maxLen):
        output, decoder_hidden, alpha = decoder(
            output, encoder_out, decoder_hidden)
        
        # I have no idea what dimension this alphas expects, just put the seq len in last place as 
        # the others are 1 anyways 
        alpha = alpha.permute(2,1,0)
        
        outputs[t] = output
        alphas[t] = alpha.data
        output = torch.autograd.Variable(output.data.max(dim=2)[1])
        if int(output.data) == eos_index:
            break
    return outputs, alphas.permute(1, 2, 0)


def translate(model, test_iter):
    results = []
    for i, batch in tqdm(enumerate(test_iter)):
        output, attention = model(batch.src)
        output = output.topk(1)[1]
        #pdb.set_trace()
        output = model.tgt2txt(output[:, 0].data).strip().split('<EOS>')[0]
        results.append(output)
    return results


# ---Model Definition etc.---
# DO NOT MODIFY ANYTHING BELOW HERE


class Encoder(nn.Module):
    """
    Encoder class
    """
    def __init__(self, source_vocab_size, embed_dim, hidden_dim,
                 n_layers, dropout):
        super(Encoder, self).__init__()
        self.hidden_dim = hidden_dim
        self.embed = nn.Embedding(source_vocab_size, embed_dim,
                                  padding_idx=hp.pad_idx)
        self.rnn = nn.GRU(embed_dim,
                          hidden_dim,
                          n_layers,
                          dropout=dropout,
                          bidirectional=True)

    def forward(self, source, hidden=None):
        """
        param source: batched input indices
        param hidden: initial hidden value of self.rnn
        output (encoder_out, encoder_hidden):
            encoder_hidden: the encoder RNN states of length len(source)
            encoder_out: the final encoder states, both direction summed up
                together h^{forward} + h^{backward}
        """
        embedded = self.embed(source)  # (batch_size, seq_len, embed_dim)
        # get encoded states (encoder_hidden)
        encoder_out, encoder_hidden = self.rnn(embedded, hidden)

        # sum bidirectional outputs
        encoder_final = (encoder_out[:, :, :self.hidden_dim] +  # forward
                         encoder_out[:, :, self.hidden_dim:])   # backward

        # encoder_final:  (seq_len, batch_size, hidden_dim)
        # encoder_hidden: (n_layers * num_directions, batch_size, hidden_dim)
        return encoder_final, encoder_hidden


class Decoder(nn.Module):
    def __init__(self, target_vocab_size,
                 embed_dim, hidden_dim,
                 n_layers,
                 dropout):
        super(Decoder, self).__init__()
        self.target_vocab_size = target_vocab_size
        self.n_layers = n_layers
        self.embed = nn.Embedding(target_vocab_size,
                                  embed_dim,
                                  padding_idx=hp.pad_idx)
        self.attention = AttentionModule(hidden_dim)

        self.rnn = nn.GRU(embed_dim + hidden_dim,
                          hidden_dim,
                          n_layers,
                          dropout=dropout)

        self.out = nn.Linear(hidden_dim * 2, target_vocab_size)

    def forward(self, output, encoder_out, decoder_hidden):
        """
        decodes one output frame
        """
        embedded = self.embed(output)  # (1, batch, embed_dim)
        context, alpha = self.attention(decoder_hidden[-1:], encoder_out)
        # 1, 1, 50 (seq, batch, hidden_dim)
        rnn_output, decoder_hidden =\
            self.rnn(torch.cat([embedded, context], dim=2), decoder_hidden)
        output = self.out(torch.cat([rnn_output, context], 2))
        return output, decoder_hidden, alpha


class Seq2Seq(nn.Module):
    def __init__(self, fields=None, srcLex=None, tgtLex=None, build=True):
        super(Seq2Seq, self).__init__()
        # If we are loading the model, we don't build it here
        if build is True:
            self.params = {
                'srcLexSize': len(srcLex.vocab),
                'tgtLexSize': len(tgtLex.vocab),
                'embed_dim': hp.embed_dim,
                'hidden_dim': hp.hidden_dim,
                'n_layers': hp.n_layers,
                'dropout': hp.dropout,
                'fields': fields,
                'maxLen': hp.max_len,
            }
            self.build()

    def build(self):
        # self.params are loaded, start building the model accordingly
        self.encoder = Encoder(
            source_vocab_size=self.params['srcLexSize'],
            embed_dim=self.params['embed_dim'],
            hidden_dim=self.params['hidden_dim'],
            n_layers=self.params['n_layers'],
            dropout=self.params['dropout'])
        self.decoder = Decoder(
            target_vocab_size=self.params['tgtLexSize'],
            embed_dim=self.params['embed_dim'],
            hidden_dim=self.params['hidden_dim'],
            n_layers=self.params['n_layers'],
            dropout=self.params['dropout'])
        self.fields = self.params['fields']
        self.maxLen = self.params['maxLen']

    def forward(self, source, maxLen=None, eos_index=2):
        """
        This method implements greedy decoding
        param source: batched input indices
        param maxLen: maximum length of generated output
        param eos_index: <EOS> token's index
        """
        if maxLen is None:
            maxLen = self.maxLen
        encoder_out, encoder_hidden = self.encoder(source)

        return greedyDecoder(self.decoder, encoder_out, encoder_hidden,
                             maxLen, eos_index)

    def tgt2txt(self, tgt):
        return " ".join([self.fields['tgt'].vocab.itos[int(i)] for i in tgt])

    def save(self, file):
        torch.save((self.params, self.state_dict()), file)

    def load(self, file):
        self.params, state_dict = torch.load(file, map_location='cpu')
        self.build()
        self.load_state_dict(state_dict)

class DataFrameDataset(data.Dataset):
    """Class for using pandas DataFrames as a datasource"""
    def __init__(self, examples, fields, filter_pred=None):
        """
        Create a dataset from a pandas dataframe of examples and Fields
        Arguments:
            examples pd.DataFrame: DataFrame of examples
            fields {str: Field}: The Fields to use in this tuple. The
                string is a field name, and the Field is the associated field.
            filter_pred (callable or None): use only exanples for which
                filter_pred(example) is true, or use all examples if None.
                Default is None
        """
        fields = dict(fields)
        self.examples = examples.apply(
            SeriesExample.fromSeries, args=(fields,), axis=1).tolist()
        if filter_pred is not None:
            self.examples = filter(filter_pred, self.examples)
        self.fields = dict(fields)
        # Unpack field tuples
        for n, f in list(self.fields.items()):
            if isinstance(n, tuple):
                self.fields.update(zip(n, f))
                del self.fields[n]

class SeriesExample(data.Example):
    """Class to convert a pandas Series to an Example"""

    @classmethod
    def fromSeries(cls, data, fields):
        return cls.fromdict(data.to_dict(), fields)

    @classmethod
    def fromdict(cls, data, fields):
        ex = cls()

        for key, field in fields.items():
            if key not in data:
                raise ValueError(
                    f"Specified key {key} was not found in the input data")
            if field is not None:
                setattr(ex, key, field.preprocess(data[key]))
            else:
                setattr(ex, key, data[key])
        return ex

def biload(src_file, tgt_file, linesToLoad=50000, verbose=False):
    src = open(src_file).read().lower().strip().split("\n")
    tgt = open(tgt_file).read().lower().strip().split("\n")
    return list(map(lambda x: (x[0].strip().split(), x[1].strip().split()), zip(src, tgt)))[:linesToLoad]


def bitext2Dataset(src, tgt, srcLex, tgtLex,
                   linesToLoad=50000, maxLen=hp.max_len):
    data = biload(src, tgt, linesToLoad=linesToLoad, verbose=False)
    data = [(f, e) for f, e in data if len(f) <= maxLen and len(e) <= maxLen]
    data = {'src': [f for f, e in data],
            'tgt': [e for f, e in data]}

    df = pd.DataFrame(data, columns=["src", "tgt"])
    dataset = DataFrameDataset(df, [('src', srcLex), ('tgt', tgtLex)])
    return dataset

def loadData(batch_size, device=0,
             trainNum=sys.maxsize, testNum=sys.maxsize):
    def tokenize(x):
        return x.split()

    srcLex = data.Field()
    tgtLex = data.Field(init_token="<SOS>", eos_token="<EOS>")

    train = bitext2Dataset('./data/train.tok.de',
                           './data/train.tok.en', srcLex, tgtLex,
                           linesToLoad=trainNum)
    val = bitext2Dataset('./data/val.tok.de',
                         './data/val.tok.en', srcLex, tgtLex)
    test = bitext2Dataset('./data/input/dev.txt',
                          './data/reference/dev.out', srcLex, tgtLex,
                          linesToLoad=testNum,
                          maxLen=sys.maxsize)

    srcLex.build_vocab(train.src, max_size=hp.lexicon_cap)
    tgtLex.build_vocab(train.tgt, max_size=hp.lexicon_cap)

    train_iter, = data.BucketIterator.splits(
        (train,),
        batch_size=batch_size,
        sort_key=lambda x: len(x.src),
        device=device,
        repeat=False)

    val_iter, = data.BucketIterator.splits(
        (val,),
        batch_size=batch_size,
        device=device,
        repeat=False)

    test_iter = data.Iterator(
        test,
        batch_size=1,
        device=device,
        sort=False,
        sort_within_batch=False,
        shuffle=False,
        repeat=False)

    return train_iter, val_iter, test_iter, srcLex, tgtLex

def loadTestData(srcFile, srcLex, device=0, linesToLoad=sys.maxsize):
    def tokenize(x):
        return x.split()
    test = bitext2Dataset(srcFile,
                          srcFile, srcLex, srcLex, linesToLoad,
                          maxLen=sys.maxsize)
    test_iter = data.Iterator(
        test,
        batch_size=1,
        device=device,
        sort=False,
        sort_within_batch=False,
        shuffle=False,
        repeat=False)
    return test_iter

# %% [markdown]
# ### Run the fixed attention soltution the dev.

# %%
model = Seq2Seq(build=False)
model.load(os.path.join('../data', 'seq2seq_E049.pt'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# loading test dataset
test_iter = loadTestData(os.path.join('../data', 'input', 'dev.txt'), model.fields['src'],
                            device=device, linesToLoad=sys.maxsize)
results = translate(model, test_iter) # Warning: will take >5mins depending on your machine
print("\n".join(results))
# Out:
# 1305it [00:57, 22.78it/s]
# when when i was in my 20s , i had my first <unk> . .
# i was a and i was particularly in berkeley . berkeley .
# she was a a woman woman named alex .
# when the came came up the first first , she came up and she a a a , and she fell into the couch in my office , <unk> her her and and told me , about about about .
# and when i heard this , i was was .
# my my , , had a a patient patient for a first patient .
# and i got a woman in the people who wanted to talk about about .
# i 'll leave that , i thought , .
# but i did n't have it .
# with the the stories , that alex opened into the , was easy easy to me just to with with head , while we were the problems .
# " 30 is the new 20 " , " alex , and as far as i did , i had right .
# work came later later , later came later later , later came later later later later came later later .
# people people in the the , and alex , and i did n't have time .
# and this distance is smaller , smaller and smaller smaller smaller , and now it 's smaller than a millimeter that 's a a a a , and computers and for are become for every . .
# but i wondered , how would it be no limit .
# i i looked like what would look like .
# first first i 've this tool tool that i into the digital world , so if you put on on the screen , it it 's the physical physical . .
# designers designers can put their ideas directly into 3d and and surgeons and to to to the at the screen .
# so this tool , the tool was so the .
# but our hands still remain outside the the .
# how can we do with the with the digital information with the digital information and and the the the the of our hands hands ?
# in microsoft , i 've done with my mentor , <unk> <unk> , computer computer computer and a a little room in the keyboard in a keyboard .
# so that that a apple screen and screen and the the the of the fingers and fingers face , and you can put his hands on the keyboard , the the the and the with the hands hands .
# and windows windows and put a position position in the room room , you can just pick it as easy to you a a book from a shelf .
# then you can through through this book and and you and and and and , and all this this , the the of of the <unk> .
# architects can can their their their their hands both their hands hands and and .
# so in these two examples , we 're going to digital digital .
# but how would we take that all the time and the digital information that we us ?
# i 've sure many of you have already already to to articles online online later later .
# but now you have to worry about it .
# here i have a " <unk> . "
# this is the view of you , you a a of your head or a your car , or the your system system the geometry of the body .
# this this idea , i started thinking about it , the idea of the just not just in the space , but it 's but it can make them and and and feel .
# how would a look like a future ?
# in mit media media lab , i 've with my my <unk> <unk> and my collaborators , and i 've been a a .
# now , in this case , this is is is like a tiny - in in our world , which means that computers computers , and people can see this object everywhere , at least small little of these .
# effectively , we have the gravity and and control control the by by magnetic magnetic , , and and these these . .
# by adding the object , , we we it it from the the through the and and time , and it 's possible to move movements movements and and and and and in in the real world .
# so example can can can can be over - visual - , or or the , , or , , and and again in the real world .
# students can use this to use complex concepts of learning and physics physics and and , and a , or a , or a is a a and and experience that experience and and and and it 's very powerful .
# and more than that , just as we we have now in the computer , it 's to imagine how the the of the world is actually transform our daily activity .
# as you can can , , digital will not only not only us us to show us with our interact with our as our part physical physical , , ourselves ourselves of ourselves .
# today , we 've started starting by talking about borders borders , but if we remove the limit , the only frontier is our imagination .
# thank you very much .
# i was been to to for two years to become a <unk> , in china , china , in the 1970s .
# when i was in the first grade , i wanted to get government government to school for school , all the paid paid paid .
# but my mother said , " no . "
# my parents wanted to me to engineer .
# after they they the the , they believed they were that the only way to happiness happiness , and safer , good job .
# it 's not important if i do n't have the job or or .
# but my dream was to be a chinese . .
# i 'm that i i on my my my my .
# a a has to do with a very early way , so i i tried to to try to go to the . .
# i wrote even the the the the and and the to the the of a .
# but the adult does n't give my idea .
# the adults did n't believe it was me to me .
# only my friends had me me , but they were also just as much , as i am myself .
# and with 15 years i knew i was to old to to with with the training .
# so my dream would never be true .
# i was afraid of fear that i could only only could to the rest of my life .
# but that 's so that 's .
# so i had to look at the head , and i could find another . .
# no one there to me me , me well , too well .
# so i i to to . .
# i <unk> my hunger to <unk> <unk> , with a book and a " the <unk> of " i was my my in the , , the <unk> tradition , " " " " " " " " in " the " " " " " " " been inspired
# [ " <unk> <unk> " ] " " " " " " " from <unk> <unk> , i came to the united states , and what did i read first ?
# of course , books that are in banned .
# " the good earth " " from life life of the chinese . .
# it 's just not just as propaganda . i understood .
# the <unk> - a - a - a - long - century series of technological . .
# from the first half of the 20th century , the the and the and the and , and a vaccine against against . .
# the middle in the middle century polio and smallpox eradicated .
# technology seemed to to something about what 's called a <unk> <unk> a " <unk> . "
# for most of the human history , we could n't even faster than a horse or a a boat with a , , but in the year , the apollo was 10 10 miles per hour per hour .
# since 1970 1970 , no human have been on on the moon .
# no one has ever faster faster than the the of apollo apollo , and the optimism optimism is about the power of technology , and we 've had to technology technology to to clean clean clean energy , or to save the world 's hunger , seem to seem to
# i remember remember as a <unk> , , i i as a
# the the of the apollo 17 , and my mother me me me , not too to the very <unk> <unk> .
# i had a idea that was the last last , but i was sure that i was going to be in in my life life .
# the <unk> <unk> " something something with our ability to deal with big problems with technology , become a .
# you hear it everywhere .
# we 've it in the last two days days . ted .
# it 's a that that if us had us to and and and ourselves themselves with with with , with with things like things and and and and and social media and social media , or algorithms , the .
# it 's nothing wrong wrong with the of these things .
# they have our our lives and and . .
# but they do n't solve the big problems of humanity .
# what happened ?
# there 's a a explanation explanation silicon silicon silicon silicon where where you 've been that in in recently , we 've been doing more than than in the years , intel intel , microsoft , apple apple and apple .
# in silicon valley valley , you are used to be , in particular , the <unk> , the company companies .
# silicon valley says that that that of of have gone to to lead to to the ideas , and and , and problems problems problems problems .
# but this explanation is not not enough enough .
# it explains mainly what does n't silicon with silicon .
# even even their their times times small times small , tiny , , 10 years ago , a a 10 years 10 years .
# investors had always been thinking of energy technologies in technologies like energy energy that are a a and and development development and and , never never never never never ever been the the development of the problems problems without having to value .
# no , the reasons reasons why we ca n't solve a problem , , complicated complicated and more . .
# sometimes we decide not to to the big problems .
# we could fly to mars mars , if we want .
# nasa , even has a plan .
# but to to , a political policy would be public public public public , and so it 's never going to happen to
# we 're not going to fly to mars because everybody thinks that there are be done on the earth 's stuff that have to be done .
# another time we ca n't solve the big problems because because our political systems are fail .
# today , less than two percent of the earth 's earth , from sources sources , solar wind wind wind wind , wind and wind , less than two percent , and the reason is is very small .
# coal and gas are cheaper than solar wind wind wind and wind and efficient is cheaper than <unk> .
# we all want to alternative alternative that can keep the <unk> , but it 's no . .
# now it 's so , , , and and and and all of all the the same opinion of what national national and international international development , to : : mainly a lot of economic development in the development and development and and and and a price of carbon .
# but in the current political climate , there is no hope that the u.s. of the u.s. or or the international the international the these the and and and .
# sometimes are problems problems problems that sounds like , , not not .
# it 's been believed that that the is going on the .
# but 30 years of research have taught us that political political political political impact impact impact impact .
# technologies technologies can things like like like or systems systems systems systems like systems and and and and , and , but it 's going to be a , , there are no governments .
# eventually , , large problems sometimes the solutions solutions because we do n't understand understand the problem .
# president , the was told the war war war war , but you discovered discovered that there were many of of of the that are of of of against therapy , and only only years , , , , , be be in the .
# difficult problems are difficult .
# it 's not true that we ca n't solve the problems with with technology .
# ...
# we have tools to how we <unk> , and we hope hoping that help help , but i 'm also asking whether whether 's 's going to be , when we 're at the same time , active or , , , our our , , to their their .
# the <unk> is a means that we can do something very important , and i 'm talking to to the the .
# i think we need to do our very simple idea of a picture of
# the definition of the is already changing changing .
# once the , the , the , directly to to over the over , and while , and his moves changed and and towards the west , , he 's the city .
# so how do you find a city city in a a . .
# they 're to find to find the equivalent to find the needle in the , , with with eyes and <unk> .
# so we used to <unk> - to - map map a map of the landscape to see to see a , changes ,
# where the the of the the used to be used .
# but you see , , and this is very interesting , this slightly <unk> of , , with with the circle that we us as a possible position for the city .
# so we worked with with scientists scientists to to <unk> what you see here .
# this is like <unk> ice in ice ice , just instead of the layers , change , climate change , you can , layers , your human . .
# in a depth of five meters , under a layer layer of , , we found a density layer from <unk> .
# this shows that that that this position position position for space , in five meters , , we we can produce more over several hundred years of <unk> , to to to the to rich , to the to the to the the that we we existence existence existence .
# we found <unk> <unk> -- <unk> , <unk> , <unk> and <unk> -- and what shows that that shows a a .
# it might not seem to look at much , but if you look at the <unk> stones , which were used by the in the in the , , you find exactly the . .
# so we found a density layer of the <unk> of at this that that that 's on the rich rich .
# we also found evidence for a for for the community society , which shows that that this is a very important city .
# but there 's no longer , , but we 'll going to get to these these soon , to to a a .
# what 's important , we we to teach for young young who who are in the school , so they 're so to have to make great discoveries .
# so i wanted to be my with my <unk> from the middle of the , , it was in the the city of <unk> <unk> years ago ago .
# " knowledge knowledge sharing is the biggest of of the . .
# there 's nothing in this in the . "
# ted was n't 1984 1984 1984 .
# ideas , , , actually , in 1984 , in a long long , , , from <unk> .
# you can see that the the the the the the the the the the .
# thank you very much .
# thank you .
# i grew up in taiwan as a daughter of a , , to my my memories , my my my my my my my my , the the , the , and the form of the chinese .
# i was , , i was fascinated by this this language .
# but for a , , it seems to as the as the great wall of china .
# i 've been wondering how i 've been able to do this wall , so everyone anyone to understand the interest of this complex , this , and understand and and .
# i thought that was a new way of learning , to be . .
# since five , the , i learned every single single every single every single in every single in the .
# in the next 15 years , i 've every new new new . .
# because we have just five minutes to have a , and very difficult , very difficult .
# a chinese <unk> has about about 20,000 . .
# you need need 1,000 for a a . .
# the most 200 200 are giving them to 40 percent of the simple literature , to understand -- -- enough enough to <unk> the <unk> , and and the the the the of the time .
# today , i start with eight eight to show you how the method works .
# are you ready ?
# open your mouth as far as it until it 's . .
# it 's going to " a mouth . "
# this person goes to a . .
# " human . "
# when the <unk> for for fire fire , a " with a person , if he was saying , " help ! i ! ! -- and the 's is going to the the of the , but i like this idea . you take the the the you you
# this is a tree .
# " tree . "
# this is a mountain .
# the sun is . "
# the moon . "
# the <unk> for for " the looks like a <unk> from from the . .
# these eight are are . .
# they are the <unk> to create a variety of .
# a human .
# if someone else is , , then it means " follow . "
# and then , more , , " and " " " and " a " . "
# if a human his his poor , , " he says , " it was so big . "
# the person in the mouth , it 's like . .
# he 's a " , " as a in the whale .
# a tree is a tree tree , two trees are a for a " . "
# three are together for a " forest . "
# and they put a a under under tree tree and they have a " . "
# if you put up a mouth , it it means " <unk> . "
# just to to because because a is a is a is a .
# do you remember that fire ?
# two two two black people are hot .
# three fire fire together together a lot of . . "
# they put the fire under two trees , it it " " . "
# for us , the sun is the source of the .
# two two together together together . "
# three are together together . "
# when the sun and the moon , it means " it 's " . "
# in the context , it 's be for for the next day .
# the sun goes across the horizon horizon .
# door . a a in the door stands to the the . "
# so , put a mouth in the door , it says , " ask questions . "
# <unk> , <unk> . is there there ?
# this person <unk> from the door . " " " " "
# the left is the the woman .
# two women are two for a " . "
# so , in three women , this is called " <unk> . "
# we have now 30 of . .
# and with this method , you can put the in the first eight words .
# so the next group of eight eight are are in with other words .
# so with a little bit of a few hundred , you can learn how a child - old child .
# when we can make these , , we start to them them .
# for example , it makes a and and fire , so , "
# we know , japan is the land of the sun sun .
# this is the sun with the " " " because japan because of africa is china .
# one is with the is called the " " . " japan . "
# a human being a ?
# a japanese japanese . "
# the are the the on the left are two mountains .
# in chinese chinese , it 's " " , chinese chinese , her political chinese in the dark of the mountains .
# today , " " " " . . "
# a mouth says says where it 's , , " it 's " . "
# that 's the slide that reminds me of the stage , thank you very much .

# %% [markdown]
# ## Evalution score for the fixed attention module leads to a score of 17.11 :)

# %%
from bleu_check import bleu
ref_t = []
with open(os.path.join('../data','reference','dev.out')) as r:
    ref_t = r.read().strip().splitlines()
print(bleu(ref_t, results))
# Out:
# BLEU = 17.11 54.0/24.1/12.0/6.5 (BP = 0.957 ratio = 0.958 hyp_len = 23858 ref_len = 24902)

# %% [markdown]
# ## 3, Beam search
# ### Extension: now we replace the greedy decoder with beam search

# %%
import pdb
import collections 


class Decoder(nn.Module):
    def __init__(self, target_vocab_size,
                 embed_dim, hidden_dim,
                 n_layers,
                 dropout):
        super(Decoder, self).__init__()
        self.target_vocab_size = target_vocab_size
        self.n_layers = n_layers
        self.embed = nn.Embedding(target_vocab_size,
                                  embed_dim,
                                  padding_idx=hp.pad_idx)
        self.attention = AttentionModule(hidden_dim)

        self.rnn = nn.GRU(embed_dim + hidden_dim,
                          hidden_dim,
                          n_layers,
                          dropout=dropout)

        self.out = nn.Linear(hidden_dim * 2, target_vocab_size)

    def forward(self, output, encoder_out, decoder_hidden):
        """
        decodes one output frame
        """
        embedded = self.embed(output)  # (1, batch, embed_dim)
        context, alpha = self.attention(decoder_hidden[-1:], encoder_out)
        # 1, 1, 50 (seq, batch, hidden_dim)
        rnn_output, decoder_hidden =\
            self.rnn(torch.cat([embedded, context], dim=2), decoder_hidden)
        output = self.out(torch.cat([rnn_output, context], 2))
        return output, decoder_hidden, alpha
    
    

    
########################################################
# class for storing the topk nodes during beam search
########################################################
class TopKNode(object):
    def __init__(self, parent, word_id, score, decoder_hidden):
        self.parent = parent
        self.word_id = word_id
        self.score = score
        self.decoder_hidden = decoder_hidden
        



def greedyDecoder(decoder, encoder_out, encoder_hidden, maxLen, eos_index):
    seq1_len, batch_size, _ = encoder_out.size()
    target_vocab_size = decoder.target_vocab_size
    topk = 25
    # get initial decoder input values
    outputs = torch.autograd.Variable(encoder_out.data.new(maxLen, batch_size, target_vocab_size))
    alphas = torch.zeros(maxLen, batch_size, seq1_len)
    decoder_hidden = encoder_hidden[-decoder.n_layers:]
    output = torch.autograd.Variable(outputs.data.new(1, batch_size).fill_(eos_index).long())
    # create initial node
    node = TopKNode(None, output, 0, decoder_hidden)
    # insert initial node to queue
    topk_nodes = collections.deque()
    topk_nodes.append(node)

    for t in range(maxLen):
        # per top-k words
        score_list= []
        decoder_h_list = []
        saved_topk = []
            
        for k in range(len(topk_nodes)):
            # remove and return one topk node
            current_node = topk_nodes.pop() 
            saved_topk.append(current_node) # temporally save parent 
            decoder_hidden = current_node.decoder_hidden 
            output = current_node.word_id
            # get new output score and hidden state
            score, decoder_hidden, alpha = decoder(output, encoder_out, decoder_hidden)
            score = score.squeeze() # convert [1,1,25004] ==> [25004]
            # pass through softmax to get prob
            score = torch.nn.functional.softmax(score, dim=-1)
            logP = torch.log(score)
            score_old = current_node.score
            # add logP
            score_list.append(logP+score_old)
            decoder_h_list.append(decoder_hidden)
        assert len(topk_nodes) == 0  
        
        # convert score list to tensor
        scores = torch.stack(score_list)  # k x 25004
        hs = torch.stack(decoder_h_list)  # k x 2 x 1 x 256
        
        # rank scores
        topk_scores = scores.view(-1).data.topk(topk)
        topk_bins = topk_scores[1] / 25004
        topk_words = topk_scores[1] % 25004
        
        # insert new topk nodes
        for k in range(topk):
            parent_idx = topk_bins[k]
            new_parent = saved_topk[parent_idx]
            output = topk_words[k].reshape(1,1)
            # early stopping
            #if int(output.data) == eos_index:
                #break
            new_node = TopKNode(new_parent, output, topk_scores[0][k], hs[parent_idx])
            topk_nodes.append(new_node)
        assert len(topk_nodes) == topk
        
    best_score = topk_nodes[0].score # best score should be the first one
    for node in topk_nodes:
        assert best_score >= node.score
    
    # raytrace path from best node
    best_node = topk_nodes[0]
    output = []
    output.append(best_node.word_id)
    ptr = best_node.parent
    while ptr != None:
        output.append(ptr.word_id)
        ptr = ptr.parent
    # need to flip it, originally in reverse order
    return_value = torch.flip(torch.LongTensor(output), [0]) 
    # ignore first dummy node
    return_value = return_value[1:51].reshape(50,1,1)   
    
    return return_value





def translate(model, test_iter):
    results = []
    for i, batch in tqdm(enumerate(test_iter)):
        output = model(batch.src)
        output = model.tgt2txt(output[:, 0].data).strip().split('<EOS>')[0]
        results.append(output)
    return results





model = Seq2Seq(build=False)
model.load(os.path.join('../data', 'seq2seq_E049.pt'))
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
model.eval()
# loading test dataset
test_iter = loadTestData(os.path.join('../data', 'input', 'dev.txt'), model.fields['src'],
                            device=device, linesToLoad=sys.maxsize)
results = translate(model, test_iter) # Warning: will take >5mins depending on your machine
print("\n".join(results))
# Out:
# 1305it [18:42,  1.16it/s]
# when when i was in my 20s , i had my first <unk> . .
# i was a , and i studied in berkeley . berkeley .
# she was a woman woman named alex .
# as soon as the first arrived came , , she came up , and she was a a , and she fell into my office in my office , <unk> her , and she told me to talk about about <unk> .
# and when i heard this , i was <unk> .
# i mean , my <unk> had had a a patient patient as a first patient .
# and i got a woman in the people who wanted to talk about about . .
# i 'll leave it , i thought .
# but i did n't have it .
# with the the stories , the alex came into the the , it was easy easy to me , just to deal with head , as we faced the problems .
# " 30 is the new 20 " , " alex alex , and as far as i did , they had right .
# work came later later , later came later , later came later later , later came later later .
# this is equally true for <unk> , <unk> , or or <unk> , a good conversation , a beautiful beautiful , a beautiful a can be a tremendous impact for years and even over generations generations .
# this is an idea that all all should be the that that knows her .
# it 's just as easy to know what i said to .
# i 've got privilege privilege this day as a every day : the the are are not the new power , so you 're on , you know , a a , , you use your your own your own family . your family .
# do n't tell you what you do n't know , or not not .
# your your right now now your life .
# thank you very much .
# in the entire industry , it was always our goal to connect the between between and and information information , the gap between our physical world and and the world on the screen where we can our our imagination .
# and this distance is smaller , smaller and smaller smaller smaller , and now it 's smaller than a millimeter , which is a a of a <unk> , and computers are for every . .
# but i wondered what it would be if there was no limit at all .
# i looked at what would would look like .
# first , i 've developed this tool , which is into the digital world , so if you focus on on the screen , , it it to the physical character .
# designers designers can put their ideas directly directly into 3d 3d surgeons and surgeons can be at at the at the bottom of the screen .
# so with that tool , the limit was so the . .
# but our hands still remain the outside of the . .
# how can we connect with with the digital information with the digital information and and the the the of our hands of our hands ?
# at microsoft microsoft , i 've worked with my mentor , <unk> <unk> , the computer computer and a a little room on the keyboard in a digital <unk> .
# so that means that a computer screen and screen to make the the of of fingers and face face , you can now put his hands on the keyboard , the the , and with with their hands hands .
# and windows windows and put a position position in the room room , you can you so easily as you can a a book from a shelf .
# and then you can get through through this book and and it and and and and , and all this this on the the of of <unk> . .
# architects can can their their their their their hands both their hands hands .
# so in these two examples , we can go into the digital world .
# but how if we do it all the time and the digital information instead of us us ?
# i mean , many of you have already made this to articles articles online and later . .
# but now you do n't have to worry about that anymore .
# here i have a " <unk> . "
# so this view is going to get you through a head on your head , or <unk> , or when your system is the geometry the geometry of our body .
# this this idea idea , i began to think about this , which is n't just in the space in the room , but they make it up , so that we can make them and and them .
# how would it look like a future future ?
# in mit with media media lab , i with with my my <unk> <unk> and my collaborators <unk> , i 've created a <unk> . .
# now , in this case , this is is is just like a tiny - in in our world , and that means that computers computers , as humans are able to move this object everywhere -- at least in that little bit of .
# effectively , we have gravity gravity gravity and control control motion by creating magnetic magnetic , , and and combine these these . .
# by doing this the digital digital program , we 're using it from the constraints through space and time , and we can move human movements now , and and and and permanent in the real world .
# so example , as can can can can can be taught , , or or , , and , , and , and again in the real world .
# students can use this in order to learn complex concepts of physics and physics physics and , and unlike , or <unk> , or this is a a and and experience experience that can touch and and , and it 's very powerful .
# and even more , than just what we have now in the computer , it 's to to imagine how the code of the world is actually transform our daily activity .
# as you can , , digital digital information will not only us us to show us to interact with interact with us as part of our physical environment , without ourselves ourselves of our physical world .
# today , we started starting by talking about borders borders , but if we remove the limit , it 's the only frontier in our imagination .
# thank you very much .
# i was been to for two years to become a <unk> , in china , china , in the 1970s .
# when i was in the first grade , i wanted to get the government to a school for school , all all paid paid . .
# but my mother said , " no . " . "
# my parents wanted wanted me to engineer it .
# after they they the the , , they believed that that the only way to happiness happiness is a safer and good job job .
# it 's not important if i do n't have the job or not .
# but my dream was to become a chinese <unk> .
# that 's me i i on on my my my .
# it has a very to to start with the start , so so i i tried to try to go to the . .
# i actually wrote the on the the , and on the side of a <unk> . .
# the mall is in in the the world , and it 's very efficient , because it 's in the middle realm in the arts of art , architecture and religion and religion .
# and always knew that the the of of <unk> would go down to the near the the , , from the two two , here , with the red red , , but somewhere in this massive . .
# this area is huge -- it 's four times four times three times .
# at the same time , the the directly directly to over <unk> <unk> , and while the rest changed changed , and moving towards the west , , he town the city .
# so how do you find a a city city in an individual landscape .
# they happened to be able to find the equivalent to find the needle in the brain , with with eyes and <unk> .
# that 's why we used <unk> <unk> to map a map of the landscape to order to be able to see changes .
# where the price of the <unk> used to be used .
# but you can see , , and it 's very interesting to see this easy <unk> , , , with the circle that us us as a possible position for the city city .
# so we worked with with scientists scientists together to see what what you can see here .
# it 's like <unk> ice in ice ice , just instead of the layers , change , climate change , you search layers , your human . .
# in a depth of five meters , under an thin layer of , , we found a density layer from <unk> .
# and it shows that that of this possible position position position , for five meters , in five meters , we can find a over a hundred hundred hundred years , to up to the rich realm , to the to to the <unk> that we get the existence of
# we found <unk> <unk> -- <unk> , <unk> , <unk> and <unk> -- -- which shows shows that here has a chicken . .
# it does n't seem to look like much , but if you look at the <unk> stones , which were being used by <unk> in in the rich , you find exactly these stones .
# so what we found is a density layer of of the that that that on the rich rich . .
# we also found some evidence for a <unk> for the society society , which shows showing that there was a very important city .
# but it did n't get there yet , but we 're going to get back to these new soon to to a a map .
# what 's more important , we used to <unk> for young young who who are in in school , so that they are able to make great discoveries .
# that 's why i wanted to leave with my <unk> from from the middle , -- it may be <unk> in the city of <unk> <unk> years ago .
# " knowledge knowledge sharing is the biggest of .
# there 's nothing happening in the . "
# ted was n't 1984 in 1984 . .
# ideas ideas , in fact , actually did n't even know about a long long ago , <unk> from <unk> . .
# you can be able to compare the the on the the in the the .
# thank you very much .
# thank you .
# i grew up in taiwan as an daughter of a teacher , to my beautiful memories , , like my mom to me the beauty , the the and the form of chinese chinese .
# after all , i was fascinated by this incredible language .
# but for a a , it seems to be as like the great wall of china .
# so in the last few years , i 've been wondering how i can get this wall , so everyone anyone who has to be interested in this complex , , and understand and understand . .
# i thought that was a new method way to learn chinese . .
# since the five , i 've learned every single single every single every single in every in the right . .
# in the next 15 years , i gave every new new every day .
# there 's only five minutes for have to have a , and it 's very useful .
# a chinese <unk> has about about 20,000 . .
# you only need 1,000 thousand for a simple <unk> .
# the most 200 200 to give them 40 to 40 percent of the simple literature , it 's enough enough to enough enough <unk> , and , and and the the of the time .
# today , let me start with eight eight to show you how the method works .
# are you ready ?
# open your mouth as possible , until it 's . .
# it 's going to be a mouth . "
# that person goes down .
# " human . "
# when the <unk> for for fire fires a person with a poor , like if he came up with me , " help ! ! ! -- and it 's going to take off the the of the , , but i like this idea . you take the the
# this is a tree .
# " tree . "
# this is a mountain mountain . "
# the sun is . "
# the moon moon . "
# the <unk> for the door " looks like a <unk> from from the the west .
# these eight eight are radical .
# they are the <unk> to create a variety of .
# a human .
# if if someone else is someone , , it means " follow follow . "
# there are more , then , " " , " and " a a . . "
# if human person his his poor , he says , " man , " it was so big . "
# the human person in mouth , it 's like <unk> .
# he 's a " , " as the in in the whale .
# there 's a tree tree for a tree , two trees are standing for a <unk> . . "
# three are three together for a " forest . "
# and they put it under a tree under the tree , and they have a " base . "
# if you put up on your mouth , it 's called " <unk> . "
# just want to remember because because a is tree is a <unk> . .
# do you remember that fire ?
# two two two people are called hot . "
# three fire fire together a lot of . . "
# they put the fire under two trees , it means " " . "
# for us , the sun is the source of the . .
# two two two together together . "
# three are together together . "
# when the sun and the moon together , it means " " . "
# in the context , it will be for for the next day .
# the sun goes across the horizon horizon .
# door . a guy in the door stands to the <unk> . . "
# you put a mouth in the door , it says , " ask questions . "
# <unk> <unk> , <unk> . is somebody there ?
# this person <unk> from the door . " " " , " . "
# the left on the left is the woman .
# two women are stand for one one . "
# for example , three women , this is called " <unk> . . "
# we 've now 30 30 . .
# with this method , you can put it in the first eight other words words .
# so the next group of eight eight are up with other words words .
# with a little bit , you can learn a hundred hundred of how a child - old child . .
# when we can make these , , we start to them them .
# for for instance , mountain and and fire , so it 's a "
# we know , japan is the land of the sun sun .
# this is the sun with the " origin , because because japan is happening by china .
# there 's a sun called the origin called " japan . "
# is a person to japan ?
# a japanese japanese . "
# the white on the left are two mountains <unk> .
# in chinese chinese , it 's written , " chinese chinese , their political chinese in the dark of the mountains .
# today is called " <unk> . . "
# a mouth says the says where it says , stands . "
# that 's the slide that reminded me on the stage . thank you very much .

# %% [markdown]
# ## Evalution score for beam search module leads to a score of 19.62 :)

# %%
from bleu_check import bleu
ref_t = []
with open(os.path.join('../data','reference','dev.out')) as r:
    ref_t = r.read().strip().splitlines()
print(bleu(ref_t, results))
# Out:
# BLEU = 19.62 55.2/26.5/14.1/8.0 (BP = 0.972 ratio = 0.973 hyp_len = 24222 ref_len = 24902)

# %% [markdown]
# ## 4, Final version, process of the unk tokens and repeated tokens

# %%
print(results[0])
prevWord = None
allnew = []
for res in results:
    newRes = []
    for word in res.split(" "):
        if prevWord is not None:
            if word == prevWord:
                prevWord = word
                continue
        
        # Replace with most common word
        # Nothing to lose as <unk> anyways
        if word == "<unk>":
            if prevWord is not None:
                if prevWord is not "the":
                    word = "the"

        prevWord = word
        newRes.append(word)
    allnew.append(" ".join(newRes))
    
print(len(allnew))
print(len(ref_t))
# Out:
# when when i was in my 20s , i had my first <unk> . .
# 1305
# 1305

# %% [markdown]
# ## Evalution score for final combined module leads to a score of 20.01 :)

# %%
from bleu_check import bleu
ref_t = []
with open(os.path.join('../data','reference','dev.out')) as r:
    ref_t = r.read().strip().splitlines()
print(bleu(ref_t, allnew))
# Out:
# BLEU = 20.01 60.5/29.4/16.2/9.5 (BP = 0.876 ratio = 0.883 hyp_len = 21980 ref_len = 24902)

# %% [markdown]
# ## Documentation & Analysis
#
# In our homework, we try to improve the perfomance of the NMT in three parts. We fix the broken attention model which plays an important role and the model get the baseline 17.11. And then we add a beam search in our Decoder, and the score rise to the 19.62. Finally, we find that the unk and repeated token does have a bad effect on our model. So when we fixed them, our model reach the 20.01.

# %% [markdown]
# One weak point is the speed of our model. It takes us almost 100mins to run it via cpu and 20mins via GPU
